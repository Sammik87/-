# %%
#Парсинг cian - Помещения

# %%
#Импортируем необходиимых библиотек для реализации парсинга
from selenium import webdriver
from selenium_stealth import stealth # делает похожим на настоящего пользователя
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from time import sleep
from tqdm import tqdm
import pandas as pd
import numpy as np

# %%
options = webdriver.ChromeOptions()
options.add_argument("start_maximized")

options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
driver = webdriver.Chrome(options=options, executable_path=r"C:\Python\chromedriver.exe")
#https://chromedriver.chromium.org/ - тут можно скачать актуальный chromedriver.exe

stealth(driver,
        languages=["en-US", "en"],
        vendor="Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Iris OpenGL Engine",
        fix_hairline=True,
        )

link_all = []

p = 13 # количество страниц

for page in tqdm(range(1, p, 1), 'Обработанно страниц'):
    
    url = f"https://www.cian.ru/cat.php?deal_type=sale&engine_version=2&offer_type=offices&office_type%5B0%5D=1&p={page}&region=4820"
    driver.get(url)
    sleep(2) #спим 2 секунды (прогрузка страницы)
    
    #выгружаем ссылку по всем квартирам
    blocks = driver.find_elements_by_class_name('_32bbee5fda--offer-title-content-container--_kUhi')
    for block in blocks:
        link = block.find_element_by_tag_name('a').get_attribute("href")
        link_all.append(link)
# Out:
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\2255168029.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(options=options, executable_path=r"C:\Python\chromedriver.exe")
# Обработанно страниц:   0%|                                                                      | 0/12 [00:00<?, ?it/s]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\2255168029.py:28: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   blocks = driver.find_elements_by_class_name('_32bbee5fda--offer-title-content-container--_kUhi')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\2255168029.py:30: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   link = block.find_element_by_tag_name('a').get_attribute("href")
# Обработанно страниц: 100%|█████████████████████████████████████████████████████████████| 12/12 [01:04<00:00,  5.41s/it]

# %%
link_all
# Out:
# ['https://krasnodar.cian.ru/sale/commercial/284367429/',
#  'https://krasnodar.cian.ru/sale/commercial/284011322/',
#  'https://krasnodar.cian.ru/sale/commercial/282850144/',
#  'https://krasnodar.cian.ru/sale/commercial/282850143/',
#  'https://krasnodar.cian.ru/sale/commercial/284011318/',
#  'https://krasnodar.cian.ru/sale/commercial/283959822/',
#  'https://krasnodar.cian.ru/sale/commercial/284009996/',
#  'https://krasnodar.cian.ru/sale/commercial/283959827/',
#  'https://krasnodar.cian.ru/sale/commercial/284009994/',
#  'https://krasnodar.cian.ru/sale/commercial/283959825/',
#  'https://krasnodar.cian.ru/sale/commercial/284011320/',
#  'https://krasnodar.cian.ru/sale/commercial/284009992/',
#  'https://krasnodar.cian.ru/sale/commercial/274390687/',
#  'https://krasnodar.cian.ru/sale/commercial/280983024/',
#  'https://krasnodar.cian.ru/sale/commercial/186023091/',
#  'https://krasnodar.cian.ru/sale/commercial/279380295/',
#  'https://krasnodar.cian.ru/sale/commercial/284894017/',
#  'https://krasnodar.cian.ru/sale/commercial/284709510/',
#  'https://krasnodar.cian.ru/sale/commercial/279352570/',
#  'https://krasnodar.cian.ru/sale/commercial/266067425/',
#  'https://krasnodar.cian.ru/sale/commercial/283476159/',
#  'https://krasnodar.cian.ru/sale/commercial/282191375/',
#  'https://krasnodar.cian.ru/sale/commercial/281676999/',
#  'https://krasnodar.cian.ru/sale/commercial/276981845/',
#  'https://krasnodar.cian.ru/sale/commercial/280695262/',
#  'https://krasnodar.cian.ru/sale/commercial/283919869/',
#  'https://krasnodar.cian.ru/sale/commercial/283818352/',
#  'https://krasnodar.cian.ru/sale/commercial/282908596/']

# %%
len(link_all)
# Out:
# 327

# %%
#options = webdriver.ChromeOptions()
#options.add_argument("start_maximized")

#options.add_experimental_option("excludeSwitches", ["enable-automation"])
#options.add_experimental_option('useAutomationExtension', False)
#driver = webdriver.Chrome(options=options, executable_path=r"C:\Python\chromedriver.exe")
##https://chromedriver.chromium.org/ - тут можно скачать актуальный chromedriver.exe

#stealth(driver,
#        languages=["en-US", "en"],
#        vendor="Google Inc.",
#        platform="Win32",
#        webgl_vendor="Intel Iris OpenGL Engine",
#        fix_hairline=True,
#        )

#url = f"https://kazan.cian.ru/sale/commercial/284551039/"
#driver.get(url)
#sleep(2) #спим 2 секунды (прогрузка страницы)

t1 = [] #список
a = 0

for lnk in tqdm(link_all, 'Сбор данных'):
    try:
        a = a + 1 #счетчик
        t1.clear() #очищаем список значений

        driver.get(lnk) #открываем ссылку
        sleep(2) #спим 2 секунды (прогрузка страницы)

        #Площадь
        inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
        ls_1 = ['Назначение', inf_1[0]] #создаем список для назначения
        ls_2 = ['Площадь_1', inf_1[1].split(' ')[1]] #создаем список для площади из загаловка
        t1.append(ls_1) #складываем в список
        t1.append(ls_2) #складываем в список

        #Площадь, этаж и этажность
        inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
        ls_1 = ['Площадь_2', inf_2[0].text.split(' ')[0]] #создаем список для площади из описания
        ls_2 = ['Этаж', inf_2[1].text.split(' ')[0]] #создаем список для этажа
        ls_3 = ['Этажность', inf_2[1].text.split(' ')[2]] #создаем список для этажности
        t1.append(ls_1) #складываем в список
        t1.append(ls_2) #складываем в список
        t1.append(ls_3) #складываем в список


        #Текст объявления
        inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
        ls_1 = ['Текст_об', inf_3]
        t1.append(ls_1)

        #Адрес
        inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
        ls_1 = ['Адрес', inf_4]
        t1.append(ls_1)

        #Таблица под картой
        inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
        k_1 = len(inf_5) #количество строк в таблице
        for j in range(0, k_1):
            table = inf_5[j].text.split('\n') #выгружаем текст и разделяем его на части по символу "\n"
            t1.append(table) #складываем в список

        #Стоимость
        price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
        ls_1 = ['Цена', price]
        t1.append(ls_1)
        
        #ССЫЛКА
        lnk_1 = ['Ссылка', lnk] #создаем список для ссылки
        t1.append(lnk_1) #складываем в список

        df = pd.DataFrame(t1)
        df = df.set_index(0)    

        if a == 1:
            df_result = df
        if a > 1:
            df_result = pd.concat([df_result, df], axis = 1)

    except:
        continue

df_result_copy = df_result.copy() #делаем копию данных
df_result_copy = df_result_copy.transpose() #транспонируем таблицу

#Сохраняем в Excel
writer = pd.ExcelWriter('Офисы_Краснодар.xlsx')
df_result_copy.to_excel(writer, 'marks')
writer.save()
# Out:
# Сбор данных:   0%|                                                                             | 0/327 [00:00<?, ?it/s]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   1%|▍                                                                    | 2/327 [00:11<29:12,  5.39s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   1%|▋                                                                    | 3/327 [00:14<23:26,  4.34s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   1%|▊                                                                    | 4/327 [00:25<38:01,  7.06s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   2%|█                                                                    | 5/327 [00:28<30:25,  5.67s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   2%|█▎                                                                   | 6/327 [00:41<43:25,  8.12s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   2%|█▍                                                                   | 7/327 [00:45<36:05,  6.77s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   2%|█▋                                                                   | 8/327 [00:49<31:32,  5.93s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   3%|█▉                                                                   | 9/327 [00:53<27:40,  5.22s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   3%|██                                                                  | 10/327 [00:56<24:25,  4.62s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   3%|██▎                                                                 | 11/327 [01:00<22:09,  4.21s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   4%|██▍                                                                 | 12/327 [01:03<20:35,  3.92s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   4%|██▋                                                                 | 13/327 [01:07<20:13,  3.87s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   4%|██▉                                                                 | 14/327 [01:10<19:19,  3.70s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   5%|███                                                                 | 15/327 [01:14<20:09,  3.88s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   5%|███▎                                                                | 16/327 [01:18<20:20,  3.92s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   5%|███▌                                                                | 17/327 [01:22<19:22,  3.75s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   6%|███▋                                                                | 18/327 [01:26<20:14,  3.93s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   6%|███▉                                                                | 19/327 [01:30<19:58,  3.89s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:   6%|████▏                                                               | 20/327 [01:34<20:11,  3.95s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# ...
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:  97%|████████████████████████████████████████████████████████████████▉  | 317/327 [19:37<00:37,  3.80s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:  97%|█████████████████████████████████████████████████████████████████▏ | 318/327 [19:40<00:34,  3.79s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:  98%|█████████████████████████████████████████████████████████████████▎ | 319/327 [19:46<00:33,  4.20s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:  98%|█████████████████████████████████████████████████████████████████▌ | 320/327 [19:50<00:28,  4.11s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:  98%|█████████████████████████████████████████████████████████████████▊ | 321/327 [19:53<00:23,  3.85s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:  98%|█████████████████████████████████████████████████████████████████▉ | 322/327 [19:56<00:18,  3.62s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# Сбор данных:  99%|██████████████████████████████████████████████████████████████████▍| 324/327 [20:04<00:11,  3.73s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:50: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_3 = driver.find_element_by_class_name('a10a3f92e9--description-text--YNzWU').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:55: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_4 = driver.find_element_by_class_name('a10a3f92e9--address--fHIqz').text
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:60: DeprecationWarning: find_elements_by_tag_name is deprecated. Please use find_elements(by=By.TAG_NAME, value=name) instead
#   inf_5 = driver.find_element_by_class_name('a10a3f92e9--list--EfxoW').find_elements_by_tag_name('li')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:67: DeprecationWarning: find_element_by_tag_name is deprecated. Please use find_element(by=By.TAG_NAME, value=name) instead
#   price = driver.find_element_by_class_name('a10a3f92e9--price--PcAEt').find_element_by_tag_name('span').get_attribute("content")
# Сбор данных:  99%|██████████████████████████████████████████████████████████████████▌| 325/327 [20:08<00:08,  4.03s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:33: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   inf_1 = driver.find_element_by_class_name('a10a3f92e9--container--PJnny').text.split(',')
# C:\Users\skapr\AppData\Local\Temp\ipykernel_13724\1514336856.py:40: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   inf_2 = driver.find_elements_by_class_name('a10a3f92e9--info-value--bm3DC')
# Сбор данных: 100%|███████████████████████████████████████████████████████████████████| 327/327 [20:16<00:00,  3.72s/it]
