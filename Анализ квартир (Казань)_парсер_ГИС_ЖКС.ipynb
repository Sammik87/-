# %%
#Импортируем необходиимых библиотек для реализации парсинга
from selenium import webdriver
from selenium_stealth import stealth # делает похожим на настоящего пользователя
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from time import sleep
from tqdm import tqdm
import pandas as pd
import numpy as np
import winsound
import requests

from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select

import datetime
year = datetime.date.today().year

# %%
#webdriver.__version__
import selenium
selenium.__version__
#import selenium
# Out:
# '4.15.2'

# %%
service = Service(executable_path = 'C:\Python\chromedriver.exe')
options = webdriver.ChromeOptions()

options.add_argument("--disable-blink-features")
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
options.add_argument("start_maximized")

driver = webdriver.Chrome(service = service, options = options)

stealth(driver,
#        user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.53 Safari/537.36',
        languages=["en-US", "en"],
        vendor = "Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine",
        fix_hairline=False, #True 
        run_on_insecure_origins=False
        )

link_all = []

url = f"https://dom.gosuslugi.ru/#!/houses"

driver.get(url)
sleep(3)

# %%
driver.find_element(By.XPATH, '//*[@id="s2id_regionpa1"]/a').click() #находим выпадающий список Субъект РФ
input_1 = driver.find_element(By.XPATH, '//*[@id="s2id_autogen6_search"]') #находим input Субъект РФ
input_1.send_keys('Приморский край') #вносим в ячейку Приморский край
sleep(2) #спим 2 секунды
input_1.send_keys(Keys.ENTER) #жмем Enter

driver.find_element(By.XPATH, '//*[@id="s2id_citypa1"]/a').click() #находим выпадающий список Город
input_2 = driver.find_element(By.XPATH, '//*[@id="s2id_autogen10_search"]') #находим input
input_2.send_keys('Владивосток') #вносим в ячейку г. Владивосток
sleep(2) #спим 2 секунды
input_2.send_keys(Keys.ENTER) #жмем Enter

driver.find_element(By.XPATH, '//*[@id="s2id_autogen25"]').click() #находим выпадающий список Тип дома
sleep(2)
driver.find_element(By.XPATH, '//*[@id="select2-drop"]/ul/li[1]').click() #Выбираем Многоквартирный или Жилой
sleep(3)
# //*[@id="select2-drop"]/ul/li[1] #Жилое
# //*[@id="select2-drop"]/ul/li[3] #Многоквартирный

#button = driver.find_element(By.XPATH, '/html/body/div[1]/div[8]/div/div[2]/houses-search-form/div[2]/div/ef-bp-form/div/form/div[3]/div/div[2]/button') #находим элемент кнопки Еще
#button.send_keys(Keys.ENTER) #нажимаем кнопку Найти
#sleep(10) #спим 10 секунд

# %%
#Парсим все улицы
soup = BeautifulSoup(driver.page_source, 'lxml')

street = soup.findAll('div', class_ = 'select2-result-label')

streets = []

for st in street:
    streets.append(st.text)

streets
#len(table_2)
# Out:
# ['пр-кт. 100-летия Владивостока',
#  'ул. 10-я Рабочая',
#  'ул. 13-я Рабочая',
#  'ул. 1-я Восточная',
#  'ул. 1-я Встречная',
#  'ул. 1-я Гражданская',
#  'ул. 1-я Дачная',
#  'ул. 1-я Заречная',
#  'ул. 1-я Круговая',
#  'ул. 1-я Крутая',
#  'ул. 1-я Лесная',
#  'ул. 1-я Линейная',
#  'ул. 1-я Матросская',
#  'ул. 1-я Морская',
#  'ул. 1-я Поселковая',
#  'ул. 1-я Пригородная',
#  'ул. 1-я Промышленная',
#  'ул. 1-я Проходная',
#  'ул. 1-я Северная',
#  'ул. 1-я Флотская',
#  'ул. 1-я Центральная',
#  'ул. 1-я Шоссейная',
#  'ул. 20 лет ВЛКСМ',
#  'ул. 2-я Водопроводная',
#  'ул. 2-я Восточная',
#  'ул. 2-я Гражданская',
#  'ул. 2-я Круговая',
#  'ул. 2-я Крутая',
#  'ул. 2-я Лесная',
#  'ул. 2-я Линейная',
#  'ул. 2-я Матросская',
#  'ул. 2-я Поселковая',
#  'ул. 2-я Пригородная',
#  'ул. 2-я Промышленная',
#  'ул. 2-я Проходная',
#  'ул. 2-я Строительная',
#  'ул. 2-я Центральная',
#  'ул. 2-я Шоссейная',
#  'ул. 2-я Южная',
#  'ул. 3-ий Ключ',
#  'пер. 3-й Восточный',
#  'ул. 3-я Восточная',
#  'ул. 3-я Встречная',
#  'ул. 3-я Гарнизонная',
#  'ул. 3-я Круговая',
#  'ул. 3-я Крутая',
#  'ул. 3-я Лесная',
#  'ул. 3-я Линейная',
#  'ул. 3-я Матросская',
#  'ул. 3-я Поселковая',
#  'ул. 3-я Пригородная',
#  'ул. 3-я Проходная',
#  'ул. 3-я Северная',
#  'ул. 3-я Строительная',
#  'ул. 3-я Центральная',
#  'ул. 3-я Шоссейная',
#  'ул. 3-я Южная',
#  'ул. 40 лет ВЛКСМ',
#  'ул. 4-ый Ключ',
#  'ул. 4-я Восточная',
#  'ул. 4-я Круговая',
#  'ул. 4-я Матросская',
#  'ул. 4-я Пригородная',
#  'ул. 4-я Проходная',
#  'ул. 4-я Террасная',
#  'ул. 4-я Флотская',
#  'ул. 4-я Центральная',
#  'ул. 50 лет ВЛКСМ',
#  'ул. 5-ый Ключ',
#  'ул. 5-я Восточная',
#  'ул. 5-я Матросская',
#  'ул. 5-я Проходная',
#  'ул. 5-я Террасная',
#  'ул. 5-я Центральная',
#  'ул. 60 лет ВЛКСМ',
#  'ул. 6-я Восточная',
#  'ул. 6-я Матросская',
#  'ул. 7-я Матросская',
#  'ул. 9-я Рабочая',
#  'ул. Абрекская',
#  'ул. Абрикосовая',
#  'пер. Абрикосовый',
#  'снт. Авангард',
#  'ул. Августовского',
#  'ул. Авиаторов',
#  'ул. Авраменко',
#  'ул. Авроровская',
#  'ул. Адмирала Горшкова',
#  'ул. Адмирала Корнилова',
#  'ул. Адмирала Кузнецова',
#  'пер. Адмирала Макарова',
#  'ул. Адмирала Макарова',
#  'ул. Адмирала Смирнова',
#  'ул. Адмирала Угрюмова',
#  'ул. Адмирала Фокина',
#  'ул. Адмирала Юмашева',
#  'ул. Азовская',
#  'ул. Аирная',
#  'ул. Аистовая',
#  'ул. Айвазовского',
#  'ул. Академика Воронова',
#  'ул. Академика Комарова',
#  'ул. Академика Крушанова',
#  'пер. Академический',
#  'ул. Аквамариновая',
#  'ул. Акимушкина',
#  'ул. Аксаковская',
#  'ул. Александра Грина',
#  'ул. Александровича',
#  'ул. Алеутская',
#  'ул. Аллилуева',
#  'ул. Алтайская',
#  'ул. Альбатросовая',
#  'ул. Алябьева',
#  'ул. Амадиновая',
#  'ул. Амарантовая',
#  'ул. Американская',
#  'ул. Аметистовая',
#  'ул. Амундсена',
#  'ул. Амурская',
#  'ул. Аникушина',
#  'ул. Анисимова',
#  'ул. Анисовая',
#  'ул. Анны Щетининой',
#  'ул. Анучинская',
#  'ул. Анютинская',
#  'ул. Апухтина',
#  'ул. Аральская',
#  'ул. Аренского',
#  'ул. Арктическая',
#  'ул. Арсенальная',
#  'ул. Арсеньева',
#  'ул. Артековская',
#  'ул. Артёмовская',
#  'ул. Архангельская',
#  'пер. Астрономический',
#  'ул. Багратиона',
#  'ул. Байдукова',
#  'ул. Байкальская',
#  'ул. Бакинская',
#  'ул. Бакунина',
#  'ул. Балакирева',
#  'ул. Балкерная',
#  'ул. Балтийская',
#  'ул. Балтовская',
#  'ул. Баляева',
#  'ул. Баневура',
#  'ул. Баратынского',
#  'ул. Барбарисовая',
#  'ул. Барбетная',
#  'ул. Баркасная',
#  'ул. Барклая',
#  'ул. Барсовая',
#  'ул. Бархатная',
#  'ул. Басаргина',
#  'ул. Бассейновая',
#  'ул. Батарейная',
#  'ул. Батумская',
#  'ул. Башидзе',
#  'ул. Бежецкая',
#  'пер. Безымянный',
#  'ул. Белинского',
#  'ул. Беломорская',
#  'ул. Беляева',
#  'ул. Белякова',
#  'ул. Береговая',
#  'ул. Березовая',
#  'пер. Беринга',
#  'ул. Беркутовая',
#  'ул. Бестужева',
#  'ул. Бетховена',
#  'ул. Бианки',
#  'ул. Бийская',
#  'пер. Биологический',
#  'ул. Большекаменская',
#  'ул. Борисенко',
#  'ул. Бородинская',
#  'ул. Босфора',
#  'ул. Боярышниковая',
#  'ул. Братская',
#  'ул. Брестская',
#  'пер. Брестский',
#  'ул. Бринера',
#  'ул. Брусничная',
#  'ул. Брюллова',
#  'ул. Брюсова',
#  'ул. Брянская',
#  'ул. Буковая',
#  'ул. Буксирная',
#  'ул. Бульварная',
#  'ул. Бурачка',
#  'ул. Буреинская',
#  'ул. Буссе',
#  'ул. Буферная',
#  'тер. Бухта Лазурная',
#  'ул. Бянкина',
#  'ул. Вавилова',
#  'ул. Васильковая',
#  'ул. Васнецова',
#  'ул. Ватутина',
#  'ул. Бурачка',
#  'ул. Буреинская',
#  'ул. Буссе',
#  'ул. Буферная',
#  'тер. Бухта Лазурная',
#  'ул. Бянкина',
#  'ул. Вавилова',
#  'ул. Васильковая',
#  'ул. Васнецова',
#  'ул. Ватутина',
#  'ул. Венюкова',
#  'снт. Вербное',
#  'ул. Вересковая',
#  'пер. Верещагина',
#  'ул. Верещагина',
#  'ул. Вертинского',
#  'ул. Вертолетная',
#  'ул. Верхнепортовая',
#  'ул. Верхнеславянская',
#  'ул. Верхняя',
#  'ул. Весенняя',
#  'снт. Весна',
#  'ул. Ветвистая',
#  'ул. Ветеранов',
#  'снт. Ветеран революции',
#  'ул. Ветреная',
#  'ул. Взлетная',
#  'ул. Визбора',
#  'ул. Вилкова',
#  'ул. Виноградная',
#  'пер. Виноградный',
#  'ул. ВИР',
#  'снт. Вировец',
#  'ул. Виттенбурга',
#  'ул. Вишневая',
#  'ул. Владикавказская',
#  'снт. Водник',
#  'ул. Водолазная',
#  'ул. Военное Шоссе',
#  'ул. Вознесенская',
#  'ул. Вокзальная',
#  'ул. Волгоградская',
#  'ул. Волжская',
#  'ул. Волкова',
#  'снт. Волна',
#  'ул. Волнистая',
#  'ул. Володарского',
#  'ул. Волочаевская',
#  'ул. Волховская',
#  'ул. Воробьиная',
#  'ул. Воровского',
#  'ул. Воронежская',
#  'ул. Воропаева',
#  'снт. Восток',
#  'снт. Восток-2',
#  'пр-кт. Восточный',
#  'ул. Вострецова',
#  'снт. Восход',
#  'ул. Восьмая',
#  'ул. Врубеля',
#  'ул. Всеволода Сибирцева',
#  'ул. Вторая',
#  'ул. Выселковая',
#  'ул. Высокая',
#  'ул. Высоковольтная',
#  'ул. Высотная',
#  'ул. Вязовая',
#  'ул. Гагаринского',
#  'ул. Гамарника',
#  'ул. Гаршина',
#  'ул. Гассе',
#  'ул. Гастелло',
#  'ул. Гвардейская',
#  'пер. Географический',
#  'ул. Героев Варяга',
#  'ул. Героев-Даманцев',
#  'ул. Героев Тихоокеанцев',
#  'ул. Героев Хасана',
#  'ул. Герцена',
#  'ул. Главная',
#  'пер. Главный',
#  'ул. Глазунова',
#  'ул. Глинки',
#  'ул. Гоголя',
#  'ул. Голицына',
#  'ул. Голубичная',
#  'ул. Горийская',
#  'ул. Горицветная',
#  'ул. Горная',
#  'ул. Горького',
#  'ул. Гражданская',
#  'снт. Гранит',
#  'ул. Грекова',
#  'ул. Грибоедова',
#  'ул. Гризодубовой',
#  'ул. Грозовая',
#  'ул. Громова',
#  'ул. Грушевая',
#  'ул. Грязелечебница',
#  'ул. Гульбиновича',
#  'пер. Гусарский',
#  'снт. Гуфсин',
#  'ул. Давыдова',
#  'ул. Дальзаводская',
#  'ул. Дальнегорская',
#  'ул. Дальняя',
#  'ул. Дачная',
#  'пер. Дачный',
#  'ул. Двенадцатая',
#  'ул. Двинская',
#  'ул. Девятая',
#  'ул. Дежнева',
#  'ул. Демьяна Бедного',
#  'ул. Деревенская',
#  'ул. Державина',
#  'ул. Дерюгина',
#  'ул. Десантная',
#  'ул. Десятая',
#  'ул. Джамбула',
#  'ул. Дивная',
#  'ул. Дмитриева',
#  'ул. Днепровская',
#  'пер. Днепровский',
#  'ул. Днепропетровская',
#  'ул. Добровольского',
#  'ул. Добролюбова',
#  'пер. Дозорный',
#  'ул. Докучаева',
#  'ул. Донская',
#  'пер. Дорожный',
#  'ул. Достоевского',
#  'снт. Дружба',
#  'ул. Дружная',
#  'ул. Дубовая',
#  'ул. Дубравная',
#  'ул. Духовского',
#  'снт. ДЭПСС',
#  'ул. Ежевичная',
#  'ул. Елецкая',
#  'ул. Елочная',
#  'ул. Енисейская',
#  'ул. Есенина',
#  'ул. Ёлочная',
#  'ул. Жариковская',
#  'ул. Железнодорожная',
#  'пер. Железнодорожный',
#  'пер. Живительный',
#  'ул. Жигура',
#  'ул. Жуковского',
#  'ул. Журавлиная',
#  'ул. Завойко',
#  'ул. Загородная',
#  'ул. Залесная',
#  'ул. Западная',
#  'ул. Запорожская',
#  'пер. Запорожский',
#  'ул. Заречная',
#  'ул. Захарова',
#  'ул. Звёздная',
#  'пер. Звонкий',
#  'ул. Зейская',
#  'ул. Зеленая',
#  'пер. Зеленый',
#  'ул. Зеленый Бульвар',
#  'снт. Зеленый Угол',
#  'ул. Земляничная',
#  'ул. Зои Космодемьянской',
#  'пер. Золотистый',
#  'ул. Зябликовая',
#  'ул. Ивановская',
#  'ул. Ивовая',
#  'ул. Иволговая',
#  'ул. Извилистая',
#  'ул. Изюбриевая',
#  'ул. Ильичева',
#  'ул. Ильменская',
#  'ул. Иманская',
#  'ул. Импортная',
#  'ул. Инженерная',
#  'пер. Инженерный',
#  'ул. Интернациональная',
#  'ул. Ирисовая',
#  'ул. Иркутская',
#  'ул. Иртышская',
#  'пер. Иртышский',
#  'снт. Искра',
#  'пер. Исторический',
#  'ул. Ишимская',
#  'пер. Кавалеровский',
#  'ул. Казакевича',
#  'ул. Казанская',
#  'ул. Калинина',
#  'ул. Калининградская',
#  'ул. Калиновая',
#  'ул. Каляева',
#  'ул. Камская',
#  'пер. Камский',
#  'пер. Канатный',
#  'ул. Канская',
#  'ул. Капитана Орликовой',
#  'ул. Капитана Шефнера',
#  'ул. Каплунова',
#  'ул. Капонирная',
#  'ул. Карамзина',
#  'ул. Карбышева',
#  'ул. Карла Либкнехта',
#  'ул. Карпинского',
#  'ул. Карская',
#  'ул. Карьерная',
#  'пер. Карьерный',
#  'ул. Карякинская',
#  'ул. Каспийская',
#  'пер. Каспийский',
#  'ул. Катерная',
#  'ул. Каштановая',
#  'пер. Квартальный',
#  'пер. Кедровый',
#  'ул. Кемеровская',
#  'ул. Керченская',
#  'ул. Киевская',
#  'ул. Кизиловая',
#  'ул. Кизлярская',
#  'пер. Килевой',
#  'ул. Кипарисовая',
#  'ул. Кирова',
#  'пер. Кирочный',
#  'пер. Китовый',
#  'ул. Клавдии Шульженко',
#  'ул. Клевера',
#  'снт. Клен(ДМСС)',
#  'ул. Клинская',
#  'ул. Клыкова',
#  'ул. Ключевая',
#  'ул. Ковальчука',
#  'ул. Колесника',
#  'ул. Командорская',
#  'ул. Комитетская',
#  'ул. Коммунаров',
#  'ул. Коммуны',
#  'ул. Комсомольская',
#  'снт. Кооператор',
#  'ул. Корабельная Набережная',
#  'пер. Корабельный',
#  'ул. Короленко',
#  'ул. Короткая',
#  'ул. Космонавтов',
#  'ул. Котельникова',
#  'пер. Кочубея',
#  'ул. Кочубея',
#  'ул. Краева',
#  'ул. Крамского',
#  'пер. Красноармейский',
#  'пр-кт. Красного Знамени',
#  'ул. Краснодонская',
#  'ул. Краснозаводская',
#  'пер. Краснознаменный',
#  'ул. Крыгина',
#  'пер. Крылатый',
#  'ул. Крылова',
#  'ул. Крымская',
#  'ул. Кубанская',
#  'ул. Кузбасская',
#  'ул. Куинджи',
#  'ул. Куйбышева',
#  'ул. Курильская',
#  'ул. Курортная',
#  'ул. Курчатова',
#  'пер. Кустарный',
#  'ул. Кутузова',
#  'ул. Лаврова',
#  'ул. Ладожская',
#  'ул. Ладыгина',
#  'ул. Лазо',
#  'ул. Лазовская',
#  'пер. Лазуритовый',
#  'ул. Лазурная',
#  'снт. Ландыш',
#  'ул. Ландышевая',
#  'пер. Ланинский',
#  'ул. Лаптева',
#  'снт. Ласточка',
#  'ул. Ласточкина',
#  'ул. Левитана',
#  'ул. Левобережная',
#  'ул. Лейтенанта Шмидта',
#  'пер. Ленский',
#  'ул. Леонова',
#  'ул. Лепестковая',
#  'ул. Лескова',
#  'ул. Лесная',
#  'снт. Лесное',
#  'пер. Лесной',
#  'ул. Лесопитомник',
#  'снт. Лиман',
#  'ул. Липовая',
#  'ул. Лиственничная',
#  'ул. Листопадная',
#  'ул. Литовская',
#  'ул. Ломаная',
#  'ул. Ломоносова',
#  'ул. Лоскутова',
#  'ул. Лоцманская',
#  'ул. Луговая',
#  'ул. Лукина',
#  'ул. Лукоморье',
#  'ул. Лунная',
#  'ул. Луцкого',
#  'пер. Лучезарный',
#  'ул. Лучистая',
#  'ул. Лянчихинская',
#  'ул. Маака',
#  'ул. Магнитогорская',
#  'ул. Майкова',
#  'ул. Майора Филипова',
#  'ул. Майская',
#  'пер. Маковского',
#  'ул. Маковского',
#  'ул. Максимовича',
#  'ул. Малика',
#  'ул. Малиновая',
#  'ул. Мамонтова',
#  'ул. Маньчжурская',
#  'ул. Маргаритова',
#  'ул. Марины Расковой',
#  'ул. Марченко',
#  'пер. Математический',
#  'ул. Матросова',
#  'ул. Махалина',
#  'ул. Маяковского',
#  'снт. Медик',
#  'ул. Медовая',
#  'ул. Междугородняя',
#  'ул. Мельниковская',
#  'ул. Менделеева',
#  'ул. Металлистов',
#  'ул. Металлургическая',
#  'ул. Метельная',
#  'ул. Мехлиса',
#  'ул. Мечникова',
#  'снт. Мечта',
#  'ул. Милоградовская',
#  'ул. Минеральная',
#  'ул. Минеров',
#  'ул. Минная',
#  'ул. Мира',
#  'ул. Михайловского',
#  'снт. Мичуринец',
#  'ул. Мичуринская',
#  'пер. Мичуринский',
#  'ул. Могилевская',
#  'ул. Можайская',
#  'ул. Можжевеловая',
#  'ул. Монтажная',
#  'ул. Мопровская',
#  'ул. Мордовцева',
#  'ул. Мореходная',
#  'ул. Морозова',
#  'снт. Моряк-2',
#  'ул. Московская',
#  'ул. Мотыльковая',
#  'ул. Моцарта',
#  'ул. Муравьева-Амурского',
#  'ул. Мурманская',
#  'ул. Мусоргского',
#  'ул. Мыс Кунгасный',
#  'ул. Мысовая',
#  'ул. Мыс Чумака',
#  'ул. Набережная',
#  'ул. Надарова',
#  'ул. Надибаидзе',
#  'ул. Нарвская',
#  'пр-кт. Народный',
#  'ул. Нахимова',
#  'ул. Находкинская',
#  'пер. Небесный',
#  'ул. Невельского',
#  'ул. Невская',
#  'ул. Нежинская',
#  'ул. Нейбута',
#  'ул. Некрасовская',
#  'пер. Некрасовский',
#  'ул. Нектарная',
#  'ул. Неманская',
#  'ул. Нерчинская',
#  'ул. Нестерова',
#  'ул. Нефритовая',
#  'ул. Нефтеветка',
#  'ул. Нижнепортовая',
#  'ул. Низинная',
#  'ул. Никитина',
#  'ул. Никифорова',
#  'пер. Новгородский',
#  'ул. Новицкого',
#  'ул. Новожилова',
#  'ул. Новоивановская',
#  'ул. Новороссийская',
#  'ул. Обзорная',
#  'ул. Областная',
#  'пер. Облачный',
#  'ул. Облепиховая',
#  'ул. Обручева',
#  'пер. Объездной',
#  'ул. Овражная',
#  'ул. Овчинникова',
#  'ул. Огарева',
#  'ул. Одесская',
#  'ул. Одиннадцатая',
#  'ул. Озерная',
#  'ул. Окатовая',
#  'пр-кт. Океанский',
#  'ул. Октябрьская',
#  'ул. Окуджавы',
#  'ул. Олега Кошевого',
#  'пер. Ольгинский',
#  'ул. Ольховая',
#  'ул. Опаловая',
#  'ул. Опорная',
#  'снт. Орбита',
#  'ул. Орбитальная',
#  'ул. Островского',
#  'ул. Острогорная',
#  'пр-кт. Острякова',
#  'ул. Отлогая',
#  'ул. Отрадная',
#  'ул. Охотская',
#  'пер. Охотский',
#  'ул. Очаковская',
#  'пер. Павленко',
#  'ул. Паллады',
#  'ул. Пальчевского',
#  'ул. Панфилова',
#  'ул. Парашютная',
#  'ул. Паровозная',
#  'ул. Партизанская',
#  'пр-кт. Партизанский',
#  'ул. Парусная',
#  'пер. Пархоменко',
#  'ул. Пархоменко',
#  'ул. Пасечная',
#  'снт. Патриот-6',
#  'ул. Патрокл',
#  'ул. Паустовского',
#  'ул. Пацаева',
#  'ул. Пейзажная',
#  'снт. Пенсионер',
#  'ул. Первая',
#  'пер. Перекопский',
#  'ул. Перепелиная',
#  'ул. Персиковая',
#  'ул. Пестеля',
#  'ул. Петра Великого',
#  'ул. Печорская',
#  'пер. Пилотажный',
#  'снт. Пионер',
#  'ул. Пионерская',
#  'ул. Пионовая',
#  'ул. Пирогова',
#  'ул. Писаревская',
#  'ул. Пихтовая',
#  'ул. Планерная',
#  'ул. Плеханова',
#  'ул. Плещеева',
#  'пер. Поворотный',
#  'ул. Пограничная',
#  'ул. Подгорная',
#  'ул. Подъемная',
#  'ул. Пожарского',
#  'ул. Полевая',
#  'пер. Полезный',
#  'ул. Поленова',
#  'пер. Полетаева',
#  'ул. Полетаева',
#  'ул. Полины Осипенко',
#  'ул. Полковника Фесюна',
#  'ул. Пологая',
#  'ул. Полонского',
#  'ул. Полтавская',
#  'ул. Полярная',
#  'ул. Попутная',
#  'снт. Портовик',
#  'снт. Портовик-1',
#  'ул. Посадская',
#  'пер. Поселковый',
#  'ул. Постышева',
#  'ул. Посьетская',
#  'ул. Потийская',
#  'ул. Почтовая',
#  'пер. Почтовый',
#  'ул. Пояркова',
#  'ул. Правобережная',
#  'ул. Прапорщика Комарова',
#  'ул. Пржевальского',
#  'ул. Прибрежная',
#  'ул. Приветливая',
#  'ул. Призовая',
#  'ул. Приморская',
#  'снт. Приморский садовод',
#  'ул. Приходько',
#  'ул. Причальная',
#  'ул. Пришвина',
#  'ул. Прокофьева',
#  'ул. Промежуточная',
#  'ул. Промысловая',
#  'ул. Проселочная',
#  'ул. Просторная',
#  'ул. Проточная',
#  'ул. Профессора Куренцова',
#  'ул. Профессора Шапкина',
#  'ул. Пугачева',
#  'ул. Пушкинская',
#  'ул. Пятая',
#  'ул. Пятнадцатая',
#  'пер. Радарный',
#  'пер. Радио',
#  'ул. Радио',
#  'ул. Радиостанция',
#  'ул. Радостная',
#  'ул. Радужная',
#  'пер. Радужный',
#  'ул. Раевского',
#  'ул. Раздольная',
#  'ул. Разина',
#  'ул. Ракетная',
#  'ул. Ракитная',
#  'ул. Рассветная',
#  'ул. Расула Гамзатова',
#  'ул. Рахманинова',
#  'ул. Режицкая',
#  'ул. Рейдовая',
#  'ул. Репина',
#  'ул. Республики',
#  'ул. Речная',
#  'ул. Решетникова',
#  'ул. Рионская',
#  'ул. Роберта Баха',
#  'ул. Ровная',
#  'пер. Родниковый',
#  'ул. Розничная',
#  'ул. Розовая',
#  'пер. Розовый',
#  'ул. Рокадная',
#  'ул. Рокотова',
#  'ул. Романтиков',
#  'ул. Ромашковая',
#  'ул. Рубиновая',
#  'ул. Рубинштейна',
#  'ул. Руднева',
#  'пер. Рулевой',
#  'ул. Русанова',
#  'ул. Русская',
#  'пер. Ручейный',
#  'ул. Рыбацкая',
#  'пер. Рыбацкий',
#  'ул. Рыбинская',
#  'снт. Рыбники',
#  'ул. Рылеева',
#  'ул. Рюриковская',
#  'ул. Ряжская',
#  'ул. Сабанеева',
#  'ул. Саврасова',
#  'снт. Садгород',
#  'ул. Садгородская',
#  'ул. Садовая',
#  'пер. Садовый',
#  'ул. Садовый тупик',
#  'ул. Салтыкова',
#  'ул. Самаргинская',
#  'ул. Самарская',
#  'ул. Саперная',
#  'ул. Сапфировая',
#  'ул. Саратовская',
#  'ул. Саульского',
#  'ул. Сафонова',
#  'ул. Сахалинская',
#  'ул. Сахарный Ключ',
#  'ул. Свердлова',
#  'снт. Свет',
#  'ул. Светланская',
#  'пер. Светланский',
#  'ул. Свободная',
#  'ул. Связи',
#  'ул. Севастопольская',
#  'ул. Североморская',
#  'ул. Северо-Суйфунская',
#  'ул. Севская',
#  'ул. Седьмая',
#  'ул. Селенгинская',
#  'ул. Сельская',
#  'ул. Семеновская',
#  'ул. Семирадского',
#  'снт. Серебряный ключ',
#  'ул. Серова',
#  'ул. Сеульская',
#  'ул. Сибирская',
#  'ул. Сигнальная',
#  'ул. Симбирская',
#  'ул. Синичкина',
#  'ул. Сипягина',
#  'ул. Сиреневая',
#  'ул. Скатная',
#  'пер. Скатный',
#  'ул. Скворцовая',
#  'ул. Скрябина',
#  'ул. Славянская',
#  'ул. Сладкова',
#  'ул. Сливовая',
#  'ул. Слуцкого',
#  'пер. Случевского',
#  'ул. Смоленская',
#  'ул. Снегирева',
#  'ул. Снеговая',
#  'ул. Советская',
#  'пер. Соколиный',
#  'пер. Сокольничий',
#  'ул. Солнечная',
#  'снт. Солнечное',
#  'ул. Соловьиная',
#  'ул. Сопочная',
#  'ул. Сосновая',
#  'ул. Софьи Перовской',
#  'ул. Сочинская',
#  'ул. Союзная',
#  'ул. Спасательная',
#  'ул. Спиридонова',
#  'ул. Спокойная',
#  'ул. Спортивная',
#  'снт. Спутник',
#  'снт. Спутник-2',
#  'ул. Стальского',
#  'ул. Станичная',
#  'ул. Станционная',
#  'ул. Станюковича',
#  'ул. Старцева',
#  'ул. Стравинского',
#  'ул. Стрелковая',
#  'пер. Стрелковый',
#  'ул. Стрелочная',
#  'пер. Стрелочный',
#  'ул. Стрельникова',
#  'снт. Строитель-1',
#  'снт. Строитель(30 км)',
#  'снт. Строитель(ГВС)',
#  'ул. Сурикова',
#  'ул. Суханова',
#  'ул. Сухогрузная',
#  'ул. Счастливая',
#  'ул. Таганрогская',
#  'ул. Таежная',
#  'ул. Талалихина',
#  'ул. Таманская',
#  'ул. Тамбовская',
#  'пер. Танеева',
#  'ул. Танкерная',
#  'ул. Таривердиева',
#  'ул. Татарская',
#  'ул. Тверская',
#  'ул. Терешковой',
#  'ул. Тетюхинская',
#  'ул. Тёплая',
#  'ул. Тигровая',
#  'ул. Тимирязева',
#  'снт. Тинро',
#  'ул. Тисовая',
#  'ул. Тихвинская',
#  'ул. Тихоокеанская',
#  'ул. Тобольская',
#  'ул. Токаревская Кошка',
#  'ул. Токаревский Маяк',
#  'ул. Толбухина',
#  'ул. Толстого',
#  'ул. Томская',
#  'ул. Тополевая',
#  'ул. Траловая',
#  'ул. Трамвайная',
#  'ул. Трансформаторная',
#  'ул. Третья',
#  'ул. Тринадцатая',
#  'снт. Труд',
#  'пер. Трудовой',
#  'ул. Трудовых Резервов',
#  'ул. Тунгусская',
#  'ул. Тургенева',
#  'ул. Туристическая',
#  'ул. Туркменская',
#  'ул. Турмалиновая',
#  'ул. Тухачевского',
#  'снт. Тюльпан',
#  'ул. Тюменская',
#  'ул. Тютчева',
#  'ул. Уборевича',
#  'ул. Ужгородская',
#  'ул. Узбекская',
#  'ул. Ульяновская',
#  'ул. Уманская',
#  'ул. Уральская',
#  'ул. Урицкого',
#  'ул. Успенского',
#  'ул. Уссурийская',
#  'ул. Уткинская',
#  'снт. Учитель',
#  'ул. Учительская',
#  'ул. Уютная',
#  'ул. Фадеева',
#  'ул. Фазановая',
#  'ул. Фанерная',
#  'пер. Фанерный',
#  'ул. Фанзавод',
#  'ул. Фастовская',
#  'ул. Федеративная',
#  'ул. Феодосийская',
#  'ул. Ферсмана',
#  'ул. Фета',
#  'ул. Фиалковая',
#  'ул. Фигурная',
#  'пер. Финвальный',
#  'ул. Фирсова',
#  'ул. Фонвизина',
#  'ул. Фонтанная',
#  'ул. Фортовая',
#  'пер. Фрахтовый',
#  'ул. Фруктовая',
#  'ул. Хабаровская',
#  'пер. Хабаровский',
#  'ул. Ханкайская',
#  'ул. Харьковская',
#  'пер. Хасанский',
#  'ул. Хвойная',
#  'ул. Херсонская',
#  'ул. Хивинская',
#  'ул. Холмистая',
#  'ул. Хорольская',
#  'ул. Художественная',
#  'ул. Хуторская',
#  'ул. Цветочная',
#  'ул. Цимлянская',
#  'снт. Чайка',
#  'ул. Чайковского',
#  'ул. Чапаева',
#  'ул. Чароитная',
#  'ул. Часовитина',
#  'ул. Черемуховая',
#  'ул. Черкавского',
#  'ул. Черниговская',
#  'ул. Черноморская',
#  'ул. Чернышевского',
#  'ул. Черняховского',
#  'ул. Четвертая',
#  'ул. Четырнадцатая',
#  'ул. Чехова',
#  'ул. Читинская',
#  'ул. Чкалова',
#  'ул. Чукотская',
#  'пер. Чуркинский',
#  'снт. Шахтер',
#  'ул. Шахтерская',
#  'ул. Шахтовая',
#  'пер. Шахтовый',
#  'ул. Швартовая',
#  'ул. Шевелева',
#  'пер. Шевченко',
#  'ул. Шевченко',
#  'ул. Шелковичная',
#  'ул. Шепеткова',
#  'ул. Шестая',
#  'ул. Шилкинская',
#  'ул. Широкая',
#  'ул. Широколиственная',
#  'ул. Шишкина',
#  'ул. Шкипера Гека',
#  'пер. Школьный',
#  'ул. Шкотовская',
#  'пер. Шкотовский',
#  'ул. Шостаковича',
#  'ул. Шошина',
#  'ул. Штилевая',
#  'ул. Штормовая',
#  'ул. Шуйская',
#  'ул. Щедрина',
#  'ул. Щитовая',
#  'ул. Щорса',
#  'ул. Экипажная',
#  'снт. Энергетик',
#  'снт. Юбилей',
#  'снт. Юбилейное',
#  'снт. Юбилейное-2',
#  'ул. Южно-Уральская',
#  'ул. Яблоневая',
#  'ул. Яблочкова',
#  'ул. Ягодная',
#  'пер. Яковлевский',
#  'ул. Якорная бухта',
#  'ул. Якутская',
#  'ул. Ялтинская',
#  'ул. Янковского',
#  'ул. Ярославская',
#  'пер. Ярошенко',
#  'ул. Ясеневая',
#  'ул. Ясная',
#  'пер. Ясный',
#  'ул. Яхтовая',
#  ...]

# %%
#Сохраняем в Excel
writer = pd.ExcelWriter('База_ГИС_ЖКХ_streets.xlsx')
pd.DataFrame(streets).to_excel(writer, 'street')
writer.save()
# Out:
# C:\Users\skapr\AppData\Local\Temp\ipykernel_2948\692976354.py:4: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
#Сплитим улицы
street_1 = []

for i in range(0, len(streets), 1):
    stree = streets[i].split('.')[1].strip()
    street_1.append(stree)

# %%
street_1
# Out:
# ['100-летия Владивостока',
#  '10-я Рабочая',
#  '13-я Рабочая',
#  '1-я Восточная',
#  '1-я Встречная',
#  '1-я Гражданская',
#  '1-я Дачная',
#  '1-я Заречная',
#  '1-я Круговая',
#  '1-я Крутая',
#  '1-я Лесная',
#  '1-я Линейная',
#  '1-я Матросская',
#  '1-я Морская',
#  '1-я Поселковая',
#  '1-я Пригородная',
#  '1-я Промышленная',
#  '1-я Проходная',
#  '1-я Северная',
#  '1-я Флотская',
#  '1-я Центральная',
#  '1-я Шоссейная',
#  '20 лет ВЛКСМ',
#  '2-я Водопроводная',
#  '2-я Восточная',
#  '2-я Гражданская',
#  '2-я Круговая',
#  '2-я Крутая',
#  '2-я Лесная',
#  '2-я Линейная',
#  '2-я Матросская',
#  '2-я Поселковая',
#  '2-я Пригородная',
#  '2-я Промышленная',
#  '2-я Проходная',
#  '2-я Строительная',
#  '2-я Центральная',
#  '2-я Шоссейная',
#  '2-я Южная',
#  '3-ий Ключ',
#  '3-й Восточный',
#  '3-я Восточная',
#  '3-я Встречная',
#  '3-я Гарнизонная',
#  '3-я Круговая',
#  '3-я Крутая',
#  '3-я Лесная',
#  '3-я Линейная',
#  '3-я Матросская',
#  '3-я Поселковая',
#  '3-я Пригородная',
#  '3-я Проходная',
#  '3-я Северная',
#  '3-я Строительная',
#  '3-я Центральная',
#  '3-я Шоссейная',
#  '3-я Южная',
#  '40 лет ВЛКСМ',
#  '4-ый Ключ',
#  '4-я Восточная',
#  '4-я Круговая',
#  '4-я Матросская',
#  '4-я Пригородная',
#  '4-я Проходная',
#  '4-я Террасная',
#  '4-я Флотская',
#  '4-я Центральная',
#  '50 лет ВЛКСМ',
#  '5-ый Ключ',
#  '5-я Восточная',
#  '5-я Матросская',
#  '5-я Проходная',
#  '5-я Террасная',
#  '5-я Центральная',
#  '60 лет ВЛКСМ',
#  '6-я Восточная',
#  '6-я Матросская',
#  '7-я Матросская',
#  '9-я Рабочая',
#  'Абрекская',
#  'Абрикосовая',
#  'Абрикосовый',
#  'Авангард',
#  'Августовского',
#  'Авиаторов',
#  'Авраменко',
#  'Авроровская',
#  'Адмирала Горшкова',
#  'Адмирала Корнилова',
#  'Адмирала Кузнецова',
#  'Адмирала Макарова',
#  'Адмирала Макарова',
#  'Адмирала Смирнова',
#  'Адмирала Угрюмова',
#  'Адмирала Фокина',
#  'Адмирала Юмашева',
#  'Азовская',
#  'Аирная',
#  'Аистовая',
#  'Айвазовского',
#  'Академика Воронова',
#  'Академика Комарова',
#  'Академика Крушанова',
#  'Академический',
#  'Аквамариновая',
#  'Акимушкина',
#  'Аксаковская',
#  'Александра Грина',
#  'Александровича',
#  'Алеутская',
#  'Аллилуева',
#  'Алтайская',
#  'Альбатросовая',
#  'Алябьева',
#  'Амадиновая',
#  'Амарантовая',
#  'Американская',
#  'Аметистовая',
#  'Амундсена',
#  'Амурская',
#  'Аникушина',
#  'Анисимова',
#  'Анисовая',
#  'Анны Щетининой',
#  'Анучинская',
#  'Анютинская',
#  'Апухтина',
#  'Аральская',
#  'Аренского',
#  'Арктическая',
#  'Арсенальная',
#  'Арсеньева',
#  'Артековская',
#  'Артёмовская',
#  'Архангельская',
#  'Астрономический',
#  'Багратиона',
#  'Байдукова',
#  'Байкальская',
#  'Бакинская',
#  'Бакунина',
#  'Балакирева',
#  'Балкерная',
#  'Балтийская',
#  'Балтовская',
#  'Баляева',
#  'Баневура',
#  'Баратынского',
#  'Барбарисовая',
#  'Барбетная',
#  'Баркасная',
#  'Барклая',
#  'Барсовая',
#  'Бархатная',
#  'Басаргина',
#  'Бассейновая',
#  'Батарейная',
#  'Батумская',
#  'Башидзе',
#  'Бежецкая',
#  'Безымянный',
#  'Белинского',
#  'Беломорская',
#  'Беляева',
#  'Белякова',
#  'Береговая',
#  'Березовая',
#  'Беринга',
#  'Беркутовая',
#  'Бестужева',
#  'Бетховена',
#  'Бианки',
#  'Бийская',
#  'Биологический',
#  'Большекаменская',
#  'Борисенко',
#  'Бородинская',
#  'Босфора',
#  'Боярышниковая',
#  'Братская',
#  'Брестская',
#  'Брестский',
#  'Бринера',
#  'Брусничная',
#  'Брюллова',
#  'Брюсова',
#  'Брянская',
#  'Буковая',
#  'Буксирная',
#  'Бульварная',
#  'Бурачка',
#  'Буреинская',
#  'Буссе',
#  'Буферная',
#  'Бухта Лазурная',
#  'Бянкина',
#  'Вавилова',
#  'Васильковая',
#  'Васнецова',
#  'Ватутина',
#  'Бурачка',
#  'Буреинская',
#  'Буссе',
#  'Буферная',
#  'Бухта Лазурная',
#  'Бянкина',
#  'Вавилова',
#  'Васильковая',
#  'Васнецова',
#  'Ватутина',
#  'Венюкова',
#  'Вербное',
#  'Вересковая',
#  'Верещагина',
#  'Верещагина',
#  'Вертинского',
#  'Вертолетная',
#  'Верхнепортовая',
#  'Верхнеславянская',
#  'Верхняя',
#  'Весенняя',
#  'Весна',
#  'Ветвистая',
#  'Ветеранов',
#  'Ветеран революции',
#  'Ветреная',
#  'Взлетная',
#  'Визбора',
#  'Вилкова',
#  'Виноградная',
#  'Виноградный',
#  'ВИР',
#  'Вировец',
#  'Виттенбурга',
#  'Вишневая',
#  'Владикавказская',
#  'Водник',
#  'Водолазная',
#  'Военное Шоссе',
#  'Вознесенская',
#  'Вокзальная',
#  'Волгоградская',
#  'Волжская',
#  'Волкова',
#  'Волна',
#  'Волнистая',
#  'Володарского',
#  'Волочаевская',
#  'Волховская',
#  'Воробьиная',
#  'Воровского',
#  'Воронежская',
#  'Воропаева',
#  'Восток',
#  'Восток-2',
#  'Восточный',
#  'Вострецова',
#  'Восход',
#  'Восьмая',
#  'Врубеля',
#  'Всеволода Сибирцева',
#  'Вторая',
#  'Выселковая',
#  'Высокая',
#  'Высоковольтная',
#  'Высотная',
#  'Вязовая',
#  'Гагаринского',
#  'Гамарника',
#  'Гаршина',
#  'Гассе',
#  'Гастелло',
#  'Гвардейская',
#  'Географический',
#  'Героев Варяга',
#  'Героев-Даманцев',
#  'Героев Тихоокеанцев',
#  'Героев Хасана',
#  'Герцена',
#  'Главная',
#  'Главный',
#  'Глазунова',
#  'Глинки',
#  'Гоголя',
#  'Голицына',
#  'Голубичная',
#  'Горийская',
#  'Горицветная',
#  'Горная',
#  'Горького',
#  'Гражданская',
#  'Гранит',
#  'Грекова',
#  'Грибоедова',
#  'Гризодубовой',
#  'Грозовая',
#  'Громова',
#  'Грушевая',
#  'Грязелечебница',
#  'Гульбиновича',
#  'Гусарский',
#  'Гуфсин',
#  'Давыдова',
#  'Дальзаводская',
#  'Дальнегорская',
#  'Дальняя',
#  'Дачная',
#  'Дачный',
#  'Двенадцатая',
#  'Двинская',
#  'Девятая',
#  'Дежнева',
#  'Демьяна Бедного',
#  'Деревенская',
#  'Державина',
#  'Дерюгина',
#  'Десантная',
#  'Десятая',
#  'Джамбула',
#  'Дивная',
#  'Дмитриева',
#  'Днепровская',
#  'Днепровский',
#  'Днепропетровская',
#  'Добровольского',
#  'Добролюбова',
#  'Дозорный',
#  'Докучаева',
#  'Донская',
#  'Дорожный',
#  'Достоевского',
#  'Дружба',
#  'Дружная',
#  'Дубовая',
#  'Дубравная',
#  'Духовского',
#  'ДЭПСС',
#  'Ежевичная',
#  'Елецкая',
#  'Елочная',
#  'Енисейская',
#  'Есенина',
#  'Ёлочная',
#  'Жариковская',
#  'Железнодорожная',
#  'Железнодорожный',
#  'Живительный',
#  'Жигура',
#  'Жуковского',
#  'Журавлиная',
#  'Завойко',
#  'Загородная',
#  'Залесная',
#  'Западная',
#  'Запорожская',
#  'Запорожский',
#  'Заречная',
#  'Захарова',
#  'Звёздная',
#  'Звонкий',
#  'Зейская',
#  'Зеленая',
#  'Зеленый',
#  'Зеленый Бульвар',
#  'Зеленый Угол',
#  'Земляничная',
#  'Зои Космодемьянской',
#  'Золотистый',
#  'Зябликовая',
#  'Ивановская',
#  'Ивовая',
#  'Иволговая',
#  'Извилистая',
#  'Изюбриевая',
#  'Ильичева',
#  'Ильменская',
#  'Иманская',
#  'Импортная',
#  'Инженерная',
#  'Инженерный',
#  'Интернациональная',
#  'Ирисовая',
#  'Иркутская',
#  'Иртышская',
#  'Иртышский',
#  'Искра',
#  'Исторический',
#  'Ишимская',
#  'Кавалеровский',
#  'Казакевича',
#  'Казанская',
#  'Калинина',
#  'Калининградская',
#  'Калиновая',
#  'Каляева',
#  'Камская',
#  'Камский',
#  'Канатный',
#  'Канская',
#  'Капитана Орликовой',
#  'Капитана Шефнера',
#  'Каплунова',
#  'Капонирная',
#  'Карамзина',
#  'Карбышева',
#  'Карла Либкнехта',
#  'Карпинского',
#  'Карская',
#  'Карьерная',
#  'Карьерный',
#  'Карякинская',
#  'Каспийская',
#  'Каспийский',
#  'Катерная',
#  'Каштановая',
#  'Квартальный',
#  'Кедровый',
#  'Кемеровская',
#  'Керченская',
#  'Киевская',
#  'Кизиловая',
#  'Кизлярская',
#  'Килевой',
#  'Кипарисовая',
#  'Кирова',
#  'Кирочный',
#  'Китовый',
#  'Клавдии Шульженко',
#  'Клевера',
#  'Клен(ДМСС)',
#  'Клинская',
#  'Клыкова',
#  'Ключевая',
#  'Ковальчука',
#  'Колесника',
#  'Командорская',
#  'Комитетская',
#  'Коммунаров',
#  'Коммуны',
#  'Комсомольская',
#  'Кооператор',
#  'Корабельная Набережная',
#  'Корабельный',
#  'Короленко',
#  'Короткая',
#  'Космонавтов',
#  'Котельникова',
#  'Кочубея',
#  'Кочубея',
#  'Краева',
#  'Крамского',
#  'Красноармейский',
#  'Красного Знамени',
#  'Краснодонская',
#  'Краснозаводская',
#  'Краснознаменный',
#  'Крыгина',
#  'Крылатый',
#  'Крылова',
#  'Крымская',
#  'Кубанская',
#  'Кузбасская',
#  'Куинджи',
#  'Куйбышева',
#  'Курильская',
#  'Курортная',
#  'Курчатова',
#  'Кустарный',
#  'Кутузова',
#  'Лаврова',
#  'Ладожская',
#  'Ладыгина',
#  'Лазо',
#  'Лазовская',
#  'Лазуритовый',
#  'Лазурная',
#  'Ландыш',
#  'Ландышевая',
#  'Ланинский',
#  'Лаптева',
#  'Ласточка',
#  'Ласточкина',
#  'Левитана',
#  'Левобережная',
#  'Лейтенанта Шмидта',
#  'Ленский',
#  'Леонова',
#  'Лепестковая',
#  'Лескова',
#  'Лесная',
#  'Лесное',
#  'Лесной',
#  'Лесопитомник',
#  'Лиман',
#  'Липовая',
#  'Лиственничная',
#  'Листопадная',
#  'Литовская',
#  'Ломаная',
#  'Ломоносова',
#  'Лоскутова',
#  'Лоцманская',
#  'Луговая',
#  'Лукина',
#  'Лукоморье',
#  'Лунная',
#  'Луцкого',
#  'Лучезарный',
#  'Лучистая',
#  'Лянчихинская',
#  'Маака',
#  'Магнитогорская',
#  'Майкова',
#  'Майора Филипова',
#  'Майская',
#  'Маковского',
#  'Маковского',
#  'Максимовича',
#  'Малика',
#  'Малиновая',
#  'Мамонтова',
#  'Маньчжурская',
#  'Маргаритова',
#  'Марины Расковой',
#  'Марченко',
#  'Математический',
#  'Матросова',
#  'Махалина',
#  'Маяковского',
#  'Медик',
#  'Медовая',
#  'Междугородняя',
#  'Мельниковская',
#  'Менделеева',
#  'Металлистов',
#  'Металлургическая',
#  'Метельная',
#  'Мехлиса',
#  'Мечникова',
#  'Мечта',
#  'Милоградовская',
#  'Минеральная',
#  'Минеров',
#  'Минная',
#  'Мира',
#  'Михайловского',
#  'Мичуринец',
#  'Мичуринская',
#  'Мичуринский',
#  'Могилевская',
#  'Можайская',
#  'Можжевеловая',
#  'Монтажная',
#  'Мопровская',
#  'Мордовцева',
#  'Мореходная',
#  'Морозова',
#  'Моряк-2',
#  'Московская',
#  'Мотыльковая',
#  'Моцарта',
#  'Муравьева-Амурского',
#  'Мурманская',
#  'Мусоргского',
#  'Мыс Кунгасный',
#  'Мысовая',
#  'Мыс Чумака',
#  'Набережная',
#  'Надарова',
#  'Надибаидзе',
#  'Нарвская',
#  'Народный',
#  'Нахимова',
#  'Находкинская',
#  'Небесный',
#  'Невельского',
#  'Невская',
#  'Нежинская',
#  'Нейбута',
#  'Некрасовская',
#  'Некрасовский',
#  'Нектарная',
#  'Неманская',
#  'Нерчинская',
#  'Нестерова',
#  'Нефритовая',
#  'Нефтеветка',
#  'Нижнепортовая',
#  'Низинная',
#  'Никитина',
#  'Никифорова',
#  'Новгородский',
#  'Новицкого',
#  'Новожилова',
#  'Новоивановская',
#  'Новороссийская',
#  'Обзорная',
#  'Областная',
#  'Облачный',
#  'Облепиховая',
#  'Обручева',
#  'Объездной',
#  'Овражная',
#  'Овчинникова',
#  'Огарева',
#  'Одесская',
#  'Одиннадцатая',
#  'Озерная',
#  'Окатовая',
#  'Океанский',
#  'Октябрьская',
#  'Окуджавы',
#  'Олега Кошевого',
#  'Ольгинский',
#  'Ольховая',
#  'Опаловая',
#  'Опорная',
#  'Орбита',
#  'Орбитальная',
#  'Островского',
#  'Острогорная',
#  'Острякова',
#  'Отлогая',
#  'Отрадная',
#  'Охотская',
#  'Охотский',
#  'Очаковская',
#  'Павленко',
#  'Паллады',
#  'Пальчевского',
#  'Панфилова',
#  'Парашютная',
#  'Паровозная',
#  'Партизанская',
#  'Партизанский',
#  'Парусная',
#  'Пархоменко',
#  'Пархоменко',
#  'Пасечная',
#  'Патриот-6',
#  'Патрокл',
#  'Паустовского',
#  'Пацаева',
#  'Пейзажная',
#  'Пенсионер',
#  'Первая',
#  'Перекопский',
#  'Перепелиная',
#  'Персиковая',
#  'Пестеля',
#  'Петра Великого',
#  'Печорская',
#  'Пилотажный',
#  'Пионер',
#  'Пионерская',
#  'Пионовая',
#  'Пирогова',
#  'Писаревская',
#  'Пихтовая',
#  'Планерная',
#  'Плеханова',
#  'Плещеева',
#  'Поворотный',
#  'Пограничная',
#  'Подгорная',
#  'Подъемная',
#  'Пожарского',
#  'Полевая',
#  'Полезный',
#  'Поленова',
#  'Полетаева',
#  'Полетаева',
#  'Полины Осипенко',
#  'Полковника Фесюна',
#  'Пологая',
#  'Полонского',
#  'Полтавская',
#  'Полярная',
#  'Попутная',
#  'Портовик',
#  'Портовик-1',
#  'Посадская',
#  'Поселковый',
#  'Постышева',
#  'Посьетская',
#  'Потийская',
#  'Почтовая',
#  'Почтовый',
#  'Пояркова',
#  'Правобережная',
#  'Прапорщика Комарова',
#  'Пржевальского',
#  'Прибрежная',
#  'Приветливая',
#  'Призовая',
#  'Приморская',
#  'Приморский садовод',
#  'Приходько',
#  'Причальная',
#  'Пришвина',
#  'Прокофьева',
#  'Промежуточная',
#  'Промысловая',
#  'Проселочная',
#  'Просторная',
#  'Проточная',
#  'Профессора Куренцова',
#  'Профессора Шапкина',
#  'Пугачева',
#  'Пушкинская',
#  'Пятая',
#  'Пятнадцатая',
#  'Радарный',
#  'Радио',
#  'Радио',
#  'Радиостанция',
#  'Радостная',
#  'Радужная',
#  'Радужный',
#  'Раевского',
#  'Раздольная',
#  'Разина',
#  'Ракетная',
#  'Ракитная',
#  'Рассветная',
#  'Расула Гамзатова',
#  'Рахманинова',
#  'Режицкая',
#  'Рейдовая',
#  'Репина',
#  'Республики',
#  'Речная',
#  'Решетникова',
#  'Рионская',
#  'Роберта Баха',
#  'Ровная',
#  'Родниковый',
#  'Розничная',
#  'Розовая',
#  'Розовый',
#  'Рокадная',
#  'Рокотова',
#  'Романтиков',
#  'Ромашковая',
#  'Рубиновая',
#  'Рубинштейна',
#  'Руднева',
#  'Рулевой',
#  'Русанова',
#  'Русская',
#  'Ручейный',
#  'Рыбацкая',
#  'Рыбацкий',
#  'Рыбинская',
#  'Рыбники',
#  'Рылеева',
#  'Рюриковская',
#  'Ряжская',
#  'Сабанеева',
#  'Саврасова',
#  'Садгород',
#  'Садгородская',
#  'Садовая',
#  'Садовый',
#  'Садовый тупик',
#  'Салтыкова',
#  'Самаргинская',
#  'Самарская',
#  'Саперная',
#  'Сапфировая',
#  'Саратовская',
#  'Саульского',
#  'Сафонова',
#  'Сахалинская',
#  'Сахарный Ключ',
#  'Свердлова',
#  'Свет',
#  'Светланская',
#  'Светланский',
#  'Свободная',
#  'Связи',
#  'Севастопольская',
#  'Североморская',
#  'Северо-Суйфунская',
#  'Севская',
#  'Седьмая',
#  'Селенгинская',
#  'Сельская',
#  'Семеновская',
#  'Семирадского',
#  'Серебряный ключ',
#  'Серова',
#  'Сеульская',
#  'Сибирская',
#  'Сигнальная',
#  'Симбирская',
#  'Синичкина',
#  'Сипягина',
#  'Сиреневая',
#  'Скатная',
#  'Скатный',
#  'Скворцовая',
#  'Скрябина',
#  'Славянская',
#  'Сладкова',
#  'Сливовая',
#  'Слуцкого',
#  'Случевского',
#  'Смоленская',
#  'Снегирева',
#  'Снеговая',
#  'Советская',
#  'Соколиный',
#  'Сокольничий',
#  'Солнечная',
#  'Солнечное',
#  'Соловьиная',
#  'Сопочная',
#  'Сосновая',
#  'Софьи Перовской',
#  'Сочинская',
#  'Союзная',
#  'Спасательная',
#  'Спиридонова',
#  'Спокойная',
#  'Спортивная',
#  'Спутник',
#  'Спутник-2',
#  'Стальского',
#  'Станичная',
#  'Станционная',
#  'Станюковича',
#  'Старцева',
#  'Стравинского',
#  'Стрелковая',
#  'Стрелковый',
#  'Стрелочная',
#  'Стрелочный',
#  'Стрельникова',
#  'Строитель-1',
#  'Строитель(30 км)',
#  'Строитель(ГВС)',
#  'Сурикова',
#  'Суханова',
#  'Сухогрузная',
#  'Счастливая',
#  'Таганрогская',
#  'Таежная',
#  'Талалихина',
#  'Таманская',
#  'Тамбовская',
#  'Танеева',
#  'Танкерная',
#  'Таривердиева',
#  'Татарская',
#  'Тверская',
#  'Терешковой',
#  'Тетюхинская',
#  'Тёплая',
#  'Тигровая',
#  'Тимирязева',
#  'Тинро',
#  'Тисовая',
#  'Тихвинская',
#  'Тихоокеанская',
#  'Тобольская',
#  'Токаревская Кошка',
#  'Токаревский Маяк',
#  'Толбухина',
#  'Толстого',
#  'Томская',
#  'Тополевая',
#  'Траловая',
#  'Трамвайная',
#  'Трансформаторная',
#  'Третья',
#  'Тринадцатая',
#  'Труд',
#  'Трудовой',
#  'Трудовых Резервов',
#  'Тунгусская',
#  'Тургенева',
#  'Туристическая',
#  'Туркменская',
#  'Турмалиновая',
#  'Тухачевского',
#  'Тюльпан',
#  'Тюменская',
#  'Тютчева',
#  'Уборевича',
#  'Ужгородская',
#  'Узбекская',
#  'Ульяновская',
#  'Уманская',
#  'Уральская',
#  'Урицкого',
#  'Успенского',
#  'Уссурийская',
#  'Уткинская',
#  'Учитель',
#  'Учительская',
#  'Уютная',
#  'Фадеева',
#  'Фазановая',
#  'Фанерная',
#  'Фанерный',
#  'Фанзавод',
#  'Фастовская',
#  'Федеративная',
#  'Феодосийская',
#  'Ферсмана',
#  'Фета',
#  'Фиалковая',
#  'Фигурная',
#  'Финвальный',
#  'Фирсова',
#  'Фонвизина',
#  'Фонтанная',
#  'Фортовая',
#  'Фрахтовый',
#  'Фруктовая',
#  'Хабаровская',
#  'Хабаровский',
#  'Ханкайская',
#  'Харьковская',
#  'Хасанский',
#  'Хвойная',
#  'Херсонская',
#  'Хивинская',
#  'Холмистая',
#  'Хорольская',
#  'Художественная',
#  'Хуторская',
#  'Цветочная',
#  'Цимлянская',
#  'Чайка',
#  'Чайковского',
#  'Чапаева',
#  'Чароитная',
#  'Часовитина',
#  'Черемуховая',
#  'Черкавского',
#  'Черниговская',
#  'Черноморская',
#  'Чернышевского',
#  'Черняховского',
#  'Четвертая',
#  'Четырнадцатая',
#  'Чехова',
#  'Читинская',
#  'Чкалова',
#  'Чукотская',
#  'Чуркинский',
#  'Шахтер',
#  'Шахтерская',
#  'Шахтовая',
#  'Шахтовый',
#  'Швартовая',
#  'Шевелева',
#  'Шевченко',
#  'Шевченко',
#  'Шелковичная',
#  'Шепеткова',
#  'Шестая',
#  'Шилкинская',
#  'Широкая',
#  'Широколиственная',
#  'Шишкина',
#  'Шкипера Гека',
#  'Школьный',
#  'Шкотовская',
#  'Шкотовский',
#  'Шостаковича',
#  'Шошина',
#  'Штилевая',
#  'Штормовая',
#  'Шуйская',
#  'Щедрина',
#  'Щитовая',
#  'Щорса',
#  'Экипажная',
#  'Энергетик',
#  'Юбилей',
#  'Юбилейное',
#  'Юбилейное-2',
#  'Южно-Уральская',
#  'Яблоневая',
#  'Яблочкова',
#  'Ягодная',
#  'Яковлевский',
#  'Якорная бухта',
#  'Якутская',
#  'Ялтинская',
#  'Янковского',
#  'Ярославская',
#  'Ярошенко',
#  'Ясеневая',
#  'Ясная',
#  'Ясный',
#  'Яхтовая',
#  ...]

# %%
#Сохраняем в Excel
writer = pd.ExcelWriter('База_ГИС_ЖКХ_streets_2.xlsx')
pd.DataFrame(street_1).to_excel(writer, 'street')
writer.save()
# Out:
# C:\Users\skapr\AppData\Local\Temp\ipykernel_2948\3177908438.py:4: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
#Подгружаем улицы
df_str = pd.read_excel('D:\Стас\Ученье - Свет\Оценка\Аспирантура\Видео по NN, Data mining, ABC и т.д\Распределение Гаусса, регрессия\Python\!Наработки\Квартиры_Владивосток\ГИС ЖКХ/База_ГИС_ЖКХ_streets.xlsx', sheet_name = 1)
df_str
# Out:
#          Улицы_yes_ж
# 0       10-я Рабочая
# 1      1-я Восточная
# 2      1-я Встречная
# 3    1-я Гражданская
# 4         1-я Дачная
# ..               ...
# 437       Янковского
# 438      Ярославская
# 439         Ясеневая
# 440            Ясный
# 441          Яхтовая
#
# [442 rows x 1 columns]

# %%
len(df_str['Улицы_yes_ж'])
# Out:
# 442

# %%
#Парсинг через улицы
#ВАРИАНТ №1 - не сработал
a = 0
street_no = [] #улицы которые не прошли и они пустые
street_big_100 = [] #улицы которые больше 100 домов
street_all_count = [] #количество домов по каждой улице
street_yes_no = [] #улицы которые не прошли и они не пустые

for stre in tqdm(range(0, len(df_str['Улицы_2']), 1), 'Сбор данных'):
    soup = BeautifulSoup(driver.page_source, 'lxml')
    a = a + 1
    try:
        #print(df['Улицы_2'][stre])
        try:
            driver.find_element(By.XPATH, '//*[@id="s2id_streetpa1"]/a').click() #находим выпадающий список Улица
            input_3 = driver.find_element(By.XPATH, '//*[@id="s2id_autogen16_search"]') #находим input
            input_3.send_keys(df_str['Улицы_2'][stre]) #вносим в ячейку улицу
            sleep(2) #спим 2 секунды
            input_3.send_keys(Keys.ENTER) #жмем Enter
        except:
            #input_3.send_keys(Keys.ENTER) #жмем Enter
            winsound.Beep(2000, 3000) #громкий звук в 3 секунд
            sleep(60)       

        button = driver.find_element(By.XPATH, '/html/body/div[1]/div[8]/div/div[2]/houses-search-form/div[2]/div/ef-bp-form/div/form/div[3]/div/div[2]/button') #находим элемент кнопки Еще
        button.send_keys(Keys.ENTER) #нажимаем кнопку Найти
        sleep(6) #спим 6 секунд
        
        soup = BeautifulSoup(driver.page_source, 'lxml')
        
        #СОХРАНИМ УЛИЦЫ КОТОРЫХ БОЛЬШЕ 100
        try:
            N = int(soup.find('b', class_ = 'ng-binding').text) #количество объектов
            street_all_count.append(N)
            if N > 100:
                street_big_100.append(df_str['Улицы_2'][stre])
        except:
            continue
        
        #АДРЕС
        address = driver.find_elements(By.CLASS_NAME, "register-card__header-title")

        #СОСТОЯНИЕ
        sost = soup.findAll('td', class_ = 'col-xs-6')

        sosts = []
        sosts_2 = []

        #for i, s in enumerate(sost):
        for s in sost:
            try:
                sosts.append(s.find('span', class_ = 'ng-binding').text.strip())
            except:
                continue

        i = 0
        for s in sosts:
            if i % 3 == 0:
                sosts_2.append(s)
            i = i + 1
        #sosts_2

        #КН, ГОД, МАТЕРИАЛ, ЭТАЖНОСТЬ + АДРЕС и СОСТОЯНИЕ
        table_2 = soup.findAll('td', class_ = 'col-xs-7')

        table_s_2 = []

        i = 0
        j = 0
        for tb in table_2:
            table_s_2.append(tb.text)
            i = i + 1
            if i % 4 == 0:
                j = j + 1
                #print(j, i, address[j - 1].text)
                table_s_2.append(address[j - 1].text)
                table_s_2.append(sosts_2[j - 1])
        #table_s_2
        
        #СОБИРАЕМ В ТАБЛИЦУ
        new_array = np.reshape(table_s_2, (N, 6))
        df = pd.DataFrame(new_array, columns = ['КН', 'Год', 'Материал', 'Этажность', 'Адрес', 'Cостояние'])

        if a == 1:
            df_result = df
        if a > 1:
            df_result = pd.concat([df_result, df], axis = 0)
    
    except:
        #print('Error')
        street_no.append(df_str['Улицы_2'][stre])
        try:
            N = int(soup.find('b', class_ = 'ng-binding').text)
            if N > 0:
                street_yes_no.append(df_str['Улицы_2'][stre])
                #winsound.Beep(2000, 3000) #громкий звук в 3 секунд
                #sleep(60)
        except:
            continue
        
#Сохраняем в Excel
writer = pd.ExcelWriter('База_ГИС_ЖКХ_Многоквартирные_all.xlsx')
df_result.to_excel(writer, 'База')
writer.save()
# Out:
# Сбор данных: 100%|███████████████████████████████████████████████████████████████| 1001/1001 [2:23:04<00:00,  8.58s/it]
# C:\Users\skapr\AppData\Local\Temp\ipykernel_2948\2986323560.py:100: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
#Новый парсинг через таблички по улицам
#ВАРИАНТ №2 - сработал, итоговый
#Необходимо обязательно выставить 100 объектов на странице
#Парсить надо только те улицы, по которым есть объекты. Перед парсингом необходимо собрать улицы с объектами

street_no = [] #улицы которые не прошли и они пустые
street_big_100 = [] #улицы которые больше 100 домов
street_all_count = [] #количество домов по каждой улице
objeckt = []
#street_yes_no = [] #улицы которые не прошли и они не пустые
a = 0

for stre in tqdm(range(0, len(df_str['Улицы_yes_ж']), 1), 'Сбор данных'):
    soup = BeautifulSoup(driver.page_source, 'lxml')
    try:
        try:
            driver.find_element(By.XPATH, '//*[@id="s2id_streetpa1"]/a').click() #находим выпадающий список Улица
            input_3 = driver.find_element(By.XPATH, '//*[@id="s2id_autogen16_search"]') #находим input
            input_3.send_keys(df_str['Улицы_yes_ж'][stre]) #вносим в ячейку улицу
            sleep(2) #спим 2 секунды
            input_3.send_keys(Keys.ENTER) #жмем Enter
        except:
            #input_3.send_keys(Keys.ENTER) #жмем Enter
            winsound.Beep(2000, 3000) #громкий звук в 3 секунд
            sleep(30)       

        button = driver.find_element(By.XPATH, '/html/body/div[1]/div[8]/div/div[2]/houses-search-form/div[2]/div/ef-bp-form/div/form/div[3]/div/div[2]/button') #находим элемент кнопки Еще
        button.send_keys(Keys.ENTER) #нажимаем кнопку Найти
        sleep(6) #спим 6 секунд
        
        soup = BeautifulSoup(driver.page_source, 'lxml')

        #СОХРАНИМ УЛИЦЫ КОТОРЫХ БОЛЬШЕ 100
        N = int(soup.find('b', class_ = 'ng-binding').text) #количество объектов
        street_all_count.append(N)
#         try:
#             obj = driver.find_element(By.XPATH, '//*[@id="select2-chosen-201"]').text
#             objeckt.append(obj)
            
#             N = int(soup.find('b', class_ = 'ng-binding').text) #количество объектов
#             #street_all_count.append(N)
#             if N > 100:
#                 street_big_100.append(df_str['Улицы_yes_ж'][stre])
#         except:
#             continue

        t1 = []
        t = []
        
        #СРБИРАЕМ ТАБЛИЧКИ
        table = soup.findAll('div', class_ = 'register-card__container_multi')  #[2].findAll('td')[10].text.strip()
        address = soup.findAll('div', class_ = 'register-card__header-title')   #адрес
        err = soup.findAll('div', class_ = 'register-card__container_multi')[0] #проверка на пустой список, если пусто,
                                                                                #то будет ошибка и вылет в except
        for tb, ad in zip(table, address):                          #перебираем таблицы и адреса (они равны по количеству)
            t1.clear()                                              #очищаем список t1
            t.clear()                                               #очищаем список t
            a = a + 1                                               #счетчик

            value = tb.findAll('td')                                #вытаскиваем все тэги td

            for vl in value:
                t.append(vl.text.strip())                           #создаем текстовый список

            splits = np.array_split(t, len(value) / 2)              #разбиваем список на пары
            for array in splits:
                t1.append(list(array))                              #все пары переносим в список t1
            
            t1.append(['Адрес:', ad.text.strip()])                  #добавляем адрес к списку t1, таблица собрана

            df = pd.DataFrame(t1)                                   #переводим таблицу в df
            df = df.set_index(0)                                    #первый столбик делаем индексом для конката  

            if a == 1:                                              #в ппервый проход создаем df
                df_result = df
            if a > 1:
                df_result = pd.concat([df_result, df], axis = 1)    #потом добавляем таблички к результату
            #print(len(df_result))
    except:
        #print(N)
        street_no.append(df_str['Улицы_yes_ж'][stre])               #улицы которые не прошли, попадают в список

df_result_copy = df_result.copy()                                   #делаем копию
df_result_copy = df_result_copy.transpose()                         #транспонируем, строки становятся столбцами

#Сохраняем в Excel
writer = pd.ExcelWriter('База_ГИС_ЖКХ_Многоквартирные_жилое.xlsx')
df_result_copy.to_excel(writer, 'База')
writer.save()
# Out:
# Сбор данных: 100%|█████████████████████████████████████████████████████████████████| 442/442 [1:04:21<00:00,  8.74s/it]
# C:\Users\skapr\AppData\Local\Temp\ipykernel_6628\985473606.py:89: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
df_result_copy
# Out:
# 0   Кадастровый номер: Год ввода в эксплуатацию: Количество этажей:  \
# 1     25:28:010031:300                         -                  1
# 1   25:28:000000:17704                         -                  1
# 1     25:28:050022:695                      1956                  1
# 1     25:28:050022:735                         -                  1
# 1     25:28:050023:901                         -                  1
# ..                 ...                       ...                ...
# 1     25:28:030002:473                      1958                  1
# 1     25:28:030002:332                      1958                  2
# 1     25:28:030002:393                      1958                  1
# 1     25:28:000000:879                         -                  2
# 1    25:28:050058:1922                         -                  2
#
# 0  Дом находится всобственности субъектаРФ и…\n                                    \n\n\n                                            Дом находится в собственности субъекта Российской Федерации и в полном объеме используется в качестве общежития  \
# 1                                                 Нет
# 1                                                 Нет
# 1                                                 NaN
# 1                                                 NaN
# 1                                                 Нет
# ..                                                ...
# 1                                                 NaN
# 1                                                 NaN
# 1                                                 NaN
# 1                                                 NaN
# 1                                                 NaN
#
# 0  Дом находится вмуниципальнойсобственности и…\n                                    \n\n\n                                            Дом находится в муниципальной собственности и в полном объеме используется в качестве общежития  \
# 1                                                 Нет
# 1                                                 Нет
# 1                                                 NaN
# 1                                                 Нет
# 1                                                 Нет
# ..                                                ...
# 1                                                 NaN
# 1                                                 NaN
# 1                                                 NaN
# 1                                                 Нет
# 1                                                 Нет
#
# 0  Состояние: Управляющая организация:  \
# 1   Исправный                        -
# 1   Исправный                        -
# 1           -                        -
# 1   Исправный                        -
# 1           -                        -
# ..        ...                      ...
# 1           -                        -
# 1           -                        -
# 1           -                        -
# 1           -                        -
# 1   Исправный                        -
#
# 0                                              Адрес:
# 1   690066, край Приморский, г Владивосток, ул 10-...
# 1   690066, край Приморский, г Владивосток, ул 10-...
# 1   690054, край Приморский, г Владивосток, ул 1-я...
# 1   690054, край Приморский, г Владивосток, ул 1-я...
# 1   690054, край Приморский, г Владивосток, ул 1-я...
# ..                                                ...
# 1   690012, край Приморский, г Владивосток, ул Ясе...
# 1   690012, край Приморский, г Владивосток, ул Ясе...
# 1   690012, край Приморский, г Владивосток, ул Ясе...
# 1   690041, край Приморский, г Владивосток, пер Яс...
# 1   690024, край Приморский, г Владивосток, ул Яхт...
#
# [2124 rows x 8 columns]

# %%
np.sum(street_all_count)
# Out:
# 3736

# %%
len(street_all_count)
# Out:
# 330

# %%
#Сохраняем количество объекто по улицам
writer = pd.ExcelWriter('База_ГИС_ЖКХ_количество.xlsx')
pd.DataFrame(street_all_count).to_excel(writer, 'количество')
writer.save()
# Out:
# C:\Users\skapr\AppData\Local\Temp\ipykernel_10060\1899113572.py:3: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
street_big_100
# Out:
# ['100-летия Владивостока', 'Восток', 'Русская']

# %%
len(street_no)
street_no
# Out:
# ['10-я Рабочая',
#  '13-я Рабочая',
#  '1-я Восточная',
#  '1-я Встречная',
#  '1-я Гражданская',
#  '1-я Заречная',
#  '1-я Крутая',
#  '1-я Лесная',
#  '1-я Линейная',
#  '1-я Пригородная',
#  '1-я Проходная',
#  '1-я Северная',
#  '1-я Центральная',
#  '1-я Шоссейная',
#  '20 лет ВЛКСМ',
#  '2-я Водопроводная',
#  '2-я Восточная',
#  '2-я Гражданская',
#  '2-я Крутая',
#  '2-я Лесная',
#  '2-я Пригородная',
#  '2-я Центральная',
#  '2-я Южная',
#  '3-ий Ключ',
#  '3-й Восточный',
#  '3-я Восточная',
#  '3-я Встречная',
#  '3-я Гарнизонная',
#  '3-я Круговая',
#  '3-я Крутая',
#  '3-я Лесная',
#  '3-я Линейная',
#  '3-я Матросская',
#  '3-я Пригородная',
#  '3-я Проходная',
#  '3-я Северная',
#  '3-я Центральная',
#  '3-я Шоссейная',
#  '3-я Южная',
#  '4-ый Ключ',
#  '4-я Круговая',
#  '4-я Матросская',
#  '4-я Пригородная',
#  '4-я Террасная',
#  '4-я Флотская',
#  '4-я Центральная',
#  '5-ый Ключ',
#  '5-я Восточная',
#  '5-я Проходная',
#  '5-я Террасная',
#  '5-я Центральная',
#  '60 лет ВЛКСМ',
#  '6-я Восточная',
#  '6-я Матросская',
#  '9-я Рабочая',
#  'Абрикосовая',
#  'Абрикосовый',
#  'Авангард',
#  'Августовского',
#  'Адмирала Макарова',
#  'Адмирала Макарова',
#  'Азовская',
#  'Аирная',
#  'Аистовая',
#  'Айвазовского',
#  'Академика Воронова',
#  'Академика Комарова',
#  'Академика Крушанова',
#  'Аквамариновая',
#  'Акимушкина',
#  'Александра Грина',
#  'Альбатросовая',
#  'Алябьева',
#  'Амадиновая',
#  'Амарантовая',
#  'Американская',
#  'Аметистовая',
#  'Амундсена',
#  'Аникушина',
#  'Анисовая',
#  'Анучинская',
#  'Анютинская',
#  'Апухтина',
#  'Аральская',
#  'Аренского',
#  'Арктическая',
#  'Арсенальная',
#  'Артёмовская',
#  'Астрономический',
#  'Байдукова',
#  'Байкальская',
#  'Бакинская',
#  'Бакунина',
#  'Балакирева',
#  'Балкерная',
#  'Балтийская',
#  'Балтовская',
#  'Баневура',
#  'Баратынского',
#  'Барбарисовая',
#  'Барбетная',
#  'Баркасная',
#  'Барклая',
#  'Барсовая',
#  'Бархатная',
#  'Бассейновая',
#  'Батумская',
#  'Бежецкая',
#  'Беломорская',
#  'Белякова',
#  'Беринга',
#  'Беркутовая',
#  'Бетховена',
#  'Бианки',
#  'Бийская',
#  'Биологический',
#  'Большекаменская',
#  'Босфора',
#  'Боярышниковая',
#  'Братская',
#  'Брестская',
#  'Брестский',
#  'Бринера',
#  'Брюсова',
#  'Буковая',
#  'Буксирная',
#  'Бульварная',
#  'Буреинская',
#  'Буссе',
#  'Буферная',
#  'Бухта Лазурная',
#  'Бянкина',
#  'Васильковая',
#  'Васнецова',
#  'Буреинская',
#  'Буссе',
#  'Буферная',
#  'Бухта Лазурная',
#  'Бянкина',
#  'Васильковая',
#  'Васнецова',
#  'Венюкова',
#  'Вербное',
#  'Вересковая',
#  'Верещагина',
#  'Верещагина',
#  'Вертинского',
#  'Вертолетная',
#  'Верхнеславянская',
#  'Верхняя',
#  'Весенняя',
#  'Весна',
#  'Ветвистая',
#  'Ветеранов',
#  'Ветеран революции',
#  'Ветреная',
#  'Взлетная',
#  'Визбора',
#  'Виноградная',
#  'Виноградный',
#  'ВИР',
#  'Вировец',
#  'Виттенбурга',
#  'Вишневая',
#  'Водник',
#  'Водолазная',
#  'Вознесенская',
#  'Вокзальная',
#  'Волгоградская',
#  'Волжская',
#  'Волна',
#  'Волнистая',
#  'Волочаевская',
#  'Воробьиная',
#  'Воронежская',
#  'Восток-2',
#  'Восточный',
#  'Вострецова',
#  'Восьмая',
#  'Врубеля',
#  'Выселковая',
#  'Высокая',
#  'Высотная',
#  'Гаршина',
#  'Гассе',
#  'Гастелло',
#  'Гвардейская',
#  'Географический',
#  'Героев-Даманцев',
#  'Герцена',
#  'Главный',
#  'Глазунова',
#  'Голицына',
#  'Голубичная',
#  'Горицветная',
#  'Горького',
#  'Гражданская',
#  'Гранит',
#  'Грекова',
#  'Грозовая',
#  'Грушевая',
#  'Гусарский',
#  'Гуфсин',
#  'Дальнегорская',
#  'Дачный',
#  'Двинская',
#  'Девятая',
#  'Дежнева',
#  'Демьяна Бедного',
#  'Деревенская',
#  'Дерюгина',
#  'Десятая',
#  'Джамбула',
#  'Дивная',
#  'Дмитриева',
#  'Добролюбова',
#  'Дозорный',
#  'Докучаева',
#  'Донская',
#  'Дорожный',
#  'Достоевского',
#  'Дружба',
#  'Дружная',
#  'Дубовая',
#  'Дубравная',
#  'Духовского',
#  'ДЭПСС',
#  'Ежевичная',
#  'Елецкая',
#  'Ёлочная',
#  'Жариковская',
#  'Железнодорожная',
#  'Железнодорожный',
#  'Живительный',
#  'Жуковского',
#  'Журавлиная',
#  'Загородная',
#  'Запорожский',
#  'Заречная',
#  'Звёздная',
#  'Звонкий',
#  'Зеленый',
#  'Зеленый Угол',
#  'Земляничная',
#  'Золотистый',
#  'Зябликовая',
#  'Ивовая',
#  'Иволговая',
#  'Извилистая',
#  'Изюбриевая',
#  'Ильменская',
#  'Иманская',
#  'Инженерная',
#  'Ирисовая',
#  'Иркутская',
#  'Иртышский',
#  'Искра',
#  'Исторический',
#  'Ишимская',
#  'Кавалеровский',
#  'Казакевича',
#  'Калининградская',
#  'Калиновая',
#  'Каляева',
#  'Канатный',
#  'Канская',
#  'Капитана Орликовой',
#  'Капонирная',
#  'Карамзина',
#  'Карпинского',
#  'Карская',
#  'Карьерный',
#  'Каспийская',
#  'Каспийский',
#  'Квартальный',
#  'Кедровый',
#  'Кемеровская',
#  'Кизиловая',
#  'Килевой',
#  'Кирочный',
#  'Китовый',
#  'Клавдии Шульженко',
#  'Клевера',
#  'Клен(ДМСС)',
#  'Клинская',
#  'Клыкова',
#  'Командорская',
#  'Кооператор',
#  'Корабельная Набережная',
#  'Корабельный',
#  'Короленко',
#  'Короткая',
#  'Кочубея',
#  'Кочубея',
#  'Крамского',
#  'Красноармейский',
#  'Краснодонская',
#  'Краснозаводская',
#  'Крылатый',
#  'Крылова',
#  'Крымская',
#  'Кубанская',
#  'Кузбасская',
#  'Куинджи',
#  'Куйбышева',
#  'Курильская',
#  'Курортная',
#  'Курчатова',
#  'Кустарный',
#  'Лаврова',
#  'Ладожская',
#  'Лазовская',
#  'Лазуритовый',
#  'Лазурная',
#  'Ландыш',
#  'Ландышевая',
#  'Ланинский',
#  'Лаптева',
#  'Ласточка',
#  'Ласточкина',
#  'Левитана',
#  'Левобережная',
#  'Лейтенанта Шмидта',
#  'Ленский',
#  'Лепестковая',
#  'Лескова',
#  'Лесная',
#  'Лесное',
#  'Лесной',
#  'Лесопитомник',
#  'Лиман',
#  'Лиственничная',
#  'Листопадная',
#  'Литовская',
#  'Ломаная',
#  'Ломоносова',
#  'Лоскутова',
#  'Лоцманская',
#  'Лукина',
#  'Лукоморье',
#  'Лунная',
#  'Лучезарный',
#  'Лучистая',
#  'Маака',
#  'Майкова',
#  'Майская',
#  'Маковского',
#  'Маковского',
#  'Максимовича',
#  'Малика',
#  'Малиновая',
#  'Мамонтова',
#  'Маньчжурская',
#  'Маргаритова',
#  'Математический',
#  'Матросова',
#  'Маяковского',
#  'Медик',
#  'Медовая',
#  'Междугородняя',
#  'Мельниковская',
#  'Менделеева',
#  'Метельная',
#  'Мехлиса',
#  'Мечникова',
#  'Мечта',
#  'Милоградовская',
#  'Минеральная',
#  'Минная',
#  'Михайловского',
#  'Мичуринец',
#  'Мичуринский',
#  'Мопровская',
#  'Мореходная',
#  'Моряк-2',
#  'Мотыльковая',
#  'Моцарта',
#  'Мурманская',
#  'Мыс Кунгасный',
#  'Набережная',
#  'Надарова',
#  'Небесный',
#  'Нежинская',
#  'Нектарная',
#  'Неманская',
#  'Нефритовая',
#  'Низинная',
#  'Никитина',
#  'Новгородский',
#  'Новицкого',
#  'Новороссийская',
#  'Обзорная',
#  'Областная',
#  'Облачный',
#  'Облепиховая',
#  'Обручева',
#  'Объездной',
#  'Овражная',
#  'Огарева',
#  'Одесская',
#  'Одиннадцатая',
#  'Озерная',
#  'Окуджавы',
#  'Ольгинский',
#  'Опаловая',
#  'Опорная',
#  'Орбита',
#  'Орбитальная',
#  'Отрадная',
#  'Охотская',
#  'Охотский',
#  'Павленко',
#  'Паллады',
#  'Панфилова',
#  'Парашютная',
#  'Паровозная',
#  'Парусная',
#  'Пархоменко',
#  'Пархоменко',
#  'Пасечная',
#  'Патриот-6',
#  'Паустовского',
#  'Пейзажная',
#  'Пенсионер',
#  'Первая',
#  'Перепелиная',
#  'Персиковая',
#  'Петра Великого',
#  'Пилотажный',
#  'Пионер',
#  'Пионовая',
#  'Пирогова',
#  'Писаревская',
#  'Планерная',
#  'Плеханова',
#  'Плещеева',
#  'Поворотный',
#  'Подгорная',
#  'Подъемная',
#  'Пожарского',
#  'Полезный',
#  'Полетаева',
#  'Полетаева',
#  'Полины Осипенко',
#  'Попутная',
#  'Портовик',
#  'Портовик-1',
#  'Посадская',
#  'Поселковый',
#  'Потийская',
#  'Почтовая',
#  'Пояркова',
#  'Правобережная',
#  'Пржевальского',
#  'Прибрежная',
#  'Приветливая',
#  'Призовая',
#  'Приморский садовод',
#  'Причальная',
#  'Пришвина',
#  'Прокофьева',
#  'Промежуточная',
#  'Промысловая',
#  'Просторная',
#  'Проточная',
#  'Профессора Куренцова',
#  'Пугачева',
#  'Пятая',
#  'Радарный',
#  'Радио',
#  'Радио',
#  'Радостная',
#  'Радужная',
#  'Радужный',
#  'Раевского',
#  'Раздольная',
#  'Разина',
#  'Ракетная',
#  'Ракитная',
#  'Рассветная',
#  'Расула Гамзатова',
#  'Рахманинова',
#  'Режицкая',
#  'Рейдовая',
#  'Репина',
#  'Республики',
#  'Речная',
#  'Решетникова',
#  'Рионская',
#  'Роберта Баха',
#  'Ровная',
#  'Родниковый',
#  'Розовая',
#  'Розовый',
#  'Рокадная',
#  'Рокотова',
#  'Романтиков',
#  'Ромашковая',
#  'Рубиновая',
#  'Рубинштейна',
#  'Рулевой',
#  'Русанова',
#  'Ручейный',
#  'Рыбацкий',
#  'Рыбинская',
#  'Рыбники',
#  'Рюриковская',
#  'Ряжская',
#  'Саврасова',
#  'Садгород',
#  'Садовый',
#  'Садовый тупик',
#  'Салтыкова',
#  'Самаргинская',
#  'Саперная',
#  'Сапфировая',
#  'Саульского',
#  'Свет',
#  'Светланский',
#  'Свободная',
#  'Севская',
#  'Седьмая',
#  'Селенгинская',
#  'Серебряный ключ',
#  'Сеульская',
#  'Сибирская',
#  'Сигнальная',
#  'Симбирская',
#  'Синичкина',
#  'Сиреневая',
#  'Скатная',
#  'Скатный',
#  'Скворцовая',
#  'Скрябина',
#  'Славянская',
#  'Сладкова',
#  'Сливовая',
#  'Случевского',
#  'Смоленская',
#  'Снегирева',
#  'Соколиный',
#  'Сокольничий',
#  'Солнечная',
#  'Солнечное',
#  'Соловьиная',
#  'Сопочная',
#  'Сосновая',
#  'Спасательная',
#  'Спокойная',
#  'Спутник',
#  'Спутник-2',
#  'Стальского',
#  'Станичная',
#  'Станционная',
#  'Стравинского',
#  'Стрелковый',
#  'Стрелочная',
#  'Стрелочный',
#  'Строитель-1',
#  'Строитель(30 км)',
#  'Строитель(ГВС)',
#  'Сурикова',
#  'Сухогрузная',
#  'Счастливая',
#  'Таганрогская',
#  'Таежная',
#  'Таманская',
#  'Тамбовская',
#  'Танеева',
#  'Танкерная',
#  'Таривердиева',
#  'Тверская',
#  'Тетюхинская',
#  'Тёплая',
#  'Тинро',
#  'Тисовая',
#  'Тихвинская',
#  'Тихоокеанская',
#  'Токаревская Кошка',
#  'Токаревский Маяк',
#  'Толбухина',
#  'Томская',
#  'Траловая',
#  'Трамвайная',
#  'Трансформаторная',
#  'Тринадцатая',
#  'Труд',
#  'Тургенева',
#  'Туристическая',
#  'Туркменская',
#  'Турмалиновая',
#  'Тюльпан',
#  'Тютчева',
#  'Ужгородская',
#  'Узбекская',
#  'Уманская',
#  'Урицкого',
#  'Уссурийская',
#  'Учитель',
#  'Учительская',
#  'Уютная',
#  'Фазановая',
#  'Фанерная',
#  'Фанерный',
#  'Федеративная',
#  'Ферсмана',
#  'Фета',
#  'Фиалковая',
#  'Фигурная',
#  'Финвальный',
#  'Фортовая',
#  'Фрахтовый',
#  'Фруктовая',
#  'Ханкайская',
#  'Хасанский',
#  'Хвойная',
#  'Хивинская',
#  'Холмистая',
#  'Хорольская',
#  'Художественная',
#  'Хуторская',
#  'Цветочная',
#  'Цимлянская',
#  'Чайка',
#  'Чайковского',
#  'Чароитная',
#  'Черкавского',
#  'Черниговская',
#  'Черноморская',
#  'Чернышевского',
#  'Четырнадцатая',
#  'Чехова',
#  'Читинская',
#  'Чукотская',
#  'Чуркинский',
#  'Шахтер',
#  'Шахтерская',
#  'Шахтовая',
#  'Шахтовый',
#  'Швартовая',
#  'Шевелева',
#  'Шелковичная',
#  'Широкая',
#  'Широколиственная',
#  'Школьный',
#  'Шкотовская',
#  'Шкотовский',
#  'Шостаковича',
#  'Штилевая',
#  'Штормовая',
#  'Шуйская',
#  'Щорса',
#  'Энергетик',
#  'Юбилей',
#  'Юбилейное',
#  'Юбилейное-2',
#  'Яблочкова',
#  'Ягодная',
#  'Яковлевский',
#  'Якорная бухта',
#  'Якутская',
#  'Янковского',
#  'Ярославская',
#  'Ярошенко',
#  'Ясеневая',
#  'Ясная',
#  'Ясный',
#  'Яхтовая',
#  'Яшмовый']

# %%
#Сохраняем улицы, которые с 0 объектов
writer = pd.ExcelWriter('База_ГИС_ЖКХ_улицы_no.xlsx')
pd.DataFrame(street_no).to_excel(writer, 'улицы_no')
writer.save()
# Out:
# C:\Users\skapr\AppData\Local\Temp\ipykernel_10060\540554558.py:3: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
#Ручной сбрщик по ВАРИАНТУ №2
soup = BeautifulSoup(driver.page_source, 'lxml')
t1 = []
t = []
a = 540  #необходимо постоянно менять на актуальное значение

#СРБИРАЕМ ТАБЛИЧКИ
table = soup.findAll('div', class_ = 'register-card__container_multi') #[2].findAll('td')[10].text.strip()
address = soup.findAll('div', class_ = 'register-card__header-title')  #адрес

for tb, ad in zip(table, address):
    t1.clear()
    t.clear()
    a = a + 1 #счетчик

    value = tb.findAll('td') #[17].text.strip()

    for vl in value:
        t.append(vl.text.strip())

    splits = np.array_split(t, len(value) / 2)
    for array in splits:
        t1.append(list(array))

    t1.append(['Адрес:', ad.text.strip()]) #добавляем адрес

    df = pd.DataFrame(t1)
    df = df.set_index(0)    

    if a == 1:
        df_result = df
    if a > 1:
        df_result = pd.concat([df_result, df], axis = 1)

df_result
# Out:
#                                                                                                     1  \
# 0
# Кадастровый номер:                                                                   25:28:050059:565
# Год ввода в эксплуатацию:                                                                        1949
# Количество этажей:                                                                                  1
# Состояние:                                                                                          -
# Управляющая организация:                                                                            -
# Адрес:                                              690024, край Приморский, г Владивосток, ул Апу...
# Дом находится всобственности субъектаРФ и…\n   ...                                                NaN
# Дом находится вмуниципальнойсобственности и…\n ...                                                NaN
#
#                                                                                                     1  \
# 0
# Кадастровый номер:                                                                   25:28:050059:637
# Год ввода в эксплуатацию:                                                                        1904
# Количество этажей:                                                                                  1
# Состояние:                                                                                          -
# Управляющая организация:                                                                            -
# Адрес:                                              690024, край Приморский, г Владивосток, ул Апу...
# Дом находится всобственности субъектаРФ и…\n   ...                                                NaN
# Дом находится вмуниципальнойсобственности и…\n ...                                                NaN
#
#                                                                                                     1  \
# 0
# Кадастровый номер:                                                
# Дом находится вмуниципальнойсобственности и…\n ...                                                Нет
#
#                                                                                                     1  \
# 0
# Кадастровый номер:                                                                  25:28:050002:1196
# Год ввода в эксплуатацию:                                                                        1960
# Количество этажей:                                                                                  1
# Состояние:                                                                                          -
# Управляющая организация:                                                                            -
# Адрес:                                              690910, край Приморский, г Владивосток, п Труд...
# Дом находится всобственности субъектаРФ и…\n   ...                                                NaN
# Дом находится вмуниципальнойсобственности и…\n ...                                                NaN
#
#                                                                                                     1
# 0
# Кадастровый номер:                                                                 25:28:000000:23593
# Год ввода в эксплуатацию:                                                                        1964
# Количество этажей:                                                                                  1
# Состояние:                                                                                          -
# Управляющая организация:                                                                            -
# Адрес:                                              690910, край Приморский, г Владивосток, п Труд...
# Дом находится всобственности субъектаРФ и…\n   ...                                                NaN
# Дом находится вмуниципальнойсобственности и…\n ...                                                Нет
#
# [8 rows x 540 columns]

# %%
a
# Out:
# 540

# %%
df_result_copy = df_result.copy()                                   #делаем копию
df_result_copy = df_result_copy.transpose()                         #транспонируем, строки становятся столбцами

#Сохраняем в Excel
writer = pd.ExcelWriter('База_ГИС_ЖКХ_Жилое_доп.xlsx')
df_result_copy.to_excel(writer, 'База')
writer.save()
# Out:
# C:\Users\skapr\AppData\Local\Temp\ipykernel_6628\1564215196.py:7: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %% [markdown]
# # Проверка улиц на наличие объектов

# %%
#ВАЖНО!
#Задаем Субъект РФ
#Задаем Город
#Задаем Тип дома
#Задаем Кадастровый номер - 25: (начало КН). Это позволит спарсить дома, по которым есть КН и скорее всего ГП (для Жилое)
#Для парсинга необходимо использовать ВАРИАНТ №2
#Необходимо обязательно выставить 100 объектов на странице
#Парсить надо только те улицы, по которым есть объекты. Перед парсингом необходимо собрать улицы с объектами
#Задержка по времени должна быть не менее 8 секунд, иначе кнопка Найти перестает работать.
#Чтобы спарсить все данные необходимо скачать всю базу с ГИС ЖКХ, отобрать улицы, сравнить их с нашими и допарсить те
#улицы, которые не прошли из-за дублирования, например, пер. 3-й Восточный и пр-кт. Восточный!!!
#Также, о. Русский, о. Попова, Трудовое - надо парсить отдельно во Владивостоке, так как это отдельные нп.

#Жилые, Владивосток, КН - 25:, общее количество 2679

# %%
#Подгружаем улицы
df_str = pd.read_excel('D:\Стас\Ученье - Свет\Оценка\Аспирантура\Видео по NN, Data mining, ABC и т.д\Распределение Гаусса, регрессия\Python\!Наработки\Квартиры_Владивосток\ГИС ЖКХ/База_ГИС_ЖКХ_streets.xlsx', sheet_name = 2)
df_str
# Out:
#       Unnamed: 0                        Улицы_1                 Улицы_2  \
# 0              0  пр-кт. 100-летия Владивостока  100-летия Владивостока
# 1              1               ул. 10-я Рабочая            10-я Рабочая
# 2              2               ул. 13-я Рабочая            13-я Рабочая
# 3              3              ул. 1-я Восточная           1-я Восточная
# 4              4              ул. 1-я Встречная           1-я Встречная
# ...          ...                            ...                     ...
# 996          996                   ул. Ясеневая                Ясеневая
# 997          997                      ул. Ясная                   Ясная
# 998          998                     пер. Ясный                   Ясный
# 999          999                    ул. Яхтовая                 Яхтовая
# 1000        1000                   пер. Яшмовый                 Яшмовый
#
#       Количество       Улицы_no
# 0            121            NaN
# 1              0   10-я Рабочая
# 2              0   13-я Рабочая
# 3              0  1-я Восточная
# 4              0  1-я Встречная
# ...          ...            ...
# 996            0       Ясеневая
# 997            0          Ясная
# 998            0          Ясный
# 999            0        Яхтовая
# 1000           0        Яшмовый
#
# [1001 rows x 5 columns]

# %%
street_no = [] #улицы которые не прошли и они пустые
street_big_100 = [] #улицы которые больше 100 домов
street_all_count = [] #количество домов по каждой улице

for stre in tqdm(range(0, len(df_str['Улицы_2']), 1), 'Сбор данных'):
    soup = BeautifulSoup(driver.page_source, 'lxml')
    try:
        try:
            driver.find_element(By.XPATH, '//*[@id="s2id_streetpa1"]/a').click() #находим выпадающий список Улица
            input_3 = driver.find_element(By.XPATH, '//*[@id="s2id_autogen16_search"]') #находим input
            input_3.send_keys(df_str['Улицы_2'][stre]) #вносим в ячейку улицу
            sleep(2) #спим 2 секунды
            input_3.send_keys(Keys.ENTER) #жмем Enter
        except:
            #input_3.send_keys(Keys.ENTER) #жмем Enter
            winsound.Beep(2000, 3000) #громкий звук в 3 секунд
            sleep(30)       

        button = driver.find_element(By.XPATH, '/html/body/div[1]/div[8]/div/div[2]/houses-search-form/div[2]/div/ef-bp-form/div/form/div[3]/div/div[2]/button') #находим элемент кнопки Еще
        button.send_keys(Keys.ENTER) #нажимаем кнопку Найти
        sleep(6) #спим 6 секунд
        
        soup = BeautifulSoup(driver.page_source, 'lxml')
        N = int(soup.find('b', class_ = 'ng-binding').text) #количество объектов
        print(N)
        street_all_count.append(N)
        
        if N > 100:
            street_big_100.append(df_str['Улицы_2'][stre])

    except:
        #print(N)
        street_no.append(df_str['Улицы_2'][stre])                   #улицы которые не прошли, попадают в список
# Out:
# Сбор данных:   0%|                                                                  | 1/1001 [00:09<2:31:13,  9.07s/it]
# 0
# Сбор данных:   0%|▏                                                                 | 2/1001 [00:17<2:25:35,  8.74s/it]
# 2
# Сбор данных:   0%|▏                                                                 | 3/1001 [00:26<2:23:47,  8.64s/it]
# 0
# Сбор данных:   0%|▎                                                                 | 4/1001 [00:34<2:22:42,  8.59s/it]
# 4
# Сбор данных:   0%|▎                                                                 | 5/1001 [00:43<2:23:20,  8.64s/it]
# 4
# Сбор данных:   1%|▍                                                                 | 6/1001 [01:23<5:22:28, 19.45s/it]
# 4
# Сбор данных:   1%|▍                                                                 | 7/1001 [01:32<4:23:27, 15.90s/it]
# 26
# Сбор данных:   1%|▌                                                                 | 8/1001 [01:40<3:44:47, 13.58s/it]
# 0
# Сбор данных:   1%|▌                                                                 | 9/1001 [01:49<3:18:18, 11.99s/it]
# 0
# Сбор данных:   1%|▋                                                                | 10/1001 [01:58<3:00:34, 10.93s/it]
# 0
# Сбор данных:   1%|▋                                                                | 11/1001 [02:06<2:48:07, 10.19s/it]
# 2
# Сбор данных:   1%|▊                                                                | 12/1001 [02:15<2:40:42,  9.75s/it]
# 3
# Сбор данных: 100%|██████████████████████████████████████████████████████████████▉| 1000/1001 [2:23:58<00:08,  8.54s/it]
# 1
# Сбор данных: 100%|███████████████████████████████████████████████████████████████| 1001/1001 [2:24:07<00:00,  8.64s/it]
# 0

# %%
len(street_all_count)
# Out:
# 1001

# %%
#Сохраняем в Excel
writer = pd.ExcelWriter('База_ГИС_ЖКХ_count_ж.xlsx')
pd.DataFrame(street_all_count).to_excel(writer, 'count')
writer.save()
# Out:
# C:\Users\skapr\AppData\Local\Temp\ipykernel_10060\2415253060.py:4: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
street_no
# Out:
# []

# %%
street_big_100
# Out:
# []

# %% [markdown]
# # Прочее

# %%
#Сохраняем в Excel
writer = pd.ExcelWriter('База_ГИС_ЖКХ_Многоквартирные_all.xlsx')
df_result.to_excel(writer, 'База')
writer.save()
# Out:
# C:\Users\skapr\AppData\Local\Temp\ipykernel_2948\3522614385.py:4: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')
N = int(soup.find('b', class_ = 'ng-binding').text)
N
# Out:
# 0

# %%
#СОСТОЯНИЕ
soup = BeautifulSoup(driver.page_source, 'lxml')
sost = soup.findAll('td', class_ = 'col-xs-6')

sosts = []
sosts_2 = []

#for i, s in enumerate(sost):
for s in sost:
    try:
        sosts.append(s.find('span', class_ = 'ng-binding').text.strip())
    except:
        continue

i = 0
for s in sosts:
    if i % 3 == 0:
        sosts_2.append(s)
    i = i + 1
sosts_2
# Out:
# ['Исправный',
#  'Аварийный',
#  'Исправный',
#  'Исправный',
#  'Исправный',
#  'Исправный',
#  'Исправный',
#  'Исправный',
#  'Исправный']

# %%
#Парсить по страницам не получится, так как ГИС дает увидеть и спарсить только первые 20 страниц 
a = 0
pages = 40

for p in tqdm(range(1, pages + 1, 1), 'Сбор данных'):
    
    soup = BeautifulSoup(driver.page_source, 'lxml')
    a = a + 1
    
    #АДРЕС
    address = driver.find_elements(By.CLASS_NAME, "register-card__header-title")
    #address[0].text

    #СОСТОЯНИЕ
    sost = soup.findAll('td', class_ = 'col-xs-6')

    sosts = []
    sosts_2 = []

    #for i, s in enumerate(sost):
    for s in sost:
        try:
            sosts.append(s.find('span', class_ = 'ng-binding').text.strip())
        except:
            continue

    i = 0
    for s in sosts:
        if i % 3 == 0:
            sosts_2.append(s)
        i = i + 1
    #sosts_2

    #КН, ГОД, МАТЕРИАЛ, ЭТАЖНОСТЬ + АДРЕС и СОСТОЯНИЕ
    table_2 = soup.findAll('td', class_ = 'col-xs-7')

    table_s_2 = []

    i = 0
    j = 0
    for tb in table_2:
        table_s_2.append(tb.text)
        i = i + 1
        if i % 4 == 0:
            j = j + 1
            #print(j, i, address[j - 1].text)
            table_s_2.append(address[j - 1].text)
            table_s_2.append(sosts_2[j - 1])
    #table_s_2
    
    #СОБИРАЕМ В ТАБЛИЦУ
    new_array = np.reshape(table_s_2, (100, 6))
    df = pd.DataFrame(new_array, columns = ['КН', 'Год', 'Материал', 'Этажность', 'Адрес', 'Cостояние'])

    if a == 1:
        df_result = df
    if a > 1:
        df_result = pd.concat([df_result, df], axis = 0)
    
    driver.execute_script("window.scrollBy(0,document.body.scrollHeight)") #прокрутка в самый низ
    sleep(1)
    button_2 = driver.find_element(By.XPATH, '/html/body/div[1]/div[8]/div/houses-search-result/div/div[4]/div/div[1]/div/ul[3]/li[2]/a') #переключение страниц
    button_2.send_keys(Keys.ENTER) #жмем Enter
    sleep(5)
# Out:
# Сбор данных:  12%|████████▊                                                             | 5/40 [00:43<05:04,  8.70s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [226], in <cell line: 4>()
#      47         table_s_2.append(sosts_2[j - 1])
#      48 #table_s_2
#      49
#      50 #СОБИРАЕМ В ТАБЛИЦУ
# ---> 51 new_array = np.reshape(table_s_2, (100, 6))
#      52 df = pd.DataFrame(new_array, columns = ['КН', 'Год', 'Материал', 'Этажность', 'Адрес', 'Cостояние'])
#      54 if a == 1:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\fromnumeric.py:285, in reshape(a, newshape, order)
#     200 @array_function_dispatch(_reshape_dispatcher)
#     201 def reshape(a, newshape, order='C'):
#     202     """
#     203     Gives a new shape to an array without changing its data.
#     204
#    (...)
#     283            [5, 6]])
#     284     """
# --> 285     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\fromnumeric.py:56, in _wrapfunc(obj, method, *args, **kwds)
#      54 bound = getattr(obj, method, None)
#      55 if bound is None:
# ---> 56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
#      59     return bound(*args, **kwds)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\fromnumeric.py:45, in _wrapit(obj, method, *args, **kwds)
#      43 except AttributeError:
#      44     wrap = None
# ---> 45 result = getattr(asarray(obj), method)(*args, **kwds)
#      46 if wrap:
#      47     if not isinstance(result, mu.ndarray):
#
# ValueError: cannot reshape array of size 601 into shape (100,6)

# %% [markdown]
# # Ручник

# %%
soup = BeautifulSoup(driver.page_source, 'lxml')
a = a + 1

#АДРЕС
address = driver.find_elements(By.CLASS_NAME, "register-card__header-title")
#address[0].text

#СОСТОЯНИЕ
sost = soup.findAll('td', class_ = 'col-xs-6')

sosts = []
sosts_2 = []

#for i, s in enumerate(sost):
for s in sost:
    try:
        sosts.append(s.find('span', class_ = 'ng-binding').text.strip())
    except:
        continue

i = 0
for s in sosts:
    if i % 3 == 0:
        sosts_2.append(s)
    i = i + 1
#sosts_2

#КН, ГОД, МАТЕРИАЛ, ЭТАЖНОСТЬ + АДРЕС и СОСТОЯНИЕ
table_2 = soup.findAll('td', class_ = 'col-xs-7')

table_s_2 = []

i = 0
j = 0
for tb in table_2:
    table_s_2.append(tb.text)
    i = i + 1
    if i % 4 == 0:
        j = j + 1
        #print(j, i, address[j - 1].text)
        table_s_2.append(address[j - 1].text)
        table_s_2.append(sosts_2[j - 1])
#table_s_2

#СОБИРАЕМ В ТАБЛИЦУ
new_array = np.reshape(table_s_2, (100, 6))
df = pd.DataFrame(new_array, columns = ['КН', 'Год', 'Материал', 'Этажность', 'Адрес', 'Cостояние'])

# %%
df
# Out:
#                     КН   Год               Материал Этажность  \
# 0     25:28:030014:317  1939                      -         2
# 1     25:28:030014:318  1930           не определен         2
# 2    25:28:030014:4986  2021  индивидуальный проект        25
# 3    25:28:030014:5274  2021  индивидуальный проект        25
# 4    25:28:000000:8599  2012                      -         8
# ..                 ...   ...                    ...       ...
# 95  25:28:030018:16447  2008                     83        11
# 96  25:28:000000:12001  1961   отсут в тех.паспорт.         5
# 97    25:28:030018:571  1966               1-515/5М         5
# 98    25:28:030018:794  1958           не определен         2
# 99    25:28:030018:531  1958           шлакоблочный         3
#
#                                                 Адрес  Cостояние
# 0   690042, край Приморский, г Владивосток, ул Бас...  Исправный
# 1   690042, край Приморский, г Владивосток, ул Бас...  Исправный
# 2   690042, край Приморский, г Владивосток, ул Бас...  Исправный
# 3   690042, край Приморский, г Владивосток, ул Бас...  Исправный
# 4   690042, край Приморский, г Владивосток, ул Бас...  Исправный
# ..                                                ...        ...
# 95  690080, край Приморский, г Владивосток, ул Сах...  Исправный
# 96  690080, край Приморский, г Владивосток, ул Сах...  Исправный
# 97  690080, край Приморский, г Владивосток, ул Сах...  Исправный
# 98  690080, край Приморский, г Владивосток, ул Сах...  Исправный
# 99  690080, край Приморский, г Владивосток, ул Сах...  Исправный
#
# [100 rows x 6 columns]

# %%
#Сохраняем в Excel
writer = pd.ExcelWriter('База_ГИС_ЖКХ_Многоквартирные_20.xlsx')
df.to_excel(writer, 'marks')
writer.save()
# Out:
# C:\Users\skapr\AppData\Local\Temp\ipykernel_2948\3213230758.py:4: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
table_s_2
# Out:
# ['25:28:010042:160',
#  '1985',
#  'Панельный',
#  '5',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 37',
#  'Исправный',
#  '25:28:010036:252',
#  '1987',
#  'Панельный',
#  '9',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 38',
#  'Исправный',
#  '25:28:010042:201',
#  '1985',
#  'Панельный',
#  '12',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 39',
#  'Исправный',
#  '25:28:010042:151',
#  '1985',
#  'Панельный',
#  '5',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 41',
#  'Исправный',
#  '25:28:010042:182',
#  '1994',
#  'Панельный',
#  '10',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 45',
#  'Исправный',
#  '25:28:010042:195',
#  '1987',
#  'Панельный',
#  '9',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 47',
#  'Исправный',
#  '25:28:010042:191',
#  '1987',
#  'Панельный',
#  '9',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 51',
#  'Исправный',
#  '25:28:010042:193',
#  '1988',
#  'Панельный',
#  '9',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 53',
#  'Исправный',
#  '25:28:010042:164',
#  '1988',
#  'Панельный',
#  '10',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 57',
#  'Исправный',
#  '25:28:010042:227',
#  '1988',
#  'Панельный',
#  '12',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 61',
#  'Исправный',
#  '25:28:010042:156',
#  '1988',
#  'Панельный',
#  '10',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 63',
#  'Исправный',
#  '25:28:010042:165',
#  '1989',
#  'Панельный',
#  '12',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 65',
#  'Исправный',
#  '25:28:010042:189',
#  '1994',
#  'Панельный',
#  '10',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 67',
#  'Исправный',
#  '25:28:010042:170',
#  '1992',
#  'Панельный',
#  '9',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 75',
#  'Исправный',
#  '25:28:010042:196',
#  '1992',
#  'Панельный',
#  '9',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 77',
#  'Исправный',
#  '25:28:010042:178',
#  '1993',
#  'Панельный',
#  '10',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 81',
#  'Исправный',
#  '-',
#  '2018',
#  '-',
#  '10',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 81А',
#  'Исправный',
#  '25:28:010042:167',
#  '1993',
#  'Панельный',
#  '10',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 83',
#  'Исправный',
#  '25:28:010042:166',
#  '1995',
#  'Панельный',
#  '11',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 85',
#  'Исправный',
#  '25:28:010042:155',
#  '1993',
#  'Панельный',
#  '10',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 87',
#  'Исправный',
#  '25:28:010043:899',
#  '2017',
#  '121',
#  '10',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 137',
#  'Исправный',
#  '25:28:010043:1110',
#  '2018',
#  '121',
#  '10',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 139',
#  'Исправный',
#  '25:28:010043:1425',
#  '2018',
#  '121',
#  '10',
#  '690109, край Приморский, г Владивосток, ул Нейбута, д. 141',
#  'Исправный',
#  '25:28:020016:93',
#  '1920',
#  '-',
#  '3',
#  '690090, край Приморский, г Владивосток, ул Пологая, д. 16',
#  'Исправный',
#  '-',
#  '1918',
#  'Кирпичный',
#  '4',
#  '690090, край Приморский, г Владивосток, ул Пологая, д. 17',
#  'Исправный',
#  '25:28:020016:94',
#  '1918',
#  '-',
#  '2',
#  '690090, край Приморский, г Владивосток, ул Пологая, д. 18',
#  'Исправный',
#  '25:28:020016:76',
#  '1940',
#  'МЖД',
#  '2',
#  '690090, край Приморский, г Владивосток, ул Пологая, д. 20',
#  'Исправный',
#  '25:28:020016:530',
#  '-',
#  '-',
#  '2',
#  '690090, край Приморский, г Владивосток, ул Пологая, д. 22',
#  '-',
#  '25:28:020016:77',
#  '1964',
#  'Кирпичный',
#  '5',
#  '690090, край Приморский, г Владивосток, ул Пологая, д. 24',
#  'Исправный',
#  '25:28:020016:69',
#  '1961',
#  'Кирпичный',
#  '5',
#  '690090, край Приморский, г Владивосток, ул Пологая, д. 28',
#  'Исправный',
#  '-',
#  '1961',
#  'Кирпичный',
#  '5',
#  '690090, край Приморский, г Владивосток, ул Пологая, д. 30',
#  'Исправный',
#  '25:28:020013:28',
#  '1957',
#  'Кирпичный',
#  '5',
#  '690090, край Приморский, г Владивосток, ул Пологая, д. 31',
#  'Исправный',
#  '25:28:020015:19',
#  '2003',
#  'индивидуальный проект',
#  '8',
#  '690091, край Приморский, г Владивосток, ул Пологая, д. 50',
#  'Исправный',
#  '-',
#  '1971',
#  'Кирпичный',
#  '9',
#  '690091, край Приморский, г Владивосток, ул Пологая, д. 53а',
#  'Исправный',
#  '25:28:010001:201',
#  '1972',
#  'Кирпичный',
#  '9',
#  '690091, край Приморский, г Владивосток, ул Пологая, д. 54А',
#  'Исправный',
#  '25:28:010001:250',
#  '1972',
#  '-',
#  '9',
#  '690091, край Приморский, г Владивосток, ул Пологая, д. 55',
#  'Исправный',
#  '25:28:010001:202',
#  '1904',
#  '-',
#  '2',
#  '690091, край Приморский, г Владивосток, ул Пологая, д. 56',
#  'Исправный',
#  '25:28:010001:251',
#  '1918',
#  '-',
#  '3',
#  '690091, край Приморский, г Владивосток, ул Пологая, д. 58',
#  'Исправный',
#  '25:28:020001:87',
#  '1964',
#  'Кирпичный',
#  '5',
#  '690091, край Приморский, г Владивосток, ул Пологая, д. 60',
#  'Исправный',
#  '25:28:010001:248',
#  '1966',
#  'Кирпичный',
#  '6',
#  '690091, край Приморский, г Владивосток, ул Пологая, д. 62',
#  'Исправный',
#  '25:28:000000:12950',
#  '1967',
#  'многоквартирный',
#  '5',
#  '690091, край Приморский, г Владивосток, ул Пологая, д. 62А',
#  'Исправный',
#  '25:28:010001:294',
#  '1971',
#  'кирпичный',
#  '11',
#  '690091, край Приморский, г Владивосток, ул Пологая, д. 63',
#  'Исправный',
#  '25:28:010001:244',
#  '1972',
#  'многоквартирный',
#  '10',
#  '690091, край Приморский, г Владивосток, ул Пологая, д. 65а',
#  'Исправный',
#  '25:28:010001:209',
#  '1971',
#  'многоквартирный',
#  '13',
#  '690091, край Приморский, г Владивосток, ул Пологая, д. 69',
#  'Исправный',
#  '25:28:010001:282',
#  '1970',
#  '-',
#  '6',
#  '690091, край Приморский, г Владивосток, ул Пологая, д. 72',
#  'Исправный',
#  '25:28:060130:29',
#  '1976',
#  '-',
#  '5',
#  '690025, край Приморский, г Владивосток, ул Зеленая, д. 1',
#  'Исправный',
#  '25:28:030009:151',
#  '1944',
#  'не определен',
#  '2',
#  '690012, край Приморский, г Владивосток, ул Полтавская, д. 11',
#  'Аварийный',
#  '25:28:030009:120',
#  '1943',
#  'не определен',
#  '2',
#  '690012, край Приморский, г Владивосток, ул Полтавская, д. 13',
#  'Исправный',
#  '25:28:030009:152',
#  '1936',
#  '-',
#  '2',
#  '690012, край Приморский, г Владивосток, ул Полтавская, д. 15',
#  'Исправный',
#  '25:28:030009:122',
#  '1943',
#  'не определен',
#  '2',
#  '690012, край Приморский, г Владивосток, ул Полтавская, д. 17',
#  'Аварийный',
#  '25:28:030009:197',
#  '1943',
#  'не определен',
#  '1',
#  '690012, край Приморский, г Владивосток, ул Полтавская, д. 21',
#  'Аварийный',
#  '25:28:030009:196',
#  '1955',
#  '-',
#  '2',
#  '690012, край Приморский, г Владивосток, ул Полтавская, д. 21А',
#  'Аварийный',
#  '-',
#  '1950',
#  '-',
#  '3',
#  '690003, край Приморский, г Владивосток, ул Нижнепортовая, д. 2',
#  'Исправный',
#  '25:28:020031:344',
#  '2031',
#  'отсктствует',
#  '7',
#  '690003, край Приморский, г Владивосток, ул Нижнепортовая, д. 6г',
#  'Исправный',
#  '25:28:020006:101',
#  '1969',
#  'Панельный',
#  '9',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 1',
#  'Исправный',
#  '25:28:040006:1026',
#  '1970',
#  'Панельный',
#  '5',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 3',
#  'Исправный',
#  '25:28:040008:562',
#  '1958',
#  'барак',
#  '2',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 4А',
#  'Исправный',
#  '25:28:040008:7816',
#  '1958',
#  'барак',
#  '2',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 4Б',
#  'Исправный',
#  '25:28:000000:66427',
#  '1917',
#  'барак',
#  '1',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 4Г',
#  'Исправный',
#  '25:28:020008:2732',
#  '1982',
#  'II-29',
#  '5',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 6',
#  'Исправный',
#  '25:28:000000:12446',
#  '1969',
#  'Панельный',
#  '9',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 7',
#  'Исправный',
#  '25:28:040008:5220',
#  '1970',
#  'Панельный',
#  '5',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 7а',
#  'Исправный',
#  '25:28:000000:12956',
#  '2006',
#  'не типовой проект',
#  '18',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 8',
#  'Исправный',
#  '25:28:000000:9457',
#  '1971',
#  'Панельный',
#  '5',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 9',
#  'Исправный',
#  '25:28:040008:5236',
#  '1978',
#  'Индивидуальный, Кирпичный',
#  '9',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 26',
#  'Исправный',
#  '25:28:000000:10223',
#  '1995',
#  'отсутствует',
#  '10',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 28',
#  'Исправный',
#  '25:28:000000:66718',
#  '1930',
#  'барак',
#  '1',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 40',
#  'Исправный',
#  '25:28:000000:10242',
#  '1937',
#  'барак',
#  '1',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 40А',
#  'Аварийный',
#  '25:28:040001:689',
#  '1937',
#  'барак',
#  '1',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 40Б',
#  'Аварийный',
#  '-',
#  '1930',
#  '-',
#  '1',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 42',
#  'Аварийный',
#  '25:28:000000:11319',
#  '1937',
#  '-',
#  '2',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 42А',
#  'Аварийный',
#  '25:28:000000:64824',
#  '1930',
#  'Отсутствуе',
#  '2',
#  '690078, край Приморский, г Владивосток, пр-кт Острякова, д. 42В',
#  'Исправный',
#  '25:28:040001:464',
#  '1967',
#  'Кирпичный',
#  '9',
#  '690002, край Приморский, г Владивосток, пр-кт Острякова, д. 44',
#  'Исправный',
#  '25:28:020002:149',
#  '1905',
#  '-',
#  '2',
#  '690078, край Приморский, г Владивосток, пр-кт Острякова, д. 49б',
#  'Исправный',
#  '25:28:020002:150',
#  '1912',
#  '-',
#  '1',
#  '690078, край Приморский, г Владивосток, пр-кт Острякова, д. 57',
#  'Исправный',
#  '25:28:030014:2513',
#  '2016',
#  '-',
#  '19',
#  '690042, край Приморский, г Владивосток, ул Сочинская, д. 1',
#  'Исправный',
#  '25:28:030014:2339',
#  '2016',
#  'Инд. проект 9044-ГП',
#  '19',
#  '690042, край Приморский, г Владивосток, ул Сочинская, д. 3',
#  'Исправный',
#  '25:28:030014:2060',
#  '2016',
#  '-',
#  '11',
#  '690042, край Приморский, г Владивосток, ул Сочинская, д. 5',
#  'Исправный',
#  '25:28:030014:2197',
#  '2016',
#  'индивидуальный проект',
#  '19',
#  '690042, край Приморский, г Владивосток, ул Сочинская, д. 7',
#  'Исправный',
#  '25:28:030014:6958',
#  '2022',
#  'отсутствует',
#  '10-11',
#  '690042, край Приморский, г Владивосток, ул Сочинская, д. 9',
#  'Исправный',
#  '25:28:030014:6820',
#  '2022',
#  'отсутствует',
#  '10-11',
#  '690042, край Приморский, г Владивосток, ул Сочинская, д. 11',
#  'Исправный',
#  '25:28:030014:2730',
#  '2017',
#  '-',
#  '15-19',
#  '690042, край Приморский, г Владивосток, ул Сочинская, д. 15',
#  'Исправный',
#  '25:28:030016:4670',
#  '2021',
#  '-',
#  '25',
#  '690016, край Приморский, г Владивосток, ул Нестерова, д. 1',
#  'Исправный',
#  '25:28:030016:264',
#  '1947',
#  'шлакоблочный',
#  '2',
#  '690016, край Приморский, г Владивосток, ул Нестерова, д. 1А',
#  'Аварийный',
#  '25:28:030016:329',
#  '1954',
#  '-',
#  '2',
#  '690016, край Приморский, г Владивосток, ул Нестерова, д. 5',
#  'Исправный',
#  '\nКвартирный\n',
#  '25:28:030016:258',
#  '1941',
#  'не определен',
#  '690016, край Приморский, г Владивосток, ул Нестерова, д. 6',
#  'Исправный',
#  '2',
#  '25:28:030016:265',
#  '1941',
#  'шлакоблочный',
#  '690016, край Приморский, г Владивосток, ул Нестерова, д. 7',
#  'Исправный',
#  '2',
#  '25:28:030016:253',
#  '1947',
#  'шлакоблочный',
#  '690016, край Приморский, г Владивосток, ул Нестерова, д. 9',
#  'Исправный',
#  '2',
#  '25:28:030016:267',
#  '1967',
#  'шлакоблочный',
#  '690016, край Приморский, г Владивосток, ул Нестерова, д. 10',
#  'Исправный',
#  '2',
#  '25:28:030016:268',
#  '1948',
#  'шлакоблочный',
#  '690016, край Приморский, г Владивосток, ул Нестерова, д. 11',
#  'Исправный',
#  '2',
#  '25:28:030016:4288',
#  '2018',
#  'панельный',
#  '690016, край Приморский, г Владивосток, ул Нестерова, д. 12',
#  'Исправный',
#  '11',
#  '25:28:050036:1885',
#  '1957',
#  '-',
#  '690041, край Приморский, г Владивосток, ул Пальчевского, д. 29',
#  'Исправный',
#  '1',
#  '25:31:010208:6255',
#  '2000',
#  'отсутствует',
#  '690078, край Приморский, г Владивосток, ул Союзная, д. 17',
#  'Исправный',
#  '10',
#  '25:28:020004:207',
#  '1997',
#  '121',
#  '690078, край Приморский, г Владивосток, ул Союзная, д. 19',
#  'Исправный',
#  '6',
#  '25:28:020004:265',
#  '1998',
#  '121',
#  '690078, край Приморский, г Владивосток, ул Союзная, д. 20',
#  'Исправный',
#  '5',
#  '25:28:020004:264',
#  '-',
#  '-',
#  '690078, край Приморский, г Владивосток, ул Союзная, д. 20а',
#  'Исправный',
#  '2',
#  '25:28:030015:427',
#  '1976',
#  'Кирпичный',
#  '690016, край Приморский, г Владивосток, ул Героев Хасана, д. 4',
#  'Исправный',
#  '10',
#  '25:28:030015:388',
#  '1976',
#  'Кирпичный',
#  '690016, край Приморский, г Владивосток, ул Героев Хасана, д. 6',
#  'Исправный',
#  '9',
#  '25:28:030015:429',
#  '1973',
#  'отсут в тех.паспорт',
#  '690016, край Приморский, г Владивосток, ул Героев Хасана, д. 10',
#  'Исправный',
#  '5',
#  '25:28:030016:269',
#  '1950',
#  'не определен',
#  '690016, край Приморский, г Владивосток, ул Героев Хасана, д. 11',
#  'Исправный',
#  '2']

# %%
sost = soup.findAll('td', class_ = 'col-xs-6')

sosts = []
sosts_2 = []

#for i, s in enumerate(sost):
for s in sost:
    try:
        sosts.append(s.find('span', class_ = 'ng-binding').text.strip())
    except:
        continue

i = 0
for s in sosts:
    if i % 3 == 0:
        sosts_2.append(s)
    i = i + 1

sosts_2
# Out:
# ['Исправный',
#  'Исправный',
#  'Исправный',
#  'Исправный',
#  'Исправный',
#  'Исправный',
#  'Исправный',
#  'Исправный',
#  'Исправный',
#  'Исправный']

# %%
table_1 = soup.findAll('td', class_ = 'col-xs-5')

table_s_1 = []

i = 0
j = 0
for tb in table_1:
    table_s_1.append(tb.text)
    i = i + 1
    if i % 4 == 0:
        #print(j, i)
        table_s_1.append('Адрес')
        table_s_1.append('Cостояние')
    
table_s_1
# Out:
# ['Кадастровый номер:',
#  'Год ввода в эксплуатацию:',
#  'Серия/Тип проекта здания:',
#  'Количество этажей:',
#  'Адрес',
#  'Cостояние',
#  'Кадастровый номер:',
#  'Год ввода в эксплуатацию:',
#  'Серия/Тип проекта здания:',
#  'Количество этажей:',
#  'Адрес',
#  'Cостояние',
#  'Кадастровый номер:',
#  'Год ввода в эксплуатацию:',
#  'Серия/Тип проекта здания:',
#  'Количество этажей:',
#  'Адрес',
#  'Cостояние',
#  'Кадастровый номер:',
#  'Год ввода в эксплуатацию:',
#  'Серия/Тип проекта здания:',
#  'Количество этажей:',
#  'Адрес',
#  'Cостояние',
#  'Кадастровый номер:',
#  'Год ввода в эксплуатацию:',
#  'Серия/Тип проекта здания:',
#  'Количество этажей:',
#  'Адрес',
#  'Cостояние',
#  'Кадастровый номер:',
#  'Год ввода в эксплуатацию:',
#  'Серия/Тип проекта здания:',
#  'Количество этажей:',
#  'Адрес',
#  'Cостояние',
#  'Кадастровый номер:',
#  'Год ввода в эксплуатацию:',
#  'Серия/Тип проекта здания:',
#  'Количество этажей:',
#  'Адрес',
#  'Cостояние',
#  'Кадастровый номер:',
#  'Год ввода в эксплуатацию:',
#  'Серия/Тип проекта здания:',
#  'Количество этажей:',
#  'Адрес',
#  'Cостояние',
#  'Кадастровый номер:',
#  'Год ввода в эксплуатацию:',
#  'Серия/Тип проекта здания:',
#  'Количество этажей:',
#  'Адрес',
#  'Cостояние',
#  'Кадастровый номер:',
#  'Год ввода в эксплуатацию:',
#  'Серия/Тип проекта здания:',
#  'Количество этажей:',
#  'Адрес',
#  'Cостояние']

# %%
table_2 = soup.findAll('td', class_ = 'col-xs-7')

table_s_2 = []

i = 0
j = 0
for tb in table_2:
    table_s_2.append(tb.text)
    i = i + 1
    if i % 4 == 0:
        j = j + 1
        #print(j, i, address[j - 1].text)
        table_s_2.append(address[j - 1].text)
        table_s_2.append(sosts_2[j - 1])
    
table_s_2
# Out:
# ['25:28:010037:6026',
#  '1985',
#  'Панельный',
#  '9',
#  '690013, край Приморский, г Владивосток, ул Невельского, д. 1',
#  'Исправный',
#  '25:28:010038:448',
#  '1985',
#  'отсутствует',
#  '9',
#  '690013, край Приморский, г Владивосток, ул Невельского, д. 2',
#  'Исправный',
#  '25:28:010038:2564',
#  '1985',
#  'отсутствует',
#  '12',
#  '690013, край Приморский, г Владивосток, ул Невельского, д. 4',
#  'Исправный',
#  '25:28:010037:7860',
#  '2022',
#  '-',
#  '23',
#  '690013, край Приморский, г Владивосток, ул Невельского, д. 5',
#  'Исправный',
#  '25:28:010038:586',
#  '1986',
#  'отсутствует',
#  '9',
#  '690013, край Приморский, г Владивосток, ул Невельского, д. 6',
#  'Исправный',
#  '25:28:010038:519',
#  '1985',
#  'отсуствует',
#  '9',
#  '690013, край Приморский, г Владивосток, ул Невельского, д. 8',
#  'Исправный',
#  '25:28:010037:183',
#  '1987',
#  'Панельный',
#  '12',
#  '690013, край Приморский, г Владивосток, ул Невельского, д. 11',
#  'Исправный',
#  '25:28:010037:247',
#  '1987',
#  'Панельный',
#  '12',
#  '690013, край Приморский, г Владивосток, ул Невельского, д. 13',
#  'Исправный',
#  '25:28:010037:6024',
#  '1986',
#  'Панельный',
#  '9',
#  '690013, край Приморский, г Владивосток, ул Невельского, д. 15',
#  'Исправный',
#  '25:28:010037:253',
#  '1985',
#  'Панельный',
#  '9',
#  '690013, край Приморский, г Владивосток, ул Невельского, д. 17',
#  'Исправный']

# %%
new_array = np.reshape(table_s_2, (10, 6))
new_array = pd.DataFrame(new_array, columns = ['КН', 'Год', 'Материал', 'Этажность', 'Адрес', 'Cостояние'])
new_array
# Out:
#                   КН   Год     Материал Этажность  \
# 0  25:28:010037:6026  1985    Панельный         9
# 1   25:28:010038:448  1985  отсутствует         9
# 2  25:28:010038:2564  1985  отсутствует        12
# 3  25:28:010037:7860  2022            -        23
# 4   25:28:010038:586  1986  отсутствует         9
# 5   25:28:010038:519  1985   отсуствует         9
# 6   25:28:010037:183  1987    Панельный        12
# 7   25:28:010037:247  1987    Панельный        12
# 8  25:28:010037:6024  1986    Панельный         9
# 9   25:28:010037:253  1985    Панельный         9
#
#                                                Адрес  Cостояние
# 0  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 1  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 2  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 3  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 4  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 5  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 6  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 7  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 8  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 9  690013, край Приморский, г Владивосток, ул Нев...  Исправный

# %%
df_result_1 = new_array.copy()
df_result_1
# Out:
#                   КН   Год     Материал Этажность  \
# 0  25:28:010037:6026  1985    Панельный         9
# 1   25:28:010038:448  1985  отсутствует         9
# 2  25:28:010038:2564  1985  отсутствует        12
# 3  25:28:010037:7860  2022            -        23
# 4   25:28:010038:586  1986  отсутствует         9
# 5   25:28:010038:519  1985   отсуствует         9
# 6   25:28:010037:183  1987    Панельный        12
# 7   25:28:010037:247  1987    Панельный        12
# 8  25:28:010037:6024  1986    Панельный         9
# 9   25:28:010037:253  1985    Панельный         9
#
#                                                Адрес  Cостояние
# 0  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 1  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 2  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 3  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 4  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 5  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 6  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 7  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 8  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 9  690013, край Приморский, г Владивосток, ул Нев...  Исправный

# %%
df_result = pd.concat([df_result_1, new_array], axis = 0)
df_result
# Out:
#                   КН   Год     Материал Этажность  \
# 0  25:28:010037:6026  1985    Панельный         9
# 1   25:28:010038:448  1985  отсутствует         9
# 2  25:28:010038:2564  1985  отсутствует        12
# 3  25:28:010037:7860  2022            -        23
# 4   25:28:010038:586  1986  отсутствует         9
# 5   25:28:010038:519  1985   отсуствует         9
# 6   25:28:010037:183  1987    Панельный        12
# 7   25:28:010037:247  1987    Панельный        12
# 8  25:28:010037:6024  1986    Панельный         9
# 9   25:28:010037:253  1985    Панельный         9
# 0  25:28:010037:6026  1985    Панельный         9
# 1   25:28:010038:448  1985  отсутствует         9
# 2  25:28:010038:2564  1985  отсутствует        12
# 3  25:28:010037:7860  2022            -        23
# 4   25:28:010038:586  1986  отсутствует         9
# 5   25:28:010038:519  1985   отсуствует         9
# 6   25:28:010037:183  1987    Панельный        12
# 7   25:28:010037:247  1987    Панельный        12
# 8  25:28:010037:6024  1986    Панельный         9
# 9   25:28:010037:253  1985    Панельный         9
#
#                                                Адрес  Cостояние
# 0  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 1  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 2  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 3  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 4  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 5  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 6  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 7  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 8  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 9  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 0  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 1  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 2  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 3  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 4  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 5  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 6  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 7  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 8  690013, край Приморский, г Владивосток, ул Нев...  Исправный
# 9  690013, край Приморский, г Владивосток, ул Нев...  Исправный

# %%
t1 = []

#Dictionary = dict(zip(table_s_1, table_s_2))
#resultList = list(map(list, Dictionary.items()))
# #t1.append(resultList)
for i in range(0, len(table_s_1), 1):
    t1.append([table_s_1[i], table_s_2[i]])

t1
# Out:
# [['Кадастровый номер:', '25:28:010037:6026'],
#  ['Год ввода в эксплуатацию:', '1985'],
#  ['Серия/Тип проекта здания:', 'Панельный'],
#  ['Количество этажей:', '9'],
#  ['Кадастровый номер:', '25:28:010038:448'],
#  ['Год ввода в эксплуатацию:', '1985'],
#  ['Серия/Тип проекта здания:', 'отсутствует'],
#  ['Количество этажей:', '9'],
#  ['Кадастровый номер:', '25:28:010038:2564'],
#  ['Год ввода в эксплуатацию:', '1985'],
#  ['Серия/Тип проекта здания:', 'отсутствует'],
#  ['Количество этажей:', '12'],
#  ['Кадастровый номер:', '25:28:010037:7860'],
#  ['Год ввода в эксплуатацию:', '2022'],
#  ['Серия/Тип проекта здания:', '-'],
#  ['Количество этажей:', '23'],
#  ['Кадастровый номер:', '25:28:010038:586'],
#  ['Год ввода в эксплуатацию:', '1986'],
#  ['Серия/Тип проекта здания:', 'отсутствует'],
#  ['Количество этажей:', '9'],
#  ['Кадастровый номер:', '25:28:010038:519'],
#  ['Год ввода в эксплуатацию:', '1985'],
#  ['Серия/Тип проекта здания:', 'отсуствует'],
#  ['Количество этажей:', '9'],
#  ['Кадастровый номер:', '25:28:010037:183'],
#  ['Год ввода в эксплуатацию:', '1987'],
#  ['Серия/Тип проекта здания:', 'Панельный'],
#  ['Количество этажей:', '12'],
#  ['Кадастровый номер:', '25:28:010037:247'],
#  ['Год ввода в эксплуатацию:', '1987'],
#  ['Серия/Тип проекта здания:', 'Панельный'],
#  ['Количество этажей:', '12'],
#  ['Кадастровый номер:', '25:28:010037:6024'],
#  ['Год ввода в эксплуатацию:', '1986'],
#  ['Серия/Тип проекта здания:', 'Панельный'],
#  ['Количество этажей:', '9'],
#  ['Кадастровый номер:', '25:28:010037:253'],
#  ['Год ввода в эксплуатацию:', '1985'],
#  ['Серия/Тип проекта здания:', 'Панельный'],
#  ['Количество этажей:', '9']]

# %% [markdown]
# # Начиная с 20 страницы json отсутствует

# %%
def get_category(page = 1):
    #копируем cURL (bash), затем вставляем в https://curlconverter.com/, получем готовый код
#     cookies = {
#     'JSESSIONID': '"Pm3SGY27QOV0I2GGB0z8TIVFTS0-K1AuWIjti72-.ppak-app-wf-ui-srv01:rest"',
#     'route_pafo-saiku': '3eed4a51ebe9ecbd752731228dd302a5',
#     'suimSessionGuid': '25c891af-6ec7-4524-9d13-8774d83d7324',
#     'route_rest': 'f814435dc3e2908dfe2bb8ec3465a5f1',
#     'route_suim': '9cec376355a82e1c2092d0f01142afd1',
#     'route_pafo-reports': 'c74cc883b187536d03cd9d27dbb214c6',
#     }

#     headers = {
#         'Accept': 'application/json; charset=utf-8',
#         'Accept-Language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
#         'Connection': 'keep-alive',
#         'Content-Type': 'application/json;charset=UTF-8',
#         # 'Cookie': 'JSESSIONID="Pm3SGY27QOV0I2GGB0z8TIVFTS0-K1AuWIjti72-.ppak-app-wf-ui-srv01:rest"; route_pafo-saiku=3eed4a51ebe9ecbd752731228dd302a5; suimSessionGuid=25c891af-6ec7-4524-9d13-8774d83d7324; route_rest=f814435dc3e2908dfe2bb8ec3465a5f1; route_suim=9cec376355a82e1c2092d0f01142afd1; route_pafo-reports=c74cc883b187536d03cd9d27dbb214c6',
#         'Origin': 'https://dom.gosuslugi.ru',
#         'Referer': 'https://dom.gosuslugi.ru/',
#         'Request-GUID': '0b6c739b-b531-4bba-896c-a8fd9bb12ba9',
#         'Sec-Fetch-Dest': 'empty',
#         'Sec-Fetch-Mode': 'cors',
#         'Sec-Fetch-Site': 'same-origin',
#         'Session-GUID': '25c891af-6ec7-4524-9d13-8774d83d7324',
#         'State-GUID': '/houses',
#         'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
#         'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
#         'sec-ch-ua-mobile': '?0',
#         'sec-ch-ua-platform': '"Windows"',
#     }

#     params = {
#         'pageIndex': str(page),
#         'elementsPerPage': '100',
#     }

#     json_data = {
#         'regionCode': '92b30014-4d52-4e2e-892d-928142b924bf',
#         'cityCode': '2763c110-cb8b-416a-9dac-ad28a55b4402',
#         'fiasHouseCodeList': None,
#         'estStatus': None,
#         'strStatus': None,
#         'calcCount': True,
#         'houseConditionRefList': [
#             '1',
#             '3',
#         ],
#         'houseTypeRefList': None,
#         'houseManagementTypeRefList': None,
#         'cadastreNumber': None,
#         'oktmo': None,
#         'statuses': [
#             'APPROVED',
#         ],
#         'regionProperty': None,
#         'municipalProperty': None,
#         'hostelTypeCodes': None,
#     }

#     response = requests.post(
#         'https://dom.gosuslugi.ru/homemanagement/api/rest/services/houses/public/searchByAddress',
#         params=params,
#         cookies=cookies,
#         headers=headers,
#         json=json_data,
#     )
    
    
    cookies = {
    'JSESSIONID': '"4KPTdMtSMvRytzOgHUjWR9ZtJp6h118SezPRIcEy.ppak-app-wf-ui-srv06:rest"',
    '_ym_uid': '1713711641264140247',
    '_ym_d': '1713711641',
    '_ym_visorc': 'w',
    '_ym_isad': '2',
    'route_pafo-saiku': 'c74cc883b187536d03cd9d27dbb214c6',
    'suimSessionGuid': '01fc532d-eb66-4ce8-a872-e6217ebe1e8c',
    'route_rest': '3af9d76967c1896ca5c2fc83285be8a8',
    'route_pafo-reports': 'c74cc883b187536d03cd9d27dbb214c6',
    'route_suim': '9cec376355a82e1c2092d0f01142afd1',
    }

    headers = {
        'Accept': 'application/json; charset=utf-8',
        'Accept-Language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
        'Connection': 'keep-alive',
        'Content-Type': 'application/json;charset=UTF-8',
        # 'Cookie': 'JSESSIONID="4KPTdMtSMvRytzOgHUjWR9ZtJp6h118SezPRIcEy.ppak-app-wf-ui-srv06:rest"; _ym_uid=1713711641264140247; _ym_d=1713711641; _ym_visorc=w; _ym_isad=2; route_pafo-saiku=c74cc883b187536d03cd9d27dbb214c6; suimSessionGuid=01fc532d-eb66-4ce8-a872-e6217ebe1e8c; route_rest=3af9d76967c1896ca5c2fc83285be8a8; route_pafo-reports=c74cc883b187536d03cd9d27dbb214c6; route_suim=9cec376355a82e1c2092d0f01142afd1',
        'Origin': 'https://my.dom.gosuslugi.ru',
        'Referer': 'https://my.dom.gosuslugi.ru/',
        'Request-GUID': '38cc5ae1-4f91-4b71-a21e-fae6c0be5a54',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-origin',
        'Session-GUID': '01fc532d-eb66-4ce8-a872-e6217ebe1e8c',
        'State-GUID': '/houses',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36',
        'sec-ch-ua': '"Google Chrome";v="125", "Chromium";v="125", "Not.A/Brand";v="24"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    params = {
        'pageIndex': str(page),
        'elementsPerPage': '100',
    }

    json_data = {
        'regionCode': '0c089b04-099e-4e0e-955a-6bf1ce525f1a',
        'cityCode': '93b3df57-4c89-44df-ac42-96f05e9cd3b9',
        'fiasHouseCodeList': None,
        'estStatus': None,
        'strStatus': None,
        'calcCount': True,
        'houseConditionRefList': [
            '1',
            '3',
        ],
        'houseTypeRefList': [
            '2',
            '3',
            '1',
        ],
        'houseManagementTypeRefList': None,
        'cadastreNumber': None,
        'oktmo': None,
        'statuses': [
            'APPROVED',
        ],
        'regionProperty': None,
        'municipalProperty': None,
        'hostelTypeCodes': None,
    }

    response = requests.post(
        'https://my.dom.gosuslugi.ru/homemanagement/api/rest/services/houses/public/searchByAddress',
        params=params,
        cookies=cookies,
        headers=headers,
        json=json_data,
    )

    # Note: json_data will not be serialized by requests
    # exactly as it was in the original request.
    #data = '{"regionCode":"0c089b04-099e-4e0e-955a-6bf1ce525f1a","cityCode":"93b3df57-4c89-44df-ac42-96f05e9cd3b9","fiasHouseCodeList":null,"estStatus":null,"strStatus":null,"calcCount":true,"houseConditionRefList":["1","3"],"houseTypeRefList":["2","3","1"],"houseManagementTypeRefList":null,"cadastreNumber":null,"oktmo":null,"statuses":["APPROVED"],"regionProperty":null,"municipalProperty":null,"hostelTypeCodes":null}'
    #response = requests.post(
    #    'https://my.dom.gosuslugi.ru/homemanagement/api/rest/services/houses/public/searchByAddress',
    #    params=params,
    #    cookies=cookies,
    #    headers=headers,
    #    data=data,
    #)

    
    return response.json()

def prepare_items(response):
    t1 = []
    
    t1_raw = response.get('items', None)
    
    if t1_raw != None and len(t1_raw) > 0:
        for t in t1_raw:
            t1.append({
                'Адрес': t.get('address', None).get('formattedAddress', None),
                'КН': t.get('cadastreNumber', None),
                'Год': t.get('buildingYear', None),
                'Материал': t.get('planSeries', None),
                'Этажность': t.get('maxFloorCount', None),
                'Состояние': t.get('houseCondition', None).get('houseCondition', None) if t.get('houseCondition', 
                                                                                                None) != None else None,
            })
    
    return t1

def main():
    pages = 3 #количество страниц
    a = 0
    pages_no = []
    
    for p in tqdm(range(1, pages + 1, 1), 'Сбор данных'):
        #try:
        a = a + 1 #счетчик
        response = get_category(page = p)
        sleep(10)
        #response = response.json()
        t1 = prepare_items(response)
        #print(t1)
        df = pd.DataFrame(t1)
        #df = df.set_index(0)

        if a == 1:
            df_result = df
        if a > 1:
            df_result = pd.concat([df_result, df], axis = 0)

        #Сохраняем в Excel
        writer = pd.ExcelWriter('База_ГИС_ЖКХ_Казань_аварийные.xlsx')
        df_result.to_excel(writer, 'marks')
        writer.save()
        #except:
            #print('Error')
            #print(resp.text)
            #pages_no.append(p)
    
    #return pages_no
    
    #pd.DataFrame(t1).to_csv('База_ГИС_ЖКС.csv', index = False)

if __name__ == '__main__':
    main()
# Out:
# Сбор данных:   0%|                                                                               | 0/3 [00:00<?, ?it/s]C:\Users\skapr\AppData\Local\Temp\ipykernel_7508\3279196440.py:199: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
# Сбор данных:  33%|███████████████████████▋                                               | 1/3 [00:10<00:21, 10.77s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_7508\3279196440.py:199: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
# Сбор данных:  67%|███████████████████████████████████████████████▎                       | 2/3 [00:21<00:10, 10.65s/it]C:\Users\skapr\AppData\Local\Temp\ipykernel_7508\3279196440.py:199: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
# Сбор данных: 100%|███████████████████████████████████████████████████████████████████████| 3/3 [00:31<00:00, 10.66s/it]

# %%
pd.read_csv('База_ГИС_ЖКС.csv')
# Out:
#                                                 Адрес                 КН  \
# 0   690013, край Приморский, г Владивосток, ул Нев...  25:28:010037:6026
# 1   690013, край Приморский, г Владивосток, ул Нев...   25:28:010038:448
# 2   690013, край Приморский, г Владивосток, ул Нев...  25:28:010038:2564
# 3   690013, край Приморский, г Владивосток, ул Нев...  25:28:010037:7860
# 4   690013, край Приморский, г Владивосток, ул Нев...   25:28:010038:586
# ..                                                ...                ...
# 95  690012, край Приморский, г Владивосток, ул Кал...   25:28:030001:257
# 96  690012, край Приморский, г Владивосток, ул Кал...   25:28:030002:407
# 97  690012, край Приморский, г Владивосток, ул Кал...   25:28:030001:284
# 98  690012, край Приморский, г Владивосток, ул Кал...   25:28:030001:288
# 99  690012, край Приморский, г Владивосток, ул Кал...   25:28:030001:285
#
#        Год              Материал  Этажность  Состояние
# 0   1985.0             Панельный          9  Исправный
# 1   1985.0           отсутствует          9  Исправный
# 2   1985.0           отсутствует         12  Исправный
# 3   2022.0                   NaN         23  Исправный
# 4   1986.0           отсутствует          9  Исправный
# ..     ...                   ...        ...        ...
# 95  1956.0  отсут в тех.паспорт.          2  Исправный
# 96  1948.0   нет данных, Блочный          3  Исправный
# 97  1957.0            нет данных          2  Исправный
# 98  1956.0                   NaN          2  Исправный
# 99  1956.0                   NaN          2  Исправный
#
# [100 rows x 6 columns]

# %% [markdown]
# # Ручник

# %%
def get_category():
    cookies = {
    'JSESSIONID': '"Pm3SGY27QOV0I2GGB0z8TIVFTS0-K1AuWIjti72-.ppak-app-wf-ui-srv01:rest"',
    'route_pafo-saiku': '3eed4a51ebe9ecbd752731228dd302a5',
    'suimSessionGuid': '25c891af-6ec7-4524-9d13-8774d83d7324',
    'route_rest': 'f814435dc3e2908dfe2bb8ec3465a5f1',
    'route_suim': '9cec376355a82e1c2092d0f01142afd1',
    'route_pafo-reports': 'c74cc883b187536d03cd9d27dbb214c6',
    }

    headers = {
        'Accept': 'application/json; charset=utf-8',
        'Accept-Language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
        'Connection': 'keep-alive',
        'Content-Type': 'application/json;charset=UTF-8',
        # 'Cookie': 'JSESSIONID="Pm3SGY27QOV0I2GGB0z8TIVFTS0-K1AuWIjti72-.ppak-app-wf-ui-srv01:rest"; route_pafo-saiku=3eed4a51ebe9ecbd752731228dd302a5; suimSessionGuid=25c891af-6ec7-4524-9d13-8774d83d7324; route_rest=f814435dc3e2908dfe2bb8ec3465a5f1; route_suim=9cec376355a82e1c2092d0f01142afd1; route_pafo-reports=c74cc883b187536d03cd9d27dbb214c6',
        'Origin': 'https://dom.gosuslugi.ru',
        'Referer': 'https://dom.gosuslugi.ru/',
        'Request-GUID': '0b6c739b-b531-4bba-896c-a8fd9bb12ba9',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-origin',
        'Session-GUID': '25c891af-6ec7-4524-9d13-8774d83d7324',
        'State-GUID': '/houses',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
        'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    params = {
        'pageIndex': '1',
        'elementsPerPage': '100',
    }

    json_data = {
        'regionCode': '92b30014-4d52-4e2e-892d-928142b924bf',
        'cityCode': '2763c110-cb8b-416a-9dac-ad28a55b4402',
        'fiasHouseCodeList': None,
        'estStatus': None,
        'strStatus': None,
        'calcCount': True,
        'houseConditionRefList': [
            '1',
            '3',
        ],
        'houseTypeRefList': None,
        'houseManagementTypeRefList': None,
        'cadastreNumber': None,
        'oktmo': None,
        'statuses': [
            'APPROVED',
        ],
        'regionProperty': None,
        'municipalProperty': None,
        'hostelTypeCodes': None,
    }

    response = requests.post(
        'https://dom.gosuslugi.ru/homemanagement/api/rest/services/houses/public/searchByAddress',
        params=params,
        cookies=cookies,
        headers=headers,
        json=json_data,
    )
    return response.json()

# %%
response = get_category()
t1_raw = response.get('items', None)

# %%
t1_raw
# Out:
# [{'guid': '836a244d-0f05-463b-aac5-2c91a8209150',
#   'rootGuid': None,
#   'versionNumber': None,
#   'lastUpdateUnixTime': None,
#   'lastUpdateDate': None,
#   'createDate': None,
#   'readOnly': None,
#   'active': None,
#   'asyncProcessing': None,
#   'asyncProcessType': None,
#   'status': 'APPROVED',
#   'cancellationReasonCode': None,
#   'cancellationComment': None,
#   'cancellationDate': None,
#   'demolitionDate': None,
#   'demolitionReason': None,
#   'address': {'region': {'guid': 'e76abf09-3148-42f6-85db-51edb09e72b7',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '92b30014-4d52-4e2e-892d-928142b924bf',
#     'aoLevel': 1,
#     'postalCode': None,
#     'formalName': 'Свердловская',
#     'offName': 'Свердловская',
#     'shortName': 'обл',
#     'parentGuid': None,
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'area': None,
#    'city': {'guid': '309fe4b8-cc4d-4085-9e34-f46ad3377ab8',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '2763c110-cb8b-416a-9dac-ad28a55b4402',
#     'aoLevel': 4,
#     'postalCode': None,
#     'formalName': 'Екатеринбург',
#     'offName': 'Екатеринбург',
#     'shortName': 'г',
#     'parentGuid': '92b30014-4d52-4e2e-892d-928142b924bf',
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'ctar': None,
#    'additionalTerritory': None,
#    'additionalTerStreet': None,
#    'settlement': None,
#    'planningStructureElement': None,
#    'street': {'guid': 'd5f8c0ac-55ab-4883-ad2e-014354fc3ff0',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '02d3e31d-7ae1-4ddf-b16a-30e4032aa19e',
#     'aoLevel': 7,
#     'postalCode': None,
#     'formalName': 'Кобозева',
#     'offName': 'Кобозева',
#     'shortName': 'ул',
#     'parentGuid': '2763c110-cb8b-416a-9dac-ad28a55b4402',
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'house': {'guid': '5f847334-5a5f-4ae6-9b07-4a7b6be8f37e',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'houseGuid': '08584f4c-56ba-43db-8962-7537f0cd4848',
#     'aoGuid': '02d3e31d-7ae1-4ddf-b16a-30e4032aa19e',
#     'postalCode': '620057',
#     'houseNumber': '40',
#     'buildingNumber': None,
#     'structNumber': None,
#     'additionalName': None,
#     'houseCondition': None,
#     'propertyStateGuid': None,
#     'oktmo': None,
#     'formattedAddress': None,
#     'isAddedManually': False,
#     'onApproval': None,
#     'estStatus': 'DOM',
#     'strStatus': 'NE_OPREDELENO',
#     'fiasHouseGuid': None,
#     'aggregated': False,
#     'childAddresses': None,
#     'parentAggregatedGuid': None,
#     'houseTextAddress': '40',
#     'doubles': None,
#     'actualHouseGuid': None,
#     'startDate': None,
#     'endDate': None},
#    'formattedAddress': '620057, обл Свердловская, г Екатеринбург, ул Кобозева, д. 40',
#    'deprecated': False},
#   'houseGuid': '5f847334-5a5f-4ae6-9b07-4a7b6be8f37e',
#   'planSeries': 'информация отсутствует',
#   'planType': None,
#   'buildingYear': '1951',
#   'operationYear': 1951,
#   'residentialPremiseCount': '8',
#   'nonResidentialPremiseCount': '0',
#   'residentialPremiseActualCount': None,
#   'nonResidentialPremiseActualCount': None,
#   'residentialPremiseConfirmedCount': None,
#   'nonResidentialPremiseConfirmedCount': None,
#   'managementOrganization': {'guid': 'fe576193-8442-4b21-9683-e71ffbd0735d',
#    'createDate': '30.04.2015',
#    'lastEventDate': '05.10.2022',
#    'fullName': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "УПРАВЛЯЮЩАЯ КОМПАНИЯ "РЭМП-"ЭЛЬМАШ"',
#    'shortName': 'ООО "УК "РЭМП -"ЭЛЬМАШ"',
#    'orgAddress': '620135, ОБЛАСТЬ СВЕРДЛОВСКАЯ, Г. ЕКАТЕРИНБУРГ, ПР-КТ КОСМОНАВТОВ, д. Д. 96, кв. ОФИС 1 ЭТАЖ',
#    'phone': '+7 (343) 306-91-88',
#    'url': 'http://www.rmpelmash.ru/',
#    'organizationType': 'L',
#    'olsonTZ': {'guid': '1e05329c-6ff0-4a20-b373-bb57c3592c3b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '6',
#     'name': None},
#    'okopf': {'guid': 'dc79475c-20f2-4291-aae7-43838ad8230b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '12300',
#     'name': None},
#    'registryOrganizationRootEntityGuid': '66c83a43-92d6-410e-af9c-cae799e9f95c',
#    'parentGuid': None,
#    'ogrn': '1056604948685'},
#   'municipalityOrganization': {'guid': '86d52f1b-f4bf-49c9-a359-649a51eaf65f',
#    'createDate': None,
#    'lastEventDate': None,
#    'fullName': 'УПРАВЛЕНИЕ ЖИЛИЩНОГО И КОММУНАЛЬНОГО ХОЗЯЙСТВА АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'shortName': 'УПРАВЛЕНИЕ ЖКХ АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'orgAddress': '620014, ОБЛАСТЬ СВЕРДЛОВСКАЯ, Г. ЕКАТЕРИНБУРГ, УЛ. МАЛЫШЕВА, к. СТР. 31А',
#    'phone': '73433041360',
#    'url': 'http://екатеринбург.рф',
#    'organizationType': 'A',
#    'olsonTZ': None,
#    'okopf': None,
#    'registryOrganizationRootEntityGuid': '03d62d42-004c-477e-b92d-085498f797a2',
#    'parentGuid': None,
#    'ogrn': '1026605246876'},
#   'maxFloorCount': '2',
#   'deterioration': '72',
#   'houseType': {'guid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'actual': True,
#    'code': '1',
#    'rootEntityGuid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseTypeName': 'Многоквартирный'},
#   'totalSquare': None,
#   'residentialSquare': None,
#   'accountCount': None,
#   'houseCondition': {'guid': 'cbe05853-a91b-43cc-a2cb-06cdfa97d492',
#    'actual': True,
#    'code': '1',
#    'rootEntityGuid': 'cbe05853-a91b-43cc-a2cb-06cdfa97d492',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseCondition': 'Аварийный'},
#   'devices': None,
#   'accountRefs': None,
#   'apartmentsWithoutAccountCount': None,
#   'ableEnterDeviceMetering': False,
#   'houseManagementType': None,
#   'oktmo': {'guid': '7b00ec79-516a-4a0a-b396-70945633cdfd',
#    'actual': False,
#    'code': '65701000001',
#    'rootEntityGuid': None,
#    'lastUpdateDate': '15.02.2024',
#    'createDate': '06.02.2015',
#    'name': 'г Екатеринбург',
#    'controlNumber': 6,
#    'additionalData': None,
#    'description': None,
#    'parent': {'guid': 'a37730d8-a9e9-4067-a157-7670ea967021',
#     'actual': False,
#     'code': '65701000000',
#     'rootEntityGuid': None,
#     'lastUpdateDate': '15.02.2024',
#     'createDate': '06.02.2015',
#     'name': 'Населенные пункты, входящие в состав городского округа город Екатеринбург',
#     'controlNumber': 9,
#     'additionalData': None,
#     'description': None,
#     'parent': {'guid': '563bc5aa-b448-4dfa-abaf-2dde03c633ae',
#      'actual': False,
#      'code': '65701000',
#      'rootEntityGuid': None,
#      'lastUpdateDate': '15.02.2024',
#      'createDate': '06.02.2015',
#      'name': 'город Екатеринбург',
#      'controlNumber': 9,
#      'additionalData': 'г Екатеринбург',
#      'description': None,
#      'parent': {'guid': '9b800224-6cbf-4d09-9eb1-77a6bb77b0c5',
#       'actual': False,
#       'code': '65700000',
#       'rootEntityGuid': None,
#       'lastUpdateDate': '15.02.2024',
#       'createDate': '06.02.2015',
#       'name': 'Городские округа Свердловской области',
#       'controlNumber': 4,
#       'additionalData': None,
#       'description': None,
#       'parent': {'guid': 'd629264f-98db-4fef-b3ee-4bae17388dd3',
#        'actual': False,
#        'code': '65000000',
#        'rootEntityGuid': None,
#        'lastUpdateDate': '15.02.2024',
#        'createDate': '06.02.2015',
#        'name': 'Муниципальные образования Свердловской области',
#        'controlNumber': 5,
#        'additionalData': None,
#        'description': None,
#        'parent': None,
#        'status': None,
#        'utvDate': '14.06.2013',
#        'vvedDate': '01.01.2014',
#        'level': 1,
#        'hasChildren': True,
#        'hasActualChildren': True,
#        'loadAttribute': None,
#        'oldMoscow': None},
#       'status': None,
#       'utvDate': '14.06.2013',
#       'vvedDate': '01.01.2014',
#       'level': 2,
#       'hasChildren': True,
#       'hasActualChildren': True,
#       'loadAttribute': None,
#       'oldMoscow': None},
#      'status': None,
#      'utvDate': '14.06.2013',
#      'vvedDate': '01.01.2014',
#      'level': 3,
#      'hasChildren': True,
#      'hasActualChildren': True,
#      'loadAttribute': None,
#      'oldMoscow': None},
#     'status': None,
#     'utvDate': '14.06.2013',
#     'vvedDate': '01.01.2014',
#     'level': 6,
#     'hasChildren': True,
#     'hasActualChildren': True,
#     'loadAttribute': None,
#     'oldMoscow': None},
#    'status': None,
#    'utvDate': '14.06.2013',
#    'vvedDate': '01.01.2014',
#    'level': 7,
#    'hasChildren': False,
#    'hasActualChildren': False,
#    'loadAttribute': None,
#    'oldMoscow': None},
#   'canAdd': None,
#   'hasMunicipalServices': None,
#   'hasDummyShare': None,
#   'hasShare': None,
#   'userOrganizationRole': None,
#   'blockedHouse': False,
#   'cadastreNumber': '66:41:0108073:114',
#   'oldCadastreNumber': None,
#   'canCancel': None,
#   'cancellationReason': None,
#   'hasIncorrectObjects': None,
#   'hasActiveDevices': None,
#   'canReadShare': None,
#   'regionProperty': None,
#   'municipalProperty': None,
#   'hostelType': None,
#   'chiefFirstName': None,
#   'chiefLastName': None,
#   'chiefMiddleName': None,
#   'houseCancelled': False,
#   'approved': True,
#   'canceledOrAsyncProcessed': False},
#  {'guid': 'd2c010a6-2685-4d4a-9700-98a52827f596',
#   'rootGuid': None,
#   'versionNumber': None,
#   'lastUpdateUnixTime': None,
#   'lastUpdateDate': None,
#   'createDate': None,
#   'readOnly': None,
#   'active': None,
#   'asyncProcessing': None,
#   'asyncProcessType': None,
#   'status': 'APPROVED',
#   'cancellationReasonCode': None,
#   'cancellationComment': None,
#   'cancellationDate': None,
#   'demolitionDate': None,
#   'demolitionReason': None,
#   'address': {'region': {'guid': 'e76abf09-3148-42f6-85db-51edb09e72b7',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '92b30014-4d52-4e2e-892d-928142b924bf',
#     'aoLevel': 1,
#     'postalCode': None,
#     'formalName': 'Свердловская',
#     'offName': 'Свердловская',
#     'shortName': 'обл',
#     'parentGuid': None,
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'area': None,
#    'city': {'guid': '309fe4b8-cc4d-4085-9e34-f46ad3377ab8',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '2763c110-cb8b-416a-9dac-ad28a55b4402',
#     'aoLevel': 4,
#     'postalCode': None,
#     'formalName': 'Екатеринбург',
#     'offName': 'Екатеринбург',
#     'shortName': 'г',
#     'parentGuid': '92b30014-4d52-4e2e-892d-928142b924bf',
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'ctar': None,
#    'additionalTerritory': None,
#    'additionalTerStreet': None,
#    'settlement': None,
#    'planningStructureElement': None,
#    'street': {'guid': 'b87fb54d-0a0c-4943-a955-8751a292d015',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '05e57cfd-c376-4717-856a-800f1fd1521e',
#     'aoLevel': 7,
#     'postalCode': None,
#     'formalName': 'Вишневая',
#     'offName': 'Вишневая',
#     'shortName': 'ул',
#     'parentGuid': '2763c110-cb8b-416a-9dac-ad28a55b4402',
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'house': {'guid': '79979dd6-ae92-406b-b5f6-a8e16b4ea864',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'houseGuid': '55c9f4f7-a9a9-444f-b5c0-ae0be90a5d43',
#     'aoGuid': '05e57cfd-c376-4717-856a-800f1fd1521e',
#     'postalCode': '620078',
#     'houseNumber': '30',
#     'buildingNumber': None,
#     'structNumber': None,
#     'additionalName': None,
#     'houseCondition': None,
#     'propertyStateGuid': None,
#     'oktmo': None,
#     'formattedAddress': None,
#     'isAddedManually': False,
#     'onApproval': None,
#     'estStatus': 'DOM',
#     'strStatus': 'NE_OPREDELENO',
#     'fiasHouseGuid': None,
#     'aggregated': False,
#     'childAddresses': None,
#     'parentAggregatedGuid': None,
#     'houseTextAddress': '30',
#     'doubles': None,
#     'actualHouseGuid': None,
#     'startDate': None,
#     'endDate': None},
#    'formattedAddress': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 30',
#    'deprecated': False},
#   'houseGuid': '79979dd6-ae92-406b-b5f6-a8e16b4ea864',
#   'planSeries': 'нет данных',
#   'planType': None,
#   'buildingYear': '1945',
#   'operationYear': 1945,
#   'residentialPremiseCount': '8',
#   'nonResidentialPremiseCount': '0',
#   'residentialPremiseActualCount': None,
#   'nonResidentialPremiseActualCount': None,
#   'residentialPremiseConfirmedCount': None,
#   'nonResidentialPremiseConfirmedCount': None,
#   'managementOrganization': {'guid': '18a285fc-760c-48ee-99be-3f62c19182cc',
#    'createDate': '29.07.2015',
#    'lastEventDate': '23.11.2023',
#    'fullName': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФОНД РАДОМИР"',
#    'shortName': 'ООО  "ФОНД РАДОМИР"',
#    'orgAddress': '620041, ОБЛАСТЬ СВЕРДЛОВСКАЯ, Г. ЕКАТЕРИНБУРГ, УЛ. ПИОНЕРОВ, д. Д.2',
#    'phone': '73432170047',
#    'url': 'fondradomir.ru',
#    'organizationType': 'L',
#    'olsonTZ': {'guid': '1e05329c-6ff0-4a20-b373-bb57c3592c3b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '6',
#     'name': None},
#    'okopf': {'guid': 'dc79475c-20f2-4291-aae7-43838ad8230b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '12300',
#     'name': None},
#    'registryOrganizationRootEntityGuid': '470dcf52-c5c6-4bc3-89be-4674af5caf04',
#    'parentGuid': None,
#    'ogrn': '1076670026586'},
#   'municipalityOrganization': {'guid': '86d52f1b-f4bf-49c9-a359-649a51eaf65f',
#    'createDate': None,
#    'lastEventDate': None,
#    'fullName': 'УПРАВЛЕНИЕ ЖИЛИЩНОГО И КОММУНАЛЬНОГО ХОЗЯЙСТВА АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'shortName': 'УПРАВЛЕНИЕ ЖКХ АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'orgAddress': '620014, ОБЛАСТЬ СВЕРДЛОВСКАЯ, Г. ЕКАТЕРИНБУРГ, УЛ. МАЛЫШЕВА, к. СТР. 31А',
#    'phone': '73433041360',
#    'url': 'http://екатеринбург.рф',
#    'organizationType': 'A',
#    'olsonTZ': None,
#    'okopf': None,
#    'registryOrganizationRootEntityGuid': '03d62d42-004c-477e-b92d-085498f797a2',
#    'parentGuid': None,
#    'ogrn': '1026605246876'},
#   'maxFloorCount': '2',
#   'deterioration': '58',
#   'houseType': {'guid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'actual': True,
#    'code': '1',
#    'rootEntityGuid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseTypeName': 'Многоквартирный'},
#   'totalSquare': None,
#   'residentialSquare': None,
#   'accountCount': None,
#   'houseCondition': {'guid': 'bf083ae4-e4ec-4ace-b190-4d009e5cd1a1',
#    'actual': True,
#    'code': '3',
#    'rootEntityGuid': 'bf083ae4-e4ec-4ace-b190-4d009e5cd1a1',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseCondition': 'Ветхий'},
#   'devices': None,
#   'accountRefs': None,
#   'apartmentsWithoutAccountCount': None,
#   'ableEnterDeviceMetering': False,
#   'houseManagementType': None,
#   'oktmo': {'guid': '7b00ec79-516a-4a0a-b396-70945633cdfd',
#    'actual': False,
#    'code': '65701000001',
#    'rootEntityGuid': None,
#    'lastUpdateDate': '15.02.2024',
#    'createDate': '06.02.2015',
#    'name': 'г Екатеринбург',
#    'controlNumber': 6,
#    'additionalData': None,
#    'description': None,
#    'parent': {'guid': 'a37730d8-a9e9-4067-a157-7670ea967021',
#     'actual': False,
#     'code': '65701000000',
#     'rootEntityGuid': None,
#     'lastUpdateDate': '15.02.2024',
#     'createDate': '06.02.2015',
#     'name': 'Населенные пункты, входящие в состав городского округа город Екатеринбург',
#     'controlNumber': 9,
#     'additionalData': None,
#     'description': None,
#     'parent': {'guid': '563bc5aa-b448-4dfa-abaf-2dde03c633ae',
#      'actual': False,
#      'code': '65701000',
#      'rootEntityGuid': None,
#      'lastUpdateDate': '15.02.2024',
#      'createDate': '06.02.2015',
#      'name': 'город Екатеринбург',
#      'controlNumber': 9,
#      'additionalData': 'г Екатеринбург',
#      'description': None,
#      'parent': {'guid': '9b800224-6cbf-4d09-9eb1-77a6bb77b0c5',
#       'actual': False,
#       'code': '65700000',
#       'rootEntityGuid': None,
#       'lastUpdateDate': '15.02.2024',
#       'createDate': '06.02.2015',
#       'name': 'Городские округа Свердловской области',
#       'controlNumber': 4,
#       'additionalData': None,
#       'description': None,
#       'parent': {'guid': 'd629264f-98db-4fef-b3ee-4bae17388dd3',
#        'actual': False,
#        'code': '65000000',
#        'rootEntityGuid': None,
#        'lastUpdateDate': '15.02.2024',
#        'createDate': '06.02.2015',
#        'name': 'Муниципальные образования Свердловской области',
#        'controlNumber': 5,
#        'additionalData': None,
#        'description': None,
#        'parent': None,
#        'status': None,
#        'utvDate': '14.06.2013',
#        'vvedDate': '01.01.2014',
#        'level': 1,
#        'hasChildren': True,
#        'hasActualChildren': True,
#        'loadAttribute': None,
#        'oldMoscow': None},
#       'status': None,
#       'utvDate': '14.06.2013',
#       'vvedDate': '01.01.2014',
#       'level': 2,
#       'hasChildren': True,
#       'hasActualChildren': True,
#       'loadAttribute': None,
#       'oldMoscow': None},
#      'status': None,
#      'utvDate': '14.06.2013',
#      'vvedDate': '01.01.2014',
#      'level': 3,
#      'hasChildren': True,
#      'hasActualChildren': True,
#      'loadAttribute': None,
#      'oldMoscow': None},
#     'status': None,
#     'utvDate': '14.06.2013',
#     'vvedDate': '01.01.2014',
#     'level': 6,
#     'hasChildren': True,
#     'hasActualChildren': True,
#     'loadAttribute': None,
#     'oldMoscow': None},
#    'status': None,
#    'utvDate': '14.06.2013',
#    'vvedDate': '01.01.2014',
#    'level': 7,
#    'hasChildren': False,
#    'hasActualChildren': False,
#    'loadAttribute': None,
#    'oldMoscow': None},
#   'canAdd': None,
#   'hasMunicipalServices': None,
#   'hasDummyShare': None,
#   'hasShare': None,
#   'userOrganizationRole': None,
#   'blockedHouse': False,
#   'cadastreNumber': '66:41:0704044:191',
#   'oldCadastreNumber': None,
#   'canCancel': None,
#   'cancellationReason': None,
#   'hasIncorrectObjects': None,
#   'hasActiveDevices': None,
#   'canReadShare': None,
#   'regionProperty': None,
#   'municipalProperty': None,
#   'hostelType': None,
#   'chiefFirstName': None,
#   'chiefLastName': None,
#   'chiefMiddleName': None,
#   'houseCancelled': False,
#   'approved': True,
#   'canceledOrAsyncProcessed': False},
#  {'guid': '4cb65a6d-52f7-44dc-80ae-674bd8fec84c',
#   'rootGuid': None,
#   'versionNumber': None,
#   'lastUpdateUnixTime': None,
#   'lastUpdateDate': None,
#   'createDate': None,
#   'readOnly': None,
#   'active': None,
#   'asyncProcessing': None,
#   'asyncProcessType': None,
#   'status': 'APPROVED',
#   'cancellationReasonCode': None,
#   'cancellationComment': None,
#   'cancellationDate': None,
#   'demolitionDate': None,
#   'demolitionReason': None,
#   'address': {'region': {'guid': 'e76abf09-3148-42f6-85db-51edb09e72b7',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '92b30014-4d52-4e2e-892d-928142b924bf',
#     'aoLevel': 1,
#     'postalCode': None,
#     'formalName': 'Свердловская',
#     'offName': 'Свердловская',
#     'shortName': 'обл',
#     'parentGuid': None,
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'area': None,
#    'city': {'guid': '309fe4b8-cc4d-4085-9e34-f46ad3377ab8',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '2763c110-cb8b-416a-9dac-ad28a55b4402',
#     'aoLevel': 4,
#     'postalCode': None,
#     'formalName': 'Екатеринбург',
#     'offName': 'Екатеринбург',
#     'shortName': 'г',
#     'parentGuid': '92b30014-4d52-4e2e-892d-928142b924bf',
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'ctar': None,
#    'additionalTerritory': None,
#    'additionalTerStreet': None,
#    'settlement': None,
#    'planningStructureElement': None,
#    'street': {'guid': 'b87fb54d-0a0c-4943-a955-8751a292d015',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '05e57cfd-c376-4717-856a-800f1fd1521e',
#     'aoLevel': 7,
#     'postalCode': None,
#     'formalName': 'Вишневая',
#     'offName': 'Вишневая',
#     'shortName': 'ул',
#     'parentGuid': '2763c110-cb8b-416a-9dac-ad28a55b4402',
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'house': {'guid': '0bd13dd0-6efa-4c13-81fd-483f1eb3b3a6',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'houseGuid': '514b8db0-ab42-4b1f-9ae1-1be0e0d5595f',
#     'aoGuid': '05e57cfd-c376-4717-856a-800f1fd1521e',
#     'postalCode': '620078',
#     'houseNumber': '36',
#     'buildingNumber': None,
#     'structNumber': None,
#     'additionalName': None,
#     'houseCondition': None,
#     'propertyStateGuid': None,
#     'oktmo': None,
#     'formattedAddress': None,
#     'isAddedManually': False,
#     'onApproval': None,
#     'estStatus': 'DOM',
#     'strStatus': 'NE_OPREDELENO',
#     'fiasHouseGuid': None,
#     'aggregated': False,
#     'childAddresses': None,
#     'parentAggregatedGuid': None,
#     'houseTextAddress': '36',
#     'doubles': None,
#     'actualHouseGuid': None,
#     'startDate': None,
#     'endDate': None},
#    'formattedAddress': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 36',
#    'deprecated': False},
#   'houseGuid': '0bd13dd0-6efa-4c13-81fd-483f1eb3b3a6',
#   'planSeries': 'нет данных',
#   'planType': None,
#   'buildingYear': '1960',
#   'operationYear': 1950,
#   'residentialPremiseCount': '8',
#   'nonResidentialPremiseCount': '0',
#   'residentialPremiseActualCount': None,
#   'nonResidentialPremiseActualCount': None,
#   'residentialPremiseConfirmedCount': None,
#   'nonResidentialPremiseConfirmedCount': None,
#   'managementOrganization': {'guid': '18a285fc-760c-48ee-99be-3f62c19182cc',
#    'createDate': '29.07.2015',
#    'lastEventDate': '23.11.2023',
#    'fullName': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФОНД РАДОМИР"',
#    'shortName': 'ООО  "ФОНД РАДОМИР"',
#    'orgAddress': '620041, ОБЛАСТЬ СВЕРДЛОВСКАЯ, Г. ЕКАТЕРИНБУРГ, УЛ. ПИОНЕРОВ, д. Д.2',
#    'phone': '73432170047',
#    'url': 'fondradomir.ru',
#    'organizationType': 'L',
#    'olsonTZ': {'guid': '1e05329c-6ff0-4a20-b373-bb57c3592c3b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '6',
#     'name': None},
#    'okopf': {'guid': 'dc79475c-20f2-4291-aae7-43838ad8230b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '12300',
#     'name': None},
#    'registryOrganizationRootEntityGuid': '470dcf52-c5c6-4bc3-89be-4674af5caf04',
#    'parentGuid': None,
#    'ogrn': '1076670026586'},
#   'municipalityOrganization': {'guid': '86d52f1b-f4bf-49c9-a359-649a51eaf65f',
#    'createDate': None,
#    'lastEventDate': None,
#    'fullName': 'УПРАВЛЕНИЕ ЖИЛИЩНОГО И КОММУНАЛЬНОГО ХОЗЯЙСТВА АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'shortName': 'УПРАВЛЕНИЕ ЖКХ АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'orgAddress': '620014, ОБЛАСТЬ СВЕРДЛОВСКАЯ, Г. ЕКАТЕРИНБУРГ, УЛ. МАЛЫШЕВА, к. СТР. 31А',
#    'phone': '73433041360',
#    'url': 'http://екатеринбург.рф',
#    'organizationType': 'A',
#    'olsonTZ': None,
#    'okopf': None,
#    'registryOrganizationRootEntityGuid': '03d62d42-004c-477e-b92d-085498f797a2',
#    'parentGuid': None,
#    'ogrn': '1026605246876'},
#   'maxFloorCount': '2',
#   'deterioration': '69',
#   'houseType': {'guid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'actual': True,
#    'code': '1',
#    'rootEntityGuid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseTypeName': 'Многоквартирный'},
#   'totalSquare': None,
#   'residentialSquare': None,
#   'accountCount': None,
#   'houseCondition': {'guid': 'cbe05853-a91b-43cc-a2cb-06cdfa97d492',
#    'actual': True,
#    'code': '1',
#    'rootEntityGuid': 'cbe05853-a91b-43cc-a2cb-06cdfa97d492',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseCondition': 'Аварийный'},
#   'devices': None,
#   'accountRefs': None,
#   'apartmentsWithoutAccountCount': None,
#   'ableEnterDeviceMetering': False,
#   'houseManagementType': None,
#   'oktmo': {'guid': '7b00ec79-516a-4a0a-b396-70945633cdfd',
#    'actual': False,
#    'code': '65701000001',
#    'rootEntityGuid': None,
#    'lastUpdateDate': '15.02.2024',
#    'createDate': '06.02.2015',
#    'name': 'г Екатеринбург',
#    'controlNumber': 6,
#    'additionalData': None,
#    'description': None,
#    'parent': {'guid': 'a37730d8-a9e9-4067-a157-7670ea967021',
#     'actual': False,
#     'code': '65701000000',
#     'rootEntityGuid': None,
#     'lastUpdateDate': '15.02.2024',
#     'createDate': '06.02.2015',
#     'name': 'Населенные пункты, входящие в состав городского округа город Екатеринбург',
#     'controlNumber': 9,
#     'additionalData': None,
#     'description': None,
#     'parent': {'guid': '563bc5aa-b448-4dfa-abaf-2dde03c633ae',
#      'actual': False,
#      'code': '65701000',
#      'rootEntityGuid': None,
#      'lastUpdateDate': '15.02.2024',
#      'createDate': '06.02.2015',
#      'name': 'город Екатеринбург',
#      'controlNumber': 9,
#      'additionalData': 'г Екатеринбург',
#      'description': None,
#      'parent': {'guid': '9b800224-6cbf-4d09-9eb1-77a6bb77b0c5',
#       'actual': False,
#       'code': '65700000',
#       'rootEntityGuid': None,
#       'lastUpdateDate': '15.02.2024',
#       'createDate': '06.02.2015',
#       'name': 'Городские округа Свердловской области',
#       'controlNumber': 4,
#       'additionalData': None,
#       'description': None,
#       'parent': {'guid': 'd629264f-98db-4fef-b3ee-4bae17388dd3',
#        'actual': False,
#        'code': '65000000',
#        'rootEntityGuid': None,
#        'lastUpdateDate': '15.02.2024',
#        'createDate': '06.02.2015',
#        'name': 'Муниципальные образования Свердловской области',
#        'controlNumber': 5,
#        'additionalData': None,
#        'description': None,
#        'parent': None,
#        'status': None,
#        'utvDate': '14.06.2013',
#        'vvedDate': '01.01.2014',
#        'level': 1,
#        'hasChildren': True,
#        'hasActualChildren': True,
#        'loadAttribute': None,
#        'oldMoscow': None},
#       'status': None,
#       'utvDate': '14.06.2013',
#       'vvedDate': '01.01.2014',
#       'level': 2,
#       'hasChildren': True,
#       'hasActualChildren': True,
#       'loadAttribute': None,
#       'oldMoscow': None},
#      'status': None,
#      'utvDate': '14.06.2013',
#      'vvedDate': '01.01.2014',
#      'level': 3,
#      'hasChildren': True,
#      'hasActualChildren': True,
#      'loadAttribute': None,
#      'oldMoscow': None},
#     'status': None,
#     'utvDate': '14.06.2013',
#     'vvedDate': '01.01.2014',
#     'level': 6,
#     'hasChildren': True,
#     'hasActualChildren': True,
#     'loadAttribute': None,
#     'oldMoscow': None},
#    'status': None,
#    'utvDate': '14.06.2013',
#    'vvedDate': '01.01.2014',
#    'level': 7,
#    'hasChildren': False,
#    'hasActualChildren': False,
#    'loadAttribute': None,
#    'oldMoscow': None},
#   'canAdd': None,
#   'hasMunicipalServices': None,
#   'hasDummyShare': None,
#   'hasShare': None,
#   'userOrganizationRole': None,
#   'blockedHouse': False,
#   'cadastreNumber': '66:41:0704044:267',
#   'oldCadastreNumber': None,
#   'canCancel': None,
#   'cancellationReason': None,
#   'hasIncorrectObjects': None,
#   'hasActiveDevices': None,
#   'canReadShare': None,
#   'regionProperty': None,
#   'municipalProperty': None,
#   'hostelType': None,
#   'chiefFirstName': None,
#   'chiefLastName': None,
#   'chiefMiddleName': None,
#   'houseCancelled': False,
#   'approved': True,
#   'canceledOrAsyncProcessed': False},
#  {'guid': 'a984c41c-c3d4-469c-a748-8e15249d21fd',
#   'rootGuid': None,
#   'versionNumber': None,
#   'lastUpdateUnixTime': None,
#   'lastUpdateDate': None,
#   'createDate': None,
#   'readOnly': None,
#   'active': None,
#   'asyncProcessing': None,
#   'asyncProcessType': None,
#   'status': 'APPROVED',
#   'cancellationReasonCode': None,
#   'cancellationComment': None,
#   'cancellationDate': None,
#   'demolitionDate': None,
#   'demolitionReason': None,
#   'address': {'region': {'guid': 'e76abf09-3148-42f6-85db-51edb09e72b7',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '92b30014-4d52-4e2e-892d-928142b924bf',
#     'aoLevel': 1,
#     'postalCode': None,
#     'formalName': 'Свердловская',
#     'offName': 'Свердловская',
#     'shortName': 'обл',
#     'parentGuid': None,
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'area': None,
#    'city': {'guid': '309fe4b8-cc4d-4085-9e34-f46ad3377ab8',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '2763c110-cb8b-416a-9dac-ad28a55b4402',
#     'aoLevel': 4,
#     'postalCode': None,
#     'formalName': 'Екатеринбург',
#     'offName': 'Екатеринбург',
#     'shortName': 'г',
#     'parentGuid': '92b30014-4d52-4e2e-892d-928142b924bf',
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'ctar': None,
#    'additionalTerritory': None,
#    'additionalTerStreet': None,
#    'settlement': None,
#    'planningStructureElement': None,
#    'street': {'guid': 'b87fb54d-0a0c-4943-a955-8751a292d015',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '05e57cfd-c376-4717-856a-800f1fd1521e',
#     'aoLevel': 7,
#     'postalCode': None,
#     'formalName': 'Вишневая',
#     'offName': 'Вишневая',
#     'shortName': 'ул',
#     'parentGuid': '2763c110-cb8b-416a-9dac-ad28a55b4402',
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'house': {'guid': 'efef25dd-18ee-4d16-8dff-db5d702c573e',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'houseGuid': '19c7f281-adb8-4433-be5b-03c5d0f2f0e7',
#     'aoGuid': '05e57cfd-c376-4717-856a-800f1fd1521e',
#     'postalCode': '620078',
#     'houseNumber': '38',
#     'buildingNumber': None,
#     'structNumber': None,
#     'additionalName': None,
#     'houseCondition': None,
#     'propertyStateGuid': None,
#     'oktmo': None,
#     'formattedAddress': None,
#     'isAddedManually': False,
#     'onApproval': None,
#     'estStatus': 'DOM',
#     'strStatus': 'NE_OPREDELENO',
#     'fiasHouseGuid': None,
#     'aggregated': False,
#     'childAddresses': None,
#     'parentAggregatedGuid': None,
#     'houseTextAddress': '38',
#     'doubles': None,
#     'actualHouseGuid': None,
#     'startDate': None,
#     'endDate': None},
#    'formattedAddress': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 38',
#    'deprecated': False},
#   'houseGuid': 'efef25dd-18ee-4d16-8dff-db5d702c573e',
#   'planSeries': 'нет данных',
#   'planType': None,
#   'buildingYear': '1950',
#   'operationYear': 1950,
#   'residentialPremiseCount': '8',
#   'nonResidentialPremiseCount': '0',
#   'residentialPremiseActualCount': None,
#   'nonResidentialPremiseActualCount': None,
#   'residentialPremiseConfirmedCount': None,
#   'nonResidentialPremiseConfirmedCount': None,
#   'managementOrganization': {'guid': '18a285fc-760c-48ee-99be-3f62c19182cc',
#    'createDate': '29.07.2015',
#    'lastEventDate': '23.11.2023',
#    'fullName': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФОНД РАДОМИР"',
#    'shortName': 'ООО  "ФОНД РАДОМИР"',
#    'orgAddress': '620041, ОБЛАСТЬ СВЕРДЛОВСКАЯ, Г. ЕКАТЕРИНБУРГ, УЛ. ПИОНЕРОВ, д. Д.2',
#    'phone': '73432170047',
#    'url': 'fondradomir.ru',
#    'organizationType': 'L',
#    'olsonTZ': {'guid': '1e05329c-6ff0-4a20-b373-bb57c3592c3b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '6',
#     'name': None},
#    'okopf': {'guid': 'dc79475c-20f2-4291-aae7-43838ad8230b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '12300',
#     'name': None},
#    'registryOrganizationRootEntityGuid': '470dcf52-c5c6-4bc3-89be-4674af5caf04',
#    'parentGuid': None,
#    'ogrn': '1076670026586'},
#   'municipalityOrganization': {'guid': '86d52f1b-f4bf-49c9-a359-649a51eaf65f',
#    'createDate': None,
#    'lastEventDate': None,
#    'fullName': 'УПРАВЛЕНИЕ ЖИЛИЩНОГО И КОММУНАЛЬНОГО ХОЗЯЙСТВА АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'shortName': 'УПРАВЛЕНИЕ ЖКХ АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'orgAddress': '620014, ОБЛАСТЬ СВЕРДЛОВСКАЯ, Г. ЕКАТЕРИНБУРГ, УЛ. МАЛЫШЕВА, к. СТР. 31А',
#    'phone': '73433041360',
#    'url': 'http://екатеринбург.рф',
#    'organizationType': 'A',
#    'olsonTZ': None,
#    'okopf': None,
#    'registryOrganizationRootEntityGuid': '03d62d42-004c-477e-b92d-085498f797a2',
#    'parentGuid': None,
#    'ogrn': '1026605246876'},
#   'maxFloorCount': '2',
#   'deterioration': '69',
#   'houseType': {'guid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'actual': True,
#    'code': '1',
#    'rootEntityGuid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseTypeName': 'Многоквартирный'},
#   'totalSquare': None,
#   'residentialSquare': None,
#   'accountCount': None,
#   'houseCondition': {'guid': 'cbe05853-a91b-43cc-a2cb-06cdfa97d492',
#    'actual': True,
#    'code': '1',
#    'rootEntityGuid': 'cbe05853-a91b-43cc-a2cb-06cdfa97d492',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseCondition': 'Аварийный'},
#   'devices': None,
#   'accountRefs': None,
#   'apartmentsWithoutAccountCount': None,
#   'ableEnterDeviceMetering': False,
#   'houseManagementType': None,
#   'oktmo': {'guid': '7b00ec79-516a-4a0a-b396-70945633cdfd',
#    'actual': False,
#    'code': '65701000001',
#    'rootEntityGuid': None,
#    'lastUpdateDate': '15.02.2024',
#    'createDate': '06.02.2015',
#    'name': 'г Екатеринбург',
#    'controlNumber': 6,
#    'additionalData': None,
#    'description': None,
#    'parent': {'guid': 'a37730d8-a9e9-4067-a157-7670ea967021',
#     'actual': False,
#     'code': '65701000000',
#     'rootEntityGuid': None,
#     'lastUpdateDate': '15.02.2024',
#     'createDate': '06.02.2015',
#     'name': 'Населенные пункты, входящие в состав городского округа город Екатеринбург',
#     'controlNumber': 9,
#     'additionalData': None,
#     'description': None,
#     'parent': {'guid': '563bc5aa-b448-4dfa-abaf-2dde03c633ae',
#      'actual': False,
#      'code': '65701000',
#      'rootEntityGuid': None,
#      'lastUpdateDate': '15.02.2024',
#      'createDate': '06.02.2015',
#      'name': 'город Екатеринбург',
#      'controlNumber': 9,
#      'additionalData': 'г Екатеринбург',
#      'description': None,
#      'parent': {'guid': '9b800224-6cbf-4d09-9eb1-77a6bb77b0c5',
#       'actual': False,
#       'code': '65700000',
#       'rootEntityGuid': None,
#       'lastUpdateDate': '15.02.2024',
#       'createDate': '06.02.2015',
#       'name': 'Городские округа Свердловской области',
#       'controlNumber': 4,
#       'additionalData': None,
#       'description': None,
#       'parent': {'guid': 'd629264f-98db-4fef-b3ee-4bae17388dd3',
#        'actual': False,
#        'code': '65000000',
#        'rootEntityGuid': None,
#        'lastUpdateDate': '15.02.2024',
#        'createDate': '06.02.2015',
#        'name': 'Муниципальные образования Свердловской области',
#        'controlNumber': 5,
#        'additionalData': None,
#        'description': None,
#        'parent': None,
#        'status': None,
#        'utvDate': '14.06.2013',
#        'vvedDate': '01.01.2014',
#        'level': 1,
#        'hasChildren': True,
#        'hasActualChildren': True,
#        'loadAttribute': None,
#        'oldMoscow': None},
#       'status': None,
#       'utvDate': '14.06.2013',
#       'vvedDate': '01.01.2014',
#       'level': 2,
#       'hasChildren': True,
#       'hasActualChildren': True,
#       'loadAttribute': None,
#       'oldMoscow': None},
#      'status': None,
#      'utvDate': '14.06.2013',
#      'vvedDate': '01.01.2014',
#      'level': 3,
#      'hasChildren': True,
#      'hasActualChildren': True,
#      'loadAttribute': None,
#      'oldMoscow': None},
#     'status': None,
#     'utvDate': '14.06.2013',
#     'vvedDate': '01.01.2014',
#     'level': 6,
#     'hasChildren': True,
#     'hasActualChildren': True,
#     'loadAttribute': None,
#     'oldMoscow': None},
#    'status': None,
#    'utvDate': '14.06.2013',
#    'vvedDate': '01.01.2014',
#    'level': 7,
#    'hasChildren': False,
#    'hasActualChildren': False,
#    'loadAttribute': None,
#    'oldMoscow': None},
#   'canAdd': None,
#   'hasMunicipalServices': None,
#   'hasDummyShare': None,
#   'hasShare': None,
#   'userOrganizationRole': None,
#   'blockedHouse': False,
#   'cadastreNumber': '66:41:0704044:169',
#   'oldCadastreNumber': None,
#   'canCancel': None,
#   'cancellationReason': None,
#   'hasIncorrectObjects': None,
#   'hasActiveDevices': None,
#   'canReadShare': None,
#   'regionProperty': None,
#   'municipalProperty': None,
#   'hostelType': None,
#   'chiefFirstName': None,
#   'chiefLastName': None,
#   'chiefMiddleName': None,
#   'houseCancelled': False,
#   'approved': True,
#   'canceledOrAsyncProcessed': False},
#  {'guid': '012120f2-996a-4805-94ad-8aa6438b0b86',
#   'rootGuid': None,
#   'versionNumber': None,
#   'lastUpdateUnixTime': None,
#   'lastUpdateDate': None,
#   'createDate': None,
#   'readOnly': None,
#   'active': None,
#   'asyncProcessing': None,
#   'asyncProcessType': None,
#   'status': 'APPROVED',
#   'cancellationReasonCode': None,
#   'cancellationComment': None,
#   'cancellationDate': None,
#   'demolitionDate': None,
#   'demolitionReason': None,
#   'address': {'region': {'guid': 'e76abf09-3148-42f6-85db-51edb09e72b7',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '92b30014-4d52-4e2e-892d-928142b924bf',
#     'aoLevel': 1,
#     'postalCode': None,
#     'formalName': 'Свердловская',
#     'offName': 'Свердловская',
#     'shortName': 'обл',
#     'parentGuid': None,
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'area': None,
#    'city': {'guid': '309fe4b8-cc4d-4085-9e34-f46ad3377ab8',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '2763c110-cb8b-416a-9dac-ad28a55b4402',
#     'aoLevel': 4,
#     'postalCode': None,
#     'formalName': 'Екатеринбург',
#     'offName': 'Екатеринбург',
#     'shortName': 'г',
#     'parentGuid': '92b30014-4d52-4e2e-892d-928142b924bf',
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'ctar': None,
#    'additionalTerritory': None,
#    'additionalTerStreet': None,
#    'settlement': None,
#    'planningStructureElement': None,
#    'street': {'guid': 'b87fb54d-0a0c-4943-a955-8751a292d015',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '05e57cfd-c376-4717-856a-800f1fd1521e',
#     'aoLevel': 7,
#     'postalCode': None,
#     'formalName': 'Вишневая',
#     'offName': 'Вишневая',
#     'shortName': 'ул',
#     'parentGuid': '2763c110-cb8b-416a-9dac-ad28a55b4402',
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'house': {'guid': '4a92dad9-72ae-4ef3-9d13-cdec3ec1995d',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'houseGuid': '1e3876c7-5475-4e5e-a461-83d0fed12f9d',
#     'aoGuid': '05e57cfd-c376-4717-856a-800f1fd1521e',
#     'postalCode': '620078',
#     'houseNumber': '45',
#     'buildingNumber': None,
#     'structNumber': None,
#     'additionalName': None,
#     'houseCondition': None,
#     'propertyStateGuid': None,
#     'oktmo': None,
#     'formattedAddress': None,
#     'isAddedManually': False,
#     'onApproval': None,
#     'estStatus': 'DOM',
#     'strStatus': 'NE_OPREDELENO',
#     'fiasHouseGuid': None,
#     'aggregated': False,
#     'childAddresses': None,
#     'parentAggregatedGuid': None,
#     'houseTextAddress': '45',
#     'doubles': None,
#     'actualHouseGuid': None,
#     'startDate': None,
#     'endDate': None},
#    'formattedAddress': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 45',
#    'deprecated': False},
#   'houseGuid': '4a92dad9-72ae-4ef3-9d13-cdec3ec1995d',
#   'planSeries': 'нет данных',
#   'planType': None,
#   'buildingYear': '1925',
#   'operationYear': 1925,
#   'residentialPremiseCount': '4',
#   'nonResidentialPremiseCount': '0',
#   'residentialPremiseActualCount': None,
#   'nonResidentialPremiseActualCount': None,
#   'residentialPremiseConfirmedCount': None,
#   'nonResidentialPremiseConfirmedCount': None,
#   'managementOrganization': {'guid': '18a285fc-760c-48ee-99be-3f62c19182cc',
#    'createDate': '29.07.2015',
#    'lastEventDate': '23.11.2023',
#    'fullName': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ФОНД РАДОМИР"',
#    'shortName': 'ООО  "ФОНД РАДОМИР"',
#    'orgAddress': '620041, ОБЛАСТЬ СВЕРДЛОВСКАЯ, Г. ЕКАТЕРИНБУРГ, УЛ. ПИОНЕРОВ, д. Д.2',
#    'phone': '73432170047',
#    'url': 'fondradomir.ru',
#    'organizationType': 'L',
#    'olsonTZ': {'guid': '1e05329c-6ff0-4a20-b373-bb57c3592c3b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '6',
#     'name': None},
#    'okopf': {'guid': 'dc79475c-20f2-4291-aae7-43838ad8230b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '12300',
#     'name': None},
#    'registryOrganizationRootEntityGuid': '470dcf52-c5c6-4bc3-89be-4674af5caf04',
#    'parentGuid': None,
#    'ogrn': '1076670026586'},
#   'municipalityOrganization': {'guid': '86d52f1b-f4bf-49c9-a359-649a51eaf65f',
#    'createDate': None,
#    'lastEventDate': None,
#    'fullName': 'УПРАВЛЕНИЕ ЖИЛИЩНОГО И КОММУНАЛЬНОГО ХОЗЯЙСТВА АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'shortName': 'УПРАВЛЕНИЕ ЖКХ АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'orgAddress': '620014, ОБЛАСТЬ СВЕРДЛОВСКАЯ, Г. ЕКАТЕРИНБУРГ, УЛ. МАЛЫШЕВА, к. СТР. 31А',
#    'phone': '73433041360',
#    'url': 'http://екатеринбург.рф',
#    'organizationType': 'A',
#    'olsonTZ': None,
#    'okopf': None,
#    'registryOrganizationRootEntityGuid': '03d62d42-004c-477e-b92d-085498f797a2',
#    'parentGuid': None,
#    'ogrn': '1026605246876'},
#   'maxFloorCount': '2',
#   'deterioration': '69',
#   'houseType': {'guid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'actual': True,
#    'code': '1',
#    'rootEntityGuid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseTypeName': 'Многоквартирный'},
#   'totalSquare': None,
#   'residentialSquare': None,
#   'accountCount': None,
#   'houseCondition': {'guid': 'bf083ae4-e4ec-4ace-b190-4d009e5cd1a1',
#    'actual': True,
#    'code': '3',
#    'rootEntityGuid': 'bf083ae4-e4ec-4ace-b190-4d009e5cd1a1',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseCondition': 'Ветхий'},
#   'devices': None,
#   'accountRefs': None,
#   'apartmentsWithoutAccountCount': None,
#   'ableEnterDeviceMetering': False,
#   'houseManagementType': None,
#   'oktmo': {'guid': '7b00ec79-516a-4a0a-b396-70945633cdfd',
#    'actual': False,
#    'code': '65701000001',
#    'rootEntityGuid': None,
#    'lastUpdateDate': '15.02.2024',
#    'createDate': '06.02.2015',
#    'name': 'г Екатеринбург',
#    'controlNumber': 6,
#    'additionalData': None,
#    'description': None,
#    'parent': {'guid': 'a37730d8-a9e9-4067-a157-7670ea967021',
#     'actual': False,
#     'code': '65701000000',
#     'rootEntityGuid': None,
#     'lastUpdateDate': '15.02.2024',
#     'createDate': '06.02.2015',
#     'name': 'Населенные пункты, входящие в состав городского округа город Екатеринбург',
#     'controlNumber': 9,
#     'additionalData': None,
#     'description': None,
#     'parent': {'guid': '563bc5aa-b448-4dfa-abaf-2dde03c633ae',
#      'actual': False,
#      'code': '65701000',
#      'rootEntityGuid': None,
#      'lastUpdateDate': '15.02.2024',
#      'createDate': '06.02.2015',
# ...
#   'residentialPremiseConfirmedCount': None,
#   'nonResidentialPremiseConfirmedCount': None,
#   'managementOrganization': {'guid': 'de745820-c026-4938-9bab-8d95963ca772',
#    'createDate': '11.11.2015',
#    'lastEventDate': '08.11.2023',
#    'fullName': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ УПРАВЛЯЮЩАЯ КОМПАНИЯ "ЛАЗУРИТ"',
#    'shortName': 'ООО УК "ЛАЗУРИТ"',
#    'orgAddress': '620130, ОБЛАСТЬ СВЕРДЛОВСКАЯ, ГОРОД ЕКАТЕРИНБУРГ, УЛИЦА АВИАЦИОННАЯ, д. 59, кв. 61',
#    'phone': '73433573287',
#    'url': 'uklazurit.ru',
#    'organizationType': 'L',
#    'olsonTZ': {'guid': '1e05329c-6ff0-4a20-b373-bb57c3592c3b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '6',
#     'name': None},
#    'okopf': {'guid': 'dc79475c-20f2-4291-aae7-43838ad8230b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '12300',
#     'name': None},
#    'registryOrganizationRootEntityGuid': 'f1a9f603-f94e-4320-af1f-c1f57402f8c5',
#    'parentGuid': None,
#    'ogrn': '1076674017188'},
#   'municipalityOrganization': {'guid': '86d52f1b-f4bf-49c9-a359-649a51eaf65f',
#    'createDate': None,
#    'lastEventDate': None,
#    'fullName': 'УПРАВЛЕНИЕ ЖИЛИЩНОГО И КОММУНАЛЬНОГО ХОЗЯЙСТВА АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'shortName': 'УПРАВЛЕНИЕ ЖКХ АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'orgAddress': '620014, ОБЛАСТЬ СВЕРДЛОВСКАЯ, Г. ЕКАТЕРИНБУРГ, УЛ. МАЛЫШЕВА, к. СТР. 31А',
#    'phone': '73433041360',
#    'url': 'http://екатеринбург.рф',
#    'organizationType': 'A',
#    'olsonTZ': None,
#    'okopf': None,
#    'registryOrganizationRootEntityGuid': '03d62d42-004c-477e-b92d-085498f797a2',
#    'parentGuid': None,
#    'ogrn': '1026605246876'},
#   'maxFloorCount': '2',
#   'deterioration': '55',
#   'houseType': {'guid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'actual': True,
#    'code': '1',
#    'rootEntityGuid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseTypeName': 'Многоквартирный'},
#   'totalSquare': None,
#   'residentialSquare': None,
#   'accountCount': None,
#   'houseCondition': {'guid': 'cbe05853-a91b-43cc-a2cb-06cdfa97d492',
#    'actual': True,
#    'code': '1',
#    'rootEntityGuid': 'cbe05853-a91b-43cc-a2cb-06cdfa97d492',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseCondition': 'Аварийный'},
#   'devices': None,
#   'accountRefs': None,
#   'apartmentsWithoutAccountCount': None,
#   'ableEnterDeviceMetering': False,
#   'houseManagementType': None,
#   'oktmo': {'guid': '7b00ec79-516a-4a0a-b396-70945633cdfd',
#    'actual': False,
#    'code': '65701000001',
#    'rootEntityGuid': None,
#    'lastUpdateDate': '15.02.2024',
#    'createDate': '06.02.2015',
#    'name': 'г Екатеринбург',
#    'controlNumber': 6,
#    'additionalData': None,
#    'description': None,
#    'parent': {'guid': 'a37730d8-a9e9-4067-a157-7670ea967021',
#     'actual': False,
#     'code': '65701000000',
#     'rootEntityGuid': None,
#     'lastUpdateDate': '15.02.2024',
#     'createDate': '06.02.2015',
#     'name': 'Населенные пункты, входящие в состав городского округа город Екатеринбург',
#     'controlNumber': 9,
#     'additionalData': None,
#     'description': None,
#     'parent': {'guid': '563bc5aa-b448-4dfa-abaf-2dde03c633ae',
#      'actual': False,
#      'code': '65701000',
#      'rootEntityGuid': None,
#      'lastUpdateDate': '15.02.2024',
#      'createDate': '06.02.2015',
#      'name': 'город Екатеринбург',
#      'controlNumber': 9,
#      'additionalData': 'г Екатеринбург',
#      'description': None,
#      'parent': {'guid': '9b800224-6cbf-4d09-9eb1-77a6bb77b0c5',
#       'actual': False,
#       'code': '65700000',
#       'rootEntityGuid': None,
#       'lastUpdateDate': '15.02.2024',
#       'createDate': '06.02.2015',
#       'name': 'Городские округа Свердловской области',
#       'controlNumber': 4,
#       'additionalData': None,
#       'description': None,
#       'parent': {'guid': 'd629264f-98db-4fef-b3ee-4bae17388dd3',
#        'actual': False,
#        'code': '65000000',
#        'rootEntityGuid': None,
#        'lastUpdateDate': '15.02.2024',
#        'createDate': '06.02.2015',
#        'name': 'Муниципальные образования Свердловской области',
#        'controlNumber': 5,
#        'additionalData': None,
#        'description': None,
#        'parent': None,
#        'status': None,
#        'utvDate': '14.06.2013',
#        'vvedDate': '01.01.2014',
#        'level': 1,
#        'hasChildren': True,
#        'hasActualChildren': True,
#        'loadAttribute': None,
#        'oldMoscow': None},
#       'status': None,
#       'utvDate': '14.06.2013',
#       'vvedDate': '01.01.2014',
#       'level': 2,
#       'hasChildren': True,
#       'hasActualChildren': True,
#       'loadAttribute': None,
#       'oldMoscow': None},
#      'status': None,
#      'utvDate': '14.06.2013',
#      'vvedDate': '01.01.2014',
#      'level': 3,
#      'hasChildren': True,
#      'hasActualChildren': True,
#      'loadAttribute': None,
#      'oldMoscow': None},
#     'status': None,
#     'utvDate': '14.06.2013',
#     'vvedDate': '01.01.2014',
#     'level': 6,
#     'hasChildren': True,
#     'hasActualChildren': True,
#     'loadAttribute': None,
#     'oldMoscow': None},
#    'status': None,
#    'utvDate': '14.06.2013',
#    'vvedDate': '01.01.2014',
#    'level': 7,
#    'hasChildren': False,
#    'hasActualChildren': False,
#    'loadAttribute': None,
#    'oldMoscow': None},
#   'canAdd': None,
#   'hasMunicipalServices': None,
#   'hasDummyShare': None,
#   'hasShare': None,
#   'userOrganizationRole': None,
#   'blockedHouse': False,
#   'cadastreNumber': '66:41:0303002:75',
#   'oldCadastreNumber': None,
#   'canCancel': None,
#   'cancellationReason': None,
#   'hasIncorrectObjects': None,
#   'hasActiveDevices': None,
#   'canReadShare': None,
#   'regionProperty': False,
#   'municipalProperty': False,
#   'hostelType': None,
#   'chiefFirstName': None,
#   'chiefLastName': None,
#   'chiefMiddleName': None,
#   'houseCancelled': False,
#   'approved': True,
#   'canceledOrAsyncProcessed': False},
#  {'guid': '6af9e5ab-38b7-44c9-996a-438309b18dcc',
#   'rootGuid': None,
#   'versionNumber': None,
#   'lastUpdateUnixTime': None,
#   'lastUpdateDate': None,
#   'createDate': None,
#   'readOnly': None,
#   'active': None,
#   'asyncProcessing': None,
#   'asyncProcessType': None,
#   'status': 'APPROVED',
#   'cancellationReasonCode': None,
#   'cancellationComment': None,
#   'cancellationDate': None,
#   'demolitionDate': None,
#   'demolitionReason': None,
#   'address': {'region': {'guid': 'e76abf09-3148-42f6-85db-51edb09e72b7',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '92b30014-4d52-4e2e-892d-928142b924bf',
#     'aoLevel': 1,
#     'postalCode': None,
#     'formalName': 'Свердловская',
#     'offName': 'Свердловская',
#     'shortName': 'обл',
#     'parentGuid': None,
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'area': None,
#    'city': {'guid': '309fe4b8-cc4d-4085-9e34-f46ad3377ab8',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': '2763c110-cb8b-416a-9dac-ad28a55b4402',
#     'aoLevel': 4,
#     'postalCode': None,
#     'formalName': 'Екатеринбург',
#     'offName': 'Екатеринбург',
#     'shortName': 'г',
#     'parentGuid': '92b30014-4d52-4e2e-892d-928142b924bf',
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'ctar': None,
#    'additionalTerritory': None,
#    'additionalTerStreet': None,
#    'settlement': None,
#    'planningStructureElement': None,
#    'street': {'guid': '3520397e-0fdb-4da0-907a-0b89e84b3d8a',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'aoGuid': 'd2c67ef6-fa35-4905-8731-dad9d325abdd',
#     'aoLevel': 7,
#     'postalCode': None,
#     'formalName': 'Энергостроителей',
#     'offName': 'Энергостроителей',
#     'shortName': 'ул',
#     'parentGuid': '2763c110-cb8b-416a-9dac-ad28a55b4402',
#     'oktmo': None,
#     'regionCode': '66',
#     'autoCode': None,
#     'areaCode': None,
#     'cityCode': None,
#     'ctarCode': None,
#     'placeCode': None,
#     'planCode': None,
#     'streetCode': None,
#     'extrCode': None,
#     'sextCode': None,
#     'updateDate': None,
#     'isAddedManually': None,
#     'onApproval': None,
#     'fiasAddrobjGuid': None,
#     'subjectCity': False},
#    'house': {'guid': 'aee49f82-5fbc-45b1-b31a-61e5ab6b8b98',
#     'actual': True,
#     'code': None,
#     'rootEntityGuid': None,
#     'lastUpdateDate': None,
#     'createDate': None,
#     'houseGuid': '4ff3552d-964c-45dc-b3f9-3999478f67de',
#     'aoGuid': 'd2c67ef6-fa35-4905-8731-dad9d325abdd',
#     'postalCode': '620000',
#     'houseNumber': '6А',
#     'buildingNumber': None,
#     'structNumber': None,
#     'additionalName': None,
#     'houseCondition': None,
#     'propertyStateGuid': None,
#     'oktmo': None,
#     'formattedAddress': None,
#     'isAddedManually': False,
#     'onApproval': None,
#     'estStatus': 'DOM',
#     'strStatus': 'NE_OPREDELENO',
#     'fiasHouseGuid': None,
#     'aggregated': False,
#     'childAddresses': None,
#     'parentAggregatedGuid': None,
#     'houseTextAddress': '6А',
#     'doubles': None,
#     'actualHouseGuid': None,
#     'startDate': None,
#     'endDate': None},
#    'formattedAddress': '620000, обл Свердловская, г Екатеринбург, ул Энергостроителей, д. 6А',
#    'deprecated': False},
#   'houseGuid': 'aee49f82-5fbc-45b1-b31a-61e5ab6b8b98',
#   'planSeries': 'отсутствуют данные',
#   'planType': None,
#   'buildingYear': '1949',
#   'operationYear': 1949,
#   'residentialPremiseCount': '8',
#   'nonResidentialPremiseCount': '0',
#   'residentialPremiseActualCount': None,
#   'nonResidentialPremiseActualCount': None,
#   'residentialPremiseConfirmedCount': None,
#   'nonResidentialPremiseConfirmedCount': None,
#   'managementOrganization': {'guid': 'de745820-c026-4938-9bab-8d95963ca772',
#    'createDate': '11.11.2015',
#    'lastEventDate': '08.11.2023',
#    'fullName': 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ УПРАВЛЯЮЩАЯ КОМПАНИЯ "ЛАЗУРИТ"',
#    'shortName': 'ООО УК "ЛАЗУРИТ"',
#    'orgAddress': '620130, ОБЛАСТЬ СВЕРДЛОВСКАЯ, ГОРОД ЕКАТЕРИНБУРГ, УЛИЦА АВИАЦИОННАЯ, д. 59, кв. 61',
#    'phone': '73433573287',
#    'url': 'uklazurit.ru',
#    'organizationType': 'L',
#    'olsonTZ': {'guid': '1e05329c-6ff0-4a20-b373-bb57c3592c3b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '6',
#     'name': None},
#    'okopf': {'guid': 'dc79475c-20f2-4291-aae7-43838ad8230b',
#     'createDate': None,
#     'lastEventDate': None,
#     'code': '12300',
#     'name': None},
#    'registryOrganizationRootEntityGuid': 'f1a9f603-f94e-4320-af1f-c1f57402f8c5',
#    'parentGuid': None,
#    'ogrn': '1076674017188'},
#   'municipalityOrganization': {'guid': '86d52f1b-f4bf-49c9-a359-649a51eaf65f',
#    'createDate': None,
#    'lastEventDate': None,
#    'fullName': 'УПРАВЛЕНИЕ ЖИЛИЩНОГО И КОММУНАЛЬНОГО ХОЗЯЙСТВА АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'shortName': 'УПРАВЛЕНИЕ ЖКХ АДМИНИСТРАЦИИ ГОРОДА ЕКАТЕРИНБУРГА',
#    'orgAddress': '620014, ОБЛАСТЬ СВЕРДЛОВСКАЯ, Г. ЕКАТЕРИНБУРГ, УЛ. МАЛЫШЕВА, к. СТР. 31А',
#    'phone': '73433041360',
#    'url': 'http://екатеринбург.рф',
#    'organizationType': 'A',
#    'olsonTZ': None,
#    'okopf': None,
#    'registryOrganizationRootEntityGuid': '03d62d42-004c-477e-b92d-085498f797a2',
#    'parentGuid': None,
#    'ogrn': '1026605246876'},
#   'maxFloorCount': '3',
#   'deterioration': '60',
#   'houseType': {'guid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'actual': True,
#    'code': '1',
#    'rootEntityGuid': '55a9b133-24eb-456f-85c4-134624646a8d',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseTypeName': 'Многоквартирный'},
#   'totalSquare': None,
#   'residentialSquare': None,
#   'accountCount': None,
#   'houseCondition': {'guid': 'cbe05853-a91b-43cc-a2cb-06cdfa97d492',
#    'actual': True,
#    'code': '1',
#    'rootEntityGuid': 'cbe05853-a91b-43cc-a2cb-06cdfa97d492',
#    'lastUpdateDate': '06.02.2015',
#    'createDate': '06.02.2015',
#    'houseCondition': 'Аварийный'},
#   'devices': None,
#   'accountRefs': None,
#   'apartmentsWithoutAccountCount': None,
#   'ableEnterDeviceMetering': False,
#   'houseManagementType': None,
#   'oktmo': {'guid': '7b00ec79-516a-4a0a-b396-70945633cdfd',
#    'actual': False,
#    'code': '65701000001',
#    'rootEntityGuid': None,
#    'lastUpdateDate': '15.02.2024',
#    'createDate': '06.02.2015',
#    'name': 'г Екатеринбург',
#    'controlNumber': 6,
#    'additionalData': None,
#    'description': None,
#    'parent': {'guid': 'a37730d8-a9e9-4067-a157-7670ea967021',
#     'actual': False,
#     'code': '65701000000',
#     'rootEntityGuid': None,
#     'lastUpdateDate': '15.02.2024',
#     'createDate': '06.02.2015',
#     'name': 'Населенные пункты, входящие в состав городского округа город Екатеринбург',
#     'controlNumber': 9,
#     'additionalData': None,
#     'description': None,
#     'parent': {'guid': '563bc5aa-b448-4dfa-abaf-2dde03c633ae',
#      'actual': False,
#      'code': '65701000',
#      'rootEntityGuid': None,
#      'lastUpdateDate': '15.02.2024',
#      'createDate': '06.02.2015',
#      'name': 'город Екатеринбург',
#      'controlNumber': 9,
#      'additionalData': 'г Екатеринбург',
#      'description': None,
#      'parent': {'guid': '9b800224-6cbf-4d09-9eb1-77a6bb77b0c5',
#       'actual': False,
#       'code': '65700000',
#       'rootEntityGuid': None,
#       'lastUpdateDate': '15.02.2024',
#       'createDate': '06.02.2015',
#       'name': 'Городские округа Свердловской области',
#       'controlNumber': 4,
#       'additionalData': None,
#       'description': None,
#       'parent': {'guid': 'd629264f-98db-4fef-b3ee-4bae17388dd3',
#        'actual': False,
#        'code': '65000000',
#        'rootEntityGuid': None,
#        'lastUpdateDate': '15.02.2024',
#        'createDate': '06.02.2015',
#        'name': 'Муниципальные образования Свердловской области',
#        'controlNumber': 5,
#        'additionalData': None,
#        'description': None,
#        'parent': None,
#        'status': None,
#        'utvDate': '14.06.2013',
#        'vvedDate': '01.01.2014',
#        'level': 1,
#        'hasChildren': True,
#        'hasActualChildren': True,
#        'loadAttribute': None,
#        'oldMoscow': None},
#       'status': None,
#       'utvDate': '14.06.2013',
#       'vvedDate': '01.01.2014',
#       'level': 2,
#       'hasChildren': True,
#       'hasActualChildren': True,
#       'loadAttribute': None,
#       'oldMoscow': None},
#      'status': None,
#      'utvDate': '14.06.2013',
#      'vvedDate': '01.01.2014',
#      'level': 3,
#      'hasChildren': True,
#      'hasActualChildren': True,
#      'loadAttribute': None,
#      'oldMoscow': None},
#     'status': None,
#     'utvDate': '14.06.2013',
#     'vvedDate': '01.01.2014',
#     'level': 6,
#     'hasChildren': True,
#     'hasActualChildren': True,
#     'loadAttribute': None,
#     'oldMoscow': None},
#    'status': None,
#    'utvDate': '14.06.2013',
#    'vvedDate': '01.01.2014',
#    'level': 7,
#    'hasChildren': False,
#    'hasActualChildren': False,
#    'loadAttribute': None,
#    'oldMoscow': None},
#   'canAdd': None,
#   'hasMunicipalServices': None,
#   'hasDummyShare': None,
#   'hasShare': None,
#   'userOrganizationRole': None,
#   'blockedHouse': False,
#   'cadastreNumber': '66:41:0303002:77',
#   'oldCadastreNumber': None,
#   'canCancel': None,
#   'cancellationReason': None,
#   'hasIncorrectObjects': None,
#   'hasActiveDevices': None,
#   'canReadShare': None,
#   'regionProperty': False,
#   'municipalProperty': False,
#   'hostelType': None,
#   'chiefFirstName': None,
#   'chiefLastName': None,
#   'chiefMiddleName': None,
#   'houseCancelled': False,
#   'approved': True,
#   'canceledOrAsyncProcessed': False}]

# %%
t1 = []

#t1_raw = response.get('items', None)

if t1_raw != None and len(t1_raw) > 0:
    for t in t1_raw:
        t1.append({
            'Адрес': t.get('address', None).get('formattedAddress', None),
            'КН': t.get('cadastreNumber', None),
            'Год': t.get('buildingYear', None),
            'Материал': t.get('planSeries', None),
            'Этажность': t.get('maxFloorCount', None),
            'Состояние': t.get('houseCondition', None).get('houseCondition', None) if t.get('houseCondition', 
                                                                                            None) != None else None,
        })
t1
# Out:
# [{'Адрес': '620057, обл Свердловская, г Екатеринбург, ул Кобозева, д. 40',
#   'КН': '66:41:0108073:114',
#   'Год': '1951',
#   'Материал': 'информация отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 30',
#   'КН': '66:41:0704044:191',
#   'Год': '1945',
#   'Материал': 'нет данных',
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 36',
#   'КН': '66:41:0704044:267',
#   'Год': '1960',
#   'Материал': 'нет данных',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 38',
#   'КН': '66:41:0704044:169',
#   'Год': '1950',
#   'Материал': 'нет данных',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 45',
#   'КН': '66:41:0704044:221',
#   'Год': '1925',
#   'Материал': 'нет данных',
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 47',
#   'КН': '66:41:0704044:171',
#   'Год': '1925',
#   'Материал': 'нет данных',
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 49',
#   'КН': '66:41:0704044:195',
#   'Год': '1926',
#   'Материал': 'несерийное деревянное здание',
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 51',
#   'КН': '66:41:0704044:295',
#   'Год': '1927',
#   'Материал': 'несерийное деревянное строение',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 57',
#   'КН': '66:41:0704044:223',
#   'Год': '1929',
#   'Материал': 'нет данных',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 65',
#   'КН': '66:41:0704044:270',
#   'Год': '1929',
#   'Материал': 'несерийное деревянное строение',
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, ул Вишневая, д. 67',
#   'КН': '66:41:0704044:107',
#   'Год': '1929',
#   'Материал': 'несерийное деревянное строение',
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620076, обл Свердловская, г Екатеринбург, ул Павлодарская, д. 3',
#   'КН': '66:41:0502006:13',
#   'Год': None,
#   'Материал': 'не передана застройщиком',
#   'Этажность': '1',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620057, обл Свердловская, г Екатеринбург, ул Краснофлотцев, д. 41',
#   'КН': '66:41:0108103:43',
#   'Год': '1950',
#   'Материал': 'информация отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620033, обл Свердловская, г Екатеринбург, ул Отдыха, д. 12',
#   'КН': None,
#   'Год': '1970',
#   'Материал': 'отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620131, обл Свердловская, г Екатеринбург, ул Венгерских Коммунаров, д. 145а',
#   'КН': '66:41:0303057:61',
#   'Год': '1963',
#   'Материал': 'Кирпичный',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620137, обл Свердловская, г Екатеринбург, ул Ботаническая, д. 26',
#   'КН': '66:41:0704014:35',
#   'Год': '1959',
#   'Материал': 'нет данных',
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620137, обл Свердловская, г Екатеринбург, ул Ботаническая, д. 26а',
#   'КН': '66:41:0704014:28',
#   'Год': '1955',
#   'Материал': 'нет данных',
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620107, обл Свердловская, г Екатеринбург, ул Стрелочников, д. 12',
#   'КН': '66:41:0206017:69',
#   'Год': '1927',
#   'Материал': 'Информация отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620107, обл Свердловская, г Екатеринбург, ул Стрелочников, д. 20',
#   'КН': '66:41:0206017:171',
#   'Год': '1927',
#   'Материал': 'Информация отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620007, обл Свердловская, г Екатеринбург, ул Карельская, д. 76',
#   'КН': '66:41:0609027:42',
#   'Год': '1953',
#   'Материал': '1968 Г 1986, Деревянные',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620141, обл Свердловская, г Екатеринбург, ул Ереванская, д. 25',
#   'КН': '66:41:0205022:77',
#   'Год': '1952',
#   'Материал': 'Информация отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620141, обл Свердловская, г Екатеринбург, ул Ереванская, д. 29',
#   'КН': '66:41:0205022:107',
#   'Год': '1952',
#   'Материал': 'Информация отсутствует',
#   'Этажность': '02',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620141, обл Свердловская, г Екатеринбург, ул Ереванская, д. 31',
#   'КН': '66:41:0205022:57',
#   'Год': '1952',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620141, обл Свердловская, г Екатеринбург, ул Ереванская, д. 33',
#   'КН': '66:41:0205022:74',
#   'Год': '1952',
#   'Материал': 'Информация отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620025, обл Свердловская, г Екатеринбург, ул Ракетная, д. 10',
#   'КН': '66:41:0612087:66',
#   'Год': '1975',
#   'Материал': '1-468Б-3',
#   'Этажность': '5',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620076, обл Свердловская, г Екатеринбург, ул Гастелло, д. 16',
#   'КН': '66:41:0502070:67',
#   'Год': None,
#   'Материал': None,
#   'Этажность': '1',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620076, обл Свердловская, г Екатеринбург, ул Гастелло, д. 18',
#   'КН': '66:41:0502070:69',
#   'Год': None,
#   'Материал': None,
#   'Этажность': '-',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620076, обл Свердловская, г Екатеринбург, ул Гастелло, д. 22',
#   'КН': '66:41:0502070:70',
#   'Год': None,
#   'Материал': None,
#   'Этажность': '1',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620076, обл Свердловская, г Екатеринбург, ул Гастелло, д. 26',
#   'КН': '66:41:0502070:72',
#   'Год': None,
#   'Материал': None,
#   'Этажность': '-',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620033, обл Свердловская, г Екатеринбург, пер Коломенский, д. 4',
#   'КН': None,
#   'Год': '1950',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620033, обл Свердловская, г Екатеринбург, ул Проезжая, д. 216',
#   'КН': '66:41:0711024:49',
#   'Год': '1959',
#   'Материал': 'отсутствует',
#   'Этажность': '1',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620134, обл Свердловская, г Екатеринбург, ул Техническая, д. 127',
#   'КН': '66:41:0204901:491',
#   'Год': None,
#   'Материал': None,
#   'Этажность': '1',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620042, обл Свердловская, г Екатеринбург, ул Народного фронта, д. 62',
#   'КН': '66:41:0106086:50',
#   'Год': '1953',
#   'Материал': 'информация отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620042, обл Свердловская, г Екатеринбург, ул Народного фронта, д. 64',
#   'КН': '66:41:0106086:98',
#   'Год': '1953',
#   'Материал': 'информация отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620134, обл Свердловская, г Екатеринбург, ул Уткинская, д. 27',
#   'КН': '66:41:0203020:68',
#   'Год': '1973',
#   'Материал': 'Информация отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620025, обл Свердловская, г Екатеринбург, ст Кольцово, д. 5',
#   'КН': None,
#   'Год': '1931',
#   'Материал': 'Деревянные',
#   'Этажность': '1',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620025, обл Свердловская, г Екатеринбург, ст Кольцово, д. 7',
#   'КН': '66:41:0612017:41',
#   'Год': '1961',
#   'Материал': 'Кирпичный',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620025, обл Свердловская, г Екатеринбург, ст Кольцово, д. 8',
#   'КН': '66:41:0000000:6727',
#   'Год': '1957',
#   'Материал': 'Деревянные',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620062, обл Свердловская, г Екатеринбург, ул Первомайская, д. 71б',
#   'КН': '66:41:0704024:135',
#   'Год': '1961',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620049, обл Свердловская, г Екатеринбург, ул Первомайская, д. 97',
#   'КН': '66:41:0704024:148',
#   'Год': '1946',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620049, обл Свердловская, г Екатеринбург, ул Первомайская, д. 99',
#   'КН': None,
#   'Год': '1946',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620049, обл Свердловская, г Екатеринбург, ул Первомайская, д. 101',
#   'КН': '66:41:0704024:157',
#   'Год': '1946',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620049, обл Свердловская, г Екатеринбург, ул Первомайская, д. 101б',
#   'КН': '66:41:0704024:118',
#   'Год': '1946',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620049, обл Свердловская, г Екатеринбург, ул Первомайская, д. 103',
#   'КН': None,
#   'Год': '1946',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620049, обл Свердловская, г Екатеринбург, ул Первомайская, д. 103а',
#   'КН': '66:41:0704024:120',
#   'Год': '1946',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620034, обл Свердловская, г Екатеринбург, ул Агриппины Полежаевой, д. 43а',
#   'КН': '66:41:0302033:45',
#   'Год': None,
#   'Материал': None,
#   'Этажность': '3',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620034, обл Свердловская, г Екатеринбург, ул Агриппины Полежаевой, д. 43б',
#   'КН': '66:41:0302033:35',
#   'Год': '1957',
#   'Материал': 'отсутствуют данные',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620033, обл Свердловская, г Екатеринбург, ул Севастопольская, д. 2',
#   'КН': '66:41:0711061:55',
#   'Год': '1960',
#   'Материал': 'нет данных',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620033, обл Свердловская, г Екатеринбург, ул Фабричная, д. 13',
#   'КН': '66:41:0710012:36',
#   'Год': '1957',
#   'Материал': 'В техническом паспорте информация отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620076, обл Свердловская, г Екатеринбург, ул Олега Кошевого, д. 19',
#   'КН': '66:41:0502095:167',
#   'Год': '1955',
#   'Материал': 'не передана застройщиком',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620100, обл Свердловская, г Екатеринбург, пер Базовый, д. 4',
#   'КН': '66:41:0603018:102',
#   'Год': '1953',
#   'Материал': 'Данные в техническом паспорте отсутствуют, Кирпичный',
#   'Этажность': '3',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620144, обл Свердловская, г Екатеринбург, пер Кыштымский, д. 8а',
#   'КН': '66:41:0402025:63',
#   'Год': '1954',
#   'Материал': 'шлакоблочный',
#   'Этажность': '3',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620060, обл Свердловская, г Екатеринбург, ул Опытная, д. 14а',
#   'КН': '66:41:0612005:95',
#   'Год': None,
#   'Материал': None,
#   'Этажность': '2+мансарда',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620010, обл Свердловская, г Екатеринбург, ул Инженерная, д. 14',
#   'КН': '66:41:0509060:72',
#   'Год': '1950',
#   'Материал': 'Блочный, отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620076, обл Свердловская, г Екатеринбург, ул Самолетная, д. 4',
#   'КН': '66:41:0502062:35',
#   'Год': '1957',
#   'Материал': 'не передана застройщиком',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620076, обл Свердловская, г Екатеринбург, ул Самолетная, д. 6',
#   'КН': '66:41:0502062:36',
#   'Год': '1957',
#   'Материал': 'не передана застройщиком',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620076, обл Свердловская, г Екатеринбург, ул Самолетная, д. 8',
#   'КН': '66:41:0502062:28',
#   'Год': '1950',
#   'Материал': 'не передан застройщиком',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620085, обл Свердловская, г Екатеринбург, пер Ремесленный, д. 3',
#   'КН': '66:41:0504025:34',
#   'Год': '1952',
#   'Материал': 'кирпич',
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620085, обл Свердловская, г Екатеринбург, пер Ремесленный, д. 5',
#   'КН': '66:41:0504025:35',
#   'Год': '1952',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620036, обл Свердловская, г Екатеринбург, ул Феофанова, д. 6',
#   'КН': None,
#   'Год': '1931',
#   'Материал': 'данные отсутствуют',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620036, обл Свердловская, г Екатеринбург, ул Феофанова, д. 8',
#   'КН': None,
#   'Год': '1931',
#   'Материал': 'Данные отсутствуют',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620103, обл Свердловская, г Екатеринбург, ул Мусоргского, д. 13',
#   'КН': '66:41:0504084:20',
#   'Год': '1959',
#   'Материал': 'Блочный',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620102, обл Свердловская, г Екатеринбург, ул Репина, д. 20',
#   'КН': None,
#   'Год': '1917',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620043, обл Свердловская, г Екатеринбург, ул Репина, д. 64',
#   'КН': '66:41:0304031:14',
#   'Год': '1959',
#   'Материал': 'отсутствуют данные',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620091, обл Свердловская, г Екатеринбург, ул Корепина, д. 5',
#   'КН': '66:41:0108114:24',
#   'Год': '1943',
#   'Материал': 'Информация отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620030, обл Свердловская, г Екатеринбург, ст Лечебный, д. 3',
#   'КН': '66:41:0000000:4946',
#   'Год': '1965',
#   'Материал': 'Данные в техническом паспорте отсутствуют, Кирпичный',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620041, обл Свердловская, г Екатеринбург, ул Уральская, д. 25',
#   'КН': '66:41:0702077:107',
#   'Год': '1940',
#   'Материал': 'в техническом паспорте нет сведений',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620024, обл Свердловская, г Екатеринбург, ул Мартовская, д. 7',
#   'КН': '66:41:0506006:271',
#   'Год': '1958',
#   'Материал': 'не передана застройщиком',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620103, обл Свердловская, г Екатеринбург, пер Обходной, д. 33',
#   'КН': '66:41:0504095:258',
#   'Год': '1960',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, пер Ученический, д. 4',
#   'КН': '66:41:0704039:24',
#   'Год': '1953',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, пер Ученический, д. 4а',
#   'КН': '66:41:0704039:22',
#   'Год': '1953',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, пер Ученический, д. 8',
#   'КН': '66:41:0704039:20',
#   'Год': '1951',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620078, обл Свердловская, г Екатеринбург, пер Ученический, д. 10',
#   'КН': '66:41:0704039:21',
#   'Год': '1951',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620007, обл Свердловская, г Екатеринбург, км Исток 1826, д. 1',
#   'КН': None,
#   'Год': '1963',
#   'Материал': 'информация отсутствует',
#   'Этажность': '1',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620103, обл Свердловская, г Екатеринбург, пер Энергетиков, д. 3А',
#   'КН': '66:41:0505029:123',
#   'Год': '1958',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620103, обл Свердловская, г Екатеринбург, пер Энергетиков, д. 5Б',
#   'КН': '66:41:0505029:126',
#   'Год': '1958',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620014, обл Свердловская, г Екатеринбург, ул Попова, д. 16',
#   'КН': '66:41:0401008:48',
#   'Год': '1917',
#   'Материал': None,
#   'Этажность': '2',
#   'Состояние': 'Ветхий'},
#  {'Адрес': '620033, обл Свердловская, г Екатеринбург, ст Аппаратная, д. 2',
#   'КН': '66:41:0111004:74',
#   'Год': '1952',
#   'Материал': 'деревянный',
#   'Этажность': '1',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620033, обл Свердловская, г Екатеринбург, ст Аппаратная, д. 4',
#   'КН': '66:41:0111004:51',
#   'Год': None,
#   'Материал': None,
#   'Этажность': '1',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620033, обл Свердловская, г Екатеринбург, ст Аппаратная, д. 6',
#   'КН': '66:41:0111004:20',
#   'Год': '1959',
#   'Материал': 'шлакоблочный',
#   'Этажность': '1',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620033, обл Свердловская, г Екатеринбург, ст Аппаратная, д. 7',
#   'КН': '66:41:0111004:27',
#   'Год': '1968',
#   'Материал': 'кирпичный',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620033, обл Свердловская, г Екатеринбург, ст Аппаратная, д. 8',
#   'КН': '66:41:0111004:75',
#   'Год': '1968',
#   'Материал': 'кирпичный',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620010, обл Свердловская, г Екатеринбург, пер Газовый, д. 1',
#   'КН': '66:41:0509021:14',
#   'Год': None,
#   'Материал': 'Блочный, отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620010, обл Свердловская, г Екатеринбург, пер Газовый, д. 4',
#   'КН': '66:41:0509022:22',
#   'Год': '1949',
#   'Материал': 'Деревянные, отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620010, обл Свердловская, г Екатеринбург, пер Газовый, д. 6',
#   'КН': '66:41:0509022:23',
#   'Год': '1949',
#   'Материал': 'Деревянные, отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620041, обл Свердловская, г Екатеринбург, ул Тобольская, д. 1б',
#   'КН': '66:41:0702052:50',
#   'Год': '1958',
#   'Материал': 'шлакоблочный',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620091, обл Свердловская, г Екатеринбург, ул Шефская, д. 15',
#   'КН': '66:41:0110014:183',
#   'Год': '1948',
#   'Материал': 'информация в тех. паспорте отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620134, обл Свердловская, г Екатеринбург, пер 2-й Подъемный, д. 8',
#   'КН': '66:41:0000000:7915',
#   'Год': '1959',
#   'Материал': 'Информация отсутствует',
#   'Этажность': '1',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620076, обл Свердловская, г Екатеринбург, ул Благодатская, д. 59',
#   'КН': '66:41:0502126:21',
#   'Год': '1958',
#   'Материал': 'не передана застройщиком',
#   'Этажность': '5',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620076, обл Свердловская, г Екатеринбург, ул Благодатская, д. 70',
#   'КН': '66:41:0502084:17',
#   'Год': '1949',
#   'Материал': 'не передана застройщиком',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620089, обл Свердловская, г Екатеринбург, ул Онежская, д. 4, к. 1',
#   'КН': '66:41:0604023:81',
#   'Год': '1951',
#   'Материал': 'данные в технической документации отсутствуют',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620010, обл Свердловская, г Екатеринбург, ул Аквамариновая, д. 26',
#   'КН': None,
#   'Год': '1924',
#   'Материал': None,
#   'Этажность': '1',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620067, обл Свердловская, г Екатеринбург, ул Блюхера, д. 21а',
#   'КН': '66:41:0704008:145',
#   'Год': '1954',
#   'Материал': 'шлакоблочный',
#   'Этажность': '3',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620054, обл Свердловская, г Екатеринбург, ул Дошкольная, д. 7',
#   'КН': '66:41:0525004:12',
#   'Год': '1955',
#   'Материал': 'Блочный, отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620141, обл Свердловская, г Екатеринбург, ул Летчиков, д. 23а',
#   'КН': '66:41:0205017:30',
#   'Год': '1948',
#   'Материал': 'Информация отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620100, обл Свердловская, г Екатеринбург, ул Куйбышева, д. 149',
#   'КН': '66:41:0206032:631',
#   'Год': '1930',
#   'Материал': 'В технической документации информация о серии и типе постройки отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620100, обл Свердловская, г Екатеринбург, ул Куйбышева, стр. 183',
#   'КН': '66:41:0206032:542',
#   'Год': '1953',
#   'Материал': 'В технической документации информация о серии и типе постройки отсутствует',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620000, обл Свердловская, г Екатеринбург, ул Энергостроителей, д. 4',
#   'КН': '66:41:0303002:74',
#   'Год': '1949',
#   'Материал': 'отсутствуют данные',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620000, обл Свердловская, г Екатеринбург, ул Энергостроителей, д. 4А',
#   'КН': '66:41:0303002:75',
#   'Год': '1949',
#   'Материал': 'отсутствуют данные',
#   'Этажность': '2',
#   'Состояние': 'Аварийный'},
#  {'Адрес': '620000, обл Свердловская, г Екатеринбург, ул Энергостроителей, д. 6А',
#   'КН': '66:41:0303002:77',
#   'Год': '1949',
#   'Материал': 'отсутствуют данные',
#   'Этажность': '3',
#   'Состояние': 'Аварийный'}]

# %%
df = pd.DataFrame(t1)
df
# Out:
#                                                 Адрес                 КН  \
# 0   620057, обл Свердловская, г Екатеринбург, ул К...  66:41:0108073:114
# 1   620078, обл Свердловская, г Екатеринбург, ул В...  66:41:0704044:191
# 2   620078, обл Свердловская, г Екатеринбург, ул В...  66:41:0704044:267
# 3   620078, обл Свердловская, г Екатеринбург, ул В...  66:41:0704044:169
# 4   620078, обл Свердловская, г Екатеринбург, ул В...  66:41:0704044:221
# ..                                                ...                ...
# 95  620100, обл Свердловская, г Екатеринбург, ул К...  66:41:0206032:631
# 96  620100, обл Свердловская, г Екатеринбург, ул К...  66:41:0206032:542
# 97  620000, обл Свердловская, г Екатеринбург, ул Э...   66:41:0303002:74
# 98  620000, обл Свердловская, г Екатеринбург, ул Э...   66:41:0303002:75
# 99  620000, обл Свердловская, г Екатеринбург, ул Э...   66:41:0303002:77
#
#      Год                                           Материал Этажность  \
# 0   1951                             информация отсутствует         2
# 1   1945                                         нет данных         2
# 2   1960                                         нет данных         2
# 3   1950                                         нет данных         2
# 4   1925                                         нет данных         2
# ..   ...                                                ...       ...
# 95  1930  В технической документации информация о серии ...         2
# 96  1953  В технической документации информация о серии ...         2
# 97  1949                                 отсутствуют данные         2
# 98  1949                                 отсутствуют данные         2
# 99  1949                                 отсутствуют данные         3
#
#     Состояние
# 0   Аварийный
# 1      Ветхий
# 2   Аварийный
# 3   Аварийный
# 4      Ветхий
# ..        ...
# 95  Аварийный
# 96  Аварийный
# 97  Аварийный
# 98  Аварийный
# 99  Аварийный
#
# [100 rows x 6 columns]

# %%
writer = pd.ExcelWriter('База_ГИС_ЖКХ_Многоквартирные_20.xlsx')
df.to_excel(writer, 'marks')
writer.save()
# Out:
# C:\Users\skapr\AppData\Local\Temp\ipykernel_2948\4012922014.py:3: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
url = 'https://dom.gosuslugi.ru/#!/houses'

r = requests.get(url)
r.text
# Out:
# '<!DOCTYPE html>\n<!-- ng-strict-di="true" -->\n<html ng-controller="PublicCabinetController" ng-csp="no-unsafe-eval">\n    <head>\n        <script type="text/javascript">\n            ;(function () {\n                var loc = window.location.href\n                if (loc.indexOf(\'/#/\') > -1 && loc.indexOf(\'#!\') === -1) {\n                    window.location.href = loc.replace(\'/#/\', \'/#!/\')\n                }\n            })()\n        </script>\n        <title ng-bind="pageTitleHeader">Государственная информационная система жилищно-коммунального хозяйств</title>\n\n        <link rel="icon" type="image/x-icon" href="assets/img/favicon.ico" />\n        <link rel="shortcut icon" type="image/x-icon" href="assets/img/favicon.ico" />\n        <link type="image/x-icon" href="assets/img/favicon.ico" />\n\n        <meta charset="utf-8" />\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="viewport" content="width=device-width, initial-scale=1" />\n        <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n        <meta name="yandex-verification" content="e1d1ef783c8c1e67" />\n        <meta name="description" content="Государственная информационная система жилищно-коммунального хозяйства" />\n\n        <script type="application/json" src="mobileapp/releasenotification.json"></script>\n\n        \n        \n        <link\n            rel="stylesheet"\n            href="./vendor.e8e2feeec4d5f7336d9c.css"\n            integrity="sha256-U2Htl50obzA2rgwZLTWIalIWavXyUQBM7/KHsG9BgpM="\n            crossorigin="anonymous"\n        />\n        \n        <link\n            rel="stylesheet"\n            href="./hybridModules.e8e2feeec4d5f7336d9c.css"\n            integrity="sha256-2z0nmElRpn/rPGiNviyqtb1Yhd7i1YkxRbd2k1VIhW8="\n            crossorigin="anonymous"\n        />\n        \n        <link\n            rel="stylesheet"\n            href="./webPackages.e8e2feeec4d5f7336d9c.css"\n            integrity="sha256-9FtvooTpPSelD2CtPBGZTxNDeZhM4OLASR78qm9T0QE="\n            crossorigin="anonymous"\n        />\n        \n        <link\n            rel="stylesheet"\n            href="./main.e8e2feeec4d5f7336d9c.css"\n            integrity="sha256-hh85G0y03K28SGIr1W0qmsXRMREkpEh3Bx+GgvCc8I8="\n            crossorigin="anonymous"\n        />\n        \n        \n    </head>\n\n    <body ng-class="{\'overflow-hidden\': !isCollapsedGosbar}">\n        <gosbar-catalog></gosbar-catalog>\n        <div class="page-wrapper page-wrapper_v2">\n            <!--<ng-include src="\'blocks/header-gosbar-menu.tpl.html\'"></ng-include>-->\n\n            <div class="container print-running-block" ng-include="\'blocks/print-running-block.tpl.html\'"></div>\n\n            <div class="portal-header-gosbar">\n                <div class="container">\n                    <div class="coat-header"></div>\n                    <div class="gosbar">\n                        <ul>\n                            <li><a class="main-page-link" href ng-click="showAbout()">О сайте</a></li>\n                            <!--<li><a class="main-page-link" href ui-sref="trialWorking">Опытная эксплуатация</a></li>-->\n                            <li ng-if="showWebhelpLink">\n                                <a class="main-page-link" href="webhelp/main/index.html">Справка по системе</a>\n                            </li>\n                            <li class="item_with_popup dropdown" style="z-index: 200">\n                                <a class="main-page-link" ui-sref="regulations">Регламенты и инструкции</a>\n                                <ul class="gosbar-dropdown-menu">\n                                    <li ng-repeat="userCategory in userCategories">\n                                        <a\n                                            href\n                                            ui-sref="regulations({userCtgrCode:userCategory.code})"\n                                            ui-sref-opts="{inherit: false}"\n  ...

# %%
soup = BeautifulSoup(r.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <!-- ng-strict-di="true" --><html ng-controller="PublicCabinetController" ng-csp="no-unsafe-eval">
# <head>
# <script type="text/javascript">
#             ;(function () {
#                 var loc = window.location.href
#                 if (loc.indexOf('/#/') > -1 && loc.indexOf('#!') === -1) {
#                     window.location.href = loc.replace('/#/', '/#!/')
#                 }
#             })()
#         </script>
# <title ng-bind="pageTitleHeader">Государственная информационная система жилищно-коммунального хозяйств</title>
# <link href="assets/img/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="assets/img/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="assets/img/favicon.ico" type="image/x-icon"/>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="e1d1ef783c8c1e67" name="yandex-verification"/>
# <meta content="Государственная информационная система жилищно-коммунального хозяйства" name="description"/>
# <script src="mobileapp/releasenotification.json" type="application/json"></script>
# <link crossorigin="anonymous" href="./vendor.e8e2feeec4d5f7336d9c.css" integrity="sha256-U2Htl50obzA2rgwZLTWIalIWavXyUQBM7/KHsG9BgpM=" rel="stylesheet"/>
# <link crossorigin="anonymous" href="./hybridModules.e8e2feeec4d5f7336d9c.css" integrity="sha256-2z0nmElRpn/rPGiNviyqtb1Yhd7i1YkxRbd2k1VIhW8=" rel="stylesheet"/>
# <link crossorigin="anonymous" href="./webPackages.e8e2feeec4d5f7336d9c.css" integrity="sha256-9FtvooTpPSelD2CtPBGZTxNDeZhM4OLASR78qm9T0QE=" rel="stylesheet"/>
# <link crossorigin="anonymous" href="./main.e8e2feeec4d5f7336d9c.css" integrity="sha256-hh85G0y03K28SGIr1W0qmsXRMREkpEh3Bx+GgvCc8I8=" rel="stylesheet"/>
# </head>
# <body ng-class="{'overflow-hidden': !isCollapsedGosbar}">
# <gosbar-catalog></gosbar-catalog>
# <div class="page-wrapper page-wrapper_v2">
# <!--<ng-include src="'blocks/header-gosbar-menu.tpl.html'"></ng-include>-->
# <div class="container print-running-block" ng-include="'blocks/print-running-block.tpl.html'"></div>
# <div class="portal-header-gosbar">
# <div class="container">
# <div class="coat-header"></div>
# <div class="gosbar">
# <ul>
# <li><a class="main-page-link" href="" ng-click="showAbout()">О сайте</a></li>
# <!--<li><a class="main-page-link" href ui-sref="trialWorking">Опытная эксплуатация</a></li>-->
# <li ng-if="showWebhelpLink">
# <a class="main-page-link" href="webhelp/main/index.html">Справка по системе</a>
# </li>
# <li class="item_with_popup dropdown" style="z-index: 200">
# <a class="main-page-link" ui-sref="regulations">Регламенты и инструкции</a>
# <ul class="gosbar-dropdown-menu">
# <li ng-repeat="userCategory in userCategories">
# <a href="" ng-bind="userCategory.name" ui-sref="regulations({userCtgrCode:userCategory.code})" ui-sref-opts="{inherit: false}">
# </a>
# </li>
# </ul>
# </li>
# <li><a class="main-page-link" href="" ui-sref="faq">Часто задаваемые вопросы</a></li>
# <li><a class="main-page-link" href="" ui-sref="siteMap">Карта сайта</a></li>
# <li>
# <a class="main-page-link" href="/special/">
# <span class="gosbar-eye"></span>
# <span>Версия для слабовидящих</span>
# </a>
# </li>
# </ul>
# </div>
# <div class="gosbar-menu" ng-class="{active: !isCollapsedGosbar}" ng-click="gosbarCatalogPopup.toggle(); gosbarCatalogPopup.isCollapsed();"></div>
# </div>
# </div>
# <!-- PORTAL HEADER -->
# <div class="portal-header target-audience target-audience_pad">
# <div class="container">
# <div class="portal-header__content">
# <div class="row">
# <div class="col-xs-4" style="padding-right: 0;">
# <div class="portal-header__logo">
# <a class="portal-header__logo-title" href="#!/" title="ГИС ЖКХ">
# <span class="portal-header__logo-icon"></span>
#                                         ГИС ЖКХ
#                                     </a>
# <span class="portal-header__logo-subtitle">Государственная информационная система<br/>
#                                         жилищно-коммунального хозяйства</span>
# </div>
# <!-- /end .portal-header__logo -->
# </div>
# <ppa-banner-public></ppa-banner-public>
# <div class="col-xs-5 portal-header__right-part-wrapper">
# <!-- /end .col-... -->
# <div class="portal-header__support-search" style="float: left">
# <div class="portal-header__support row">
# <a class="main-page-link portal-header__contact cnt-lk roboto" ui-sref="public-support-cabinet-och">
# <span class="cnt-lk__label">Обращение в службу поддержки</span>
# </a>
# </div>
# <!-- /end .portal-header__support -->
# <div class="portal-header__search">
# <div class="form-group has-feedback">
# <label class="control-label sr-only" for="portalHeaderSearch">Поиск на портале</label>
# <input class="form-control portal-header__search-it" id="portalHeaderSearch" maxlength="128" ng-model="searchContext.text" placeholder="Поиск по сайту" style="padding-right: 52px" type="text" ui-keypress="{13:'action.portalHeaderSearch(); $event.preventDefault();'}"/>
# <span class="glyphicon glyphicon-search form-control-feedback portal-header__search-it-icon" ng-click="action.portalHeaderSearch()"></span>
# <abbr class="select2-search-choice-close" ng-click="action.portalHeaderSearchClean()" ng-if="searchContext.text" style="margin-right: 30px; margin-top: 5px"></abbr>
# </div>
# </div>
# <!-- /end .portal-header__search -->
# <div style="width: 230px">
# <geo-targeting class="roboto geo-targeting-title-color"></geo-targeting>
# </div>
# </div>
# <!-- /end .col-... -->
# <signed-status-badge style="float: left; width: 315px; padding-left: 10px; padding-right: 3px;"></signed-status-badge>
# </div>
# </div>
# <!-- /end .row -->
# </div>
# <!-- /end .portal-header__content -->
# </div>
# <!-- /end .container -->
# <div class="header-aud-items">
# <target-audience audience="$state.current.data.audience"></target-audience>
# </div>
# </div>
# <header class="print-header">
# <div class="container">
# <div class="row">
# <div class="col-xs-12">
# <div class="title-group title-group_align_center">
# <span class="title-group__icon">
# <img src="assets/img/ui/logo-icon.png"/>
# </span>
# <span class="title-group__title">Государственная информационная система жилищно-коммунального хозяйства</span>
# </div>
# <hr class="print-header__splitter"/>
# </div>
# </div>
# </div>
# </header>
# <div class="app-nav-main-wrapper" id="main-menu" ng-if="!$state.current.data.hideNavBar">
# <div class="container">
# <nav class="app-nav-main">
# <div class="navbar navbar-default" role="navigation">
# <div class="navbar-collapse">
# <ul class="nav navbar-nav navbar-public-menu">
# <li class="dropdown" ng-class="{ active: isActive('regulations, videos') }">
# <a class="main-page-link"> Обучающие материалы </a>
# <ul class="dropdown-menu" role="menu">
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="regulations({rubricNames:'Учебники'})" ui-sref-opts="{inherit: false}">
#                                                     Учебники
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="videos({categories:1})">
#                                                     Видео ГИС ЖКХ
#                                                 </a>
# </li>
# </ul>
# </li>
# <li class="dropdown" ng-class="{ active: isActive('public-programs-rpr-registry, public-capital-repair-programs') }">
# <a class="main-page-link"> Программы в сфере ЖКХ и Горсреды </a>
# <ul class="dropdown-menu" role="menu">
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="public-programs-rpr-registry">
#                                                     Реестр программ в сфере ЖКХ
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="public-capital-repair-programs">
#                                                     Реестр программ капитального ремонта
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" href="{{urbanUrl}}" tabindex="-1">
#                                                     Федеральный проект «Формирование комфортной городской среды»
#                                                 </a>
# </li>
# </ul>
# </li>
# <li class="dropdown" ng-class="{ active: isActive('housesSearch,organizations,rp,pc-licenses,consolidateFederalLicenses,disqualifiedPersonSearch,rap-och-rp, rap-rp') }">
# <a class="main-page-link"> Реестры </a>
# <ul class="dropdown-menu" role="menu">
# <li>
# <a class="main-page-link" href="#!/houses" tabindex="-1">
#                                                     Реестр объектов жилищного фонда
#                                                 </a>
# </li>
# <li class="dropdown-submenu" ng-mouseenter="fixDropdownMenuBounds($event,'organizations_dropdown')" role="menu">
# <a class="main-page-link" href="" ng-click="goToRegistry()">
#                                                     Реестры поставщиков информации
#                                                 </a>
# <ul class="dropdown-menu dropdown-menu-top-0" id="organizations_dropdown" role="menu">
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="organizations({orgType: ['7', '12', '4', '6', '17', '5', '8', '10', '16', '28', '29'], doSearch: false, reftitle: 'Органы государственной власти и местного самоуправления', restore: false})">
#                                                             Органы государственной власти и местного самоуправления
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="organizations({orgType: ['14'], doSearch: false, reftitle: 'Региональные операторы капитального ремонта' , restore: false})">
#                                                             Региональные операторы капитального ремонта
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="organizations({orgType: ['1', '19', '22', '21', '20'], doSearch: false, reftitle: 'Организации, осуществляющие управление многоквартирными домами', restore: false})">
#                                                             Организации, осуществляющие управление многоквартирными
#                                                             домами
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="organizations({orgType: ['2'], doSearch: false, reftitle: 'Ресурсоснабжающие организации', restore: false})">
#                                                             Ресурсоснабжающие организации
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="organizations({orgType: ['18'], doSearch: false, reftitle: 'Региональные операторы по обращению с твердыми коммунальными отходами', restore: false})">
#                                                             Региональные операторы по обращению с твердыми коммунальными
#                                                             отходами
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="organizations({orgType: ['24', '25'], doSearch: false, reftitle: 'Платежные агенты', restore: false})">
#                                                             Платежные агенты
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="organizations({orgType: ['26'], doSearch: false, reftitle: 'Банки, иные кредитные организации или органы, осуществляющие открытие и ведение лицевых счетов в соответствии с бюджетным законодательством РФ', restore: false})">
#                                                             Банки, иные кредитные организации или органы, осуществляющие
#                                                             открытие<br/>и ведение лицевых счетов в соответствии с
#                                                             бюджетным законодательством РФ
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="organizations({orgType: ['23', '3', '15', '11', '13', '30'], doSearch: false, reftitle: 'Иные поставщики информации', restore: false})">
#                                                             Иные поставщики информации
#                                                         </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="main-page-link" href="#!/rp" tabindex="-1">
#                                                     Реестр проверок
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" href="#!/rpg/readiness-passports-search-public" tabindex="-1">
#                                                     Реестр информации о готовности к отопительному сезону (периоду)
#                                                 </a>
# </li>
# <li class="dropdown-submenu" ng-mouseenter="fixDropdownMenuBounds($event,'tko_och_dropdown')" role="menu">
# <a class="main-page-link">
#                                                     Реестры информации об обращении с твердыми коммунальными отходами
#                                                 </a>
# <ul class="dropdown-menu dropdown-menu-top-0" id="tko_och_dropdown" role="menu">
# <li>
# <a class="main-page-link" href="#!/public-tko/tko-search" tabindex="-1">
#                                                             Информация о местах накопления
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" href="#!/tkoregop" tabindex="-1">
#                                                             Информация о конкурсах по отбору региональных операторов
#                                                         </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="main-page-link" ng-if="!rlsEnableNewRegistry" tabindex="-1" ui-sref="pc-licenses">
#                                                     Реестр лицензий субъектов РФ
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" ng-if="!rlsEnableNewRegistry" tabindex="-1" ui-sref="consolidateFederalLicenses">
#                                                     Сводный реестр лицензий
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="disqualifiedPersonSearch">
#                                                     Реестр дисквалифицированных лиц
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" ui-sref="rap-och-rp">
#                                                     Реестр административных правонарушений
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="ppa-och-ogv">
#                                                     Перечень органов власти
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="withdrawal">
#                                                     Реестр решений об изъятии земельных участков
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="placesWithoutInternet">
#                                                     Перечень населенных пунктов без доступа к сети Интернет
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" href="#!/tr-mo-pub/registry/organizations" tabindex="-1">
#                                                     Реестр управляющих организаций и решений об определении управляющих
#                                                     организаций
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="public-capital-repair-programs-tenders">
#                                                     Реестр информации о конкурсах по отбору кредитных организаций
#                                                 </a>
# </li>
# </ul>
# </li>
# <li class="dropdown" ng-class="{ active: isActive('statOfWaterQualityMap') }">
# <a class="main-page-link"> Аналитика и отчёты </a>
# <ul class="dropdown-menu" role="menu">
# <li ng-repeat="item in pafoMenuItems">
# <a class="main-page-link" href="/#!{{item.url}}" tabindex="-1">
# <ng-bind-html ng-bind-html="item.name"></ng-bind-html>
# </a>
# </li>
# <li>
# <!--ЭФ_ПОЧ_ГЛ_Меню.23-->
# <a class="main-page-link" tabindex="-1" ui-sref="statOfWaterQualityMap">
#                                                     Качество питьевой воды
#                                                 </a>
# </li>
# </ul>
# </li>
# <li class="dropdown" ng-class="{ active: isActive('meetings,rates,subsidies,interactive-analytics') }">
# <a class="main-page-link"> Информация для граждан </a>
# <ul class="dropdown-menu" role="menu">
# <li>
# <!--<a class="main-page-link" href="http://dom.gosuslugi.ru/forum/" target="_blank">
# 												Форум ГИС ЖКХ
# 											</a>-->
# <a class="main-page-link" href="#!/meetings" ng-if="availableModules.MEETINGS" tabindex="-1">
#                                                     Встречи органов власти с гражданами
#                                                 </a>
# </li>
# <li class="dropdown-submenu" ng-mouseenter="fixDropdownMenuBounds($event,'tariffs_och_dropdown')" role="menu">
# <a class="main-page-link">
#                                                     Плата за жилое помещение и коммунальные услуги
#                                                 </a>
# <ul class="dropdown-menu dropdown-menu-top-0" id="tariffs_och_dropdown" role="menu">
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="public-tariff-communal-resources-search">
#                                                             Тарифы на оплату коммунальных ресурсов
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="public-tariff-extra-search({typeTariff: 'CAPITAL_REPAIR'})">
#                                                             Размер платы за содержание жилого помещения
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="public-tariff-extra-search({typeTariff: 'CAPITAL_REPAIR_MIN_CONTRIBUTION'})">
#                                                             Минимальный размер взноса на капитальный ремонт
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="public-tariff-extra-search({typeTariff: 'ELECTRICITY_CONSUMPTION_SOCIAL_NORM'})">
#                                                             Социальная норма потребления электрической энергии
#                                                             (мощности)
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="public-tariff-extra-search({typeTariff: 'RENT_PAYMENT'})">
#                                                             Размер платы за пользование жилым помещением
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="rates()">
#                                                             Нормативные правовые акты в сфере регулирования тарифов
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="public-reduced-tariff-search()">
#                                                             Льготные тарифы на жилищно-коммунальные услуги
#                                                         </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="public-indices-main">
#                                                     Индексы изменения платы граждан за ЖКУ
#                                                 </a>
# </li>
# <li class="dropdown-submenu" ng-mouseenter="fixDropdownMenuBounds($event,'msp_och_dropdown')" role="menu">
# <a class="main-page-link"> Меры социальной поддержки </a>
# <ul class="dropdown-menu dropdown-menu-top-0" id="msp_och_dropdown" role="menu">
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="public-msp-categories-list">
#                                                             Компенсации расходов отдельным категориям граждан
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="public-msp-subsidy-provisions-list">
#                                                             Субсидии на оплату ЖКУ
#                                                         </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="subsidies">
#                                                             Нормативные правовые акты в сфере мер социальной поддержки
#                                                         </a>
# </li>
# </ul>
# </li>
# <li ng-if="availableModules.SRUCTURED_MUNICIPAL_SERVICE_SPECIFICATION">
# <a class="main-page-link" href="#!/public-rate-consumption/list" tabindex="-1">
#                                                     Нормативы потребления коммунальных услуг
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="public-standart">
#                                                     Информация о стандартах
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" href="#!/ojk/search" tabindex="-1">
#                                                     Мероприятия общественного жилищного контроля
#                                                 </a>
# </li>
# <li>
# <a class="main-page-link" tabindex="-1" ui-sref="planned-outage-list">
#                                                     Информация о плановых перерывах в предоставлении КУ
#                                                 </a>
# </li>
# </ul>
# </li>
# <li class="dropdown" ng-class="{ active: isActive('') }">
# <!-- для работы на ПАК ссылка без хост-имени/порта -->
# <a class="main-page-link" ui-sref="openData"> Открытые данные </a>
# </li>
# <li class="dropdown" ng-class="{ active: isActive('') }">
# <!-- для работы на ПАК ссылка без хост-имени/порта -->
# <a class="main-page-link" href="/forum/" target="_blank"> Форум </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# </div>
# </div>
# <div class="button-up-div" ng-if="enableScrollButton">
# <button class="button-up" ng-click="scrollToTop()">
#                     НАВЕРХ
#                     <span class="icon-button-up"></span>
# </button>
# </div>
# <div class="app-header-wrapper">
# <div class="container">
# <hcs-banner-rr></hcs-banner-rr>
# </div>
# </div>
# <div class="app-header-breadcrumbs-wrapper">
# <div class="container">
# <div ui-view="pageHeader"></div>
# </div>
# </div>
# <!-- APP CONTENT -->
# <div>
# <div class="container app-content-new" ui-view="content"></div>
# <ng-include src="'blocks/preloader.tpl.html'"></ng-include>
# </div>
# <!-- /END APP CONTENT -->
# <!-- PORTAL FOOTER -->
# <footer class="portal-footer portal-footer_pad">
# <div class="container">
# <div class="portal-footer__content">
# <!-- PORTAL FOOTER MINISTRIES -->
# <div class="portal-footer__ministries">
# <div>
# <div class="footer_inline">
# <span class="portal-footer__ministries-i-icon portal-footer__icon-ministry-ois"></span>
# <a class="main-page-link" ng-click="href('https://www.oisrf.ru/')">
# <span class="portal-footer__ministries-i-title cnt-lk">
# <span class="cnt-lk__label">АО "ОПЕРАТОР ИНФОРМАЦИОННОЙ СИСТЕМЫ"</span>
# </span>
# </a>
# </div>
# <div class="footer_inline">
# <span class="portal-footer__ministries-i-icon portal-footer__icon-ministry-1"></span>
# <a class="main-page-link" ng-click="href('https://minstroyrf.gov.ru')">
# <span class="portal-footer__ministries-i-title cnt-lk">
# <span class="cnt-lk__label">Минстрой России</span>
# </span>
# </a>
# </div>
# </div>
# </div>
# <div class="portal-footer__copyright">
# <div class="row">
# <div class="col-xs-12">
# <div class="app-build-info">
# <span class="app-footer-copy"><hcs-copy-right></hcs-copy-right></span>
# <span class="pull-right">
# <hcs-build-info></hcs-build-info>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
#                 ;(function (d, w, c) {
#                     ;(w[c] = w[c] || []).push(function () {
#                         try {
#                             w.yaCounter28362746 = new Ya.Metrika({
#                                 id: 28362746,
#                                 webvisor: true,
#                                 clickmap: true,
#                                 trackLinks: true,
#                                 accurateTrackBounce: true,
#                                 trackHash: true,
#                                 ut: 'noindex',
#                             })
#                         } catch (e) {}
#                     })
#                     var n = d.getElementsByTagName('script')[0],
#                         s = d.createElement('script'),
#                         f = function () {
#                             n.parentNode.insertBefore(s, n)
#                         }
#                     s.type = 'text/javascript'
#                     s.async = true
#                     s.src = 'https://mc.yandex.ru/metrika/watch.js'
#                     if (w.opera == '[object Opera]') {
#                         d.addEventListener('DOMContentLoaded', f, false)
#                     } else {
#                         f()
#                     }
#                 })(document, window, 'yandex_metrika_callbacks')
#             </script>
# <noscript>
# <div>
# <img alt="" src="//mc.yandex.ru/watch/28362746?ut=noindex" style="position: absolute; left: -9999px"/>
# </div>
# </noscript>
# <!-- /Yandex.Metrika counter -->
# </div>
# <script crossorigin="anonymous" integrity="sha256-zBJu8oNVENCHtODkfujl6TFMN09liSd4VP4p8E9Oaks=" src="./js/vendor.e8e2feeec4d5f7336d9c.js"></script>
# <script crossorigin="anonymous" integrity="sha256-6pvKZXQvMZ7Kp+go+3sgnAAVp+V16m5BqABt1JdFUQ4=" src="./js/hybridApi.e8e2feeec4d5f7336d9c.js"></script>
# <script crossorigin="anonymous" integrity="sha256-CKauua4ak6rMU/kzEfB8wJh9q+x9FykJEXoRPHqadL8=" src="./js/hybridModules.e8e2feeec4d5f7336d9c.js"></script>
# <script crossorigin="anonymous" integrity="sha256-p+3by+GpAHr/jX8lwEjkeY/Te84v9IWxGSdmuQAe+cg=" src="./js/webPackages.e8e2feeec4d5f7336d9c.js"></script>
# <script crossorigin="anonymous" integrity="sha256-b8zt/CVfMLvH2eiXJzGUBLloqgIg4Srm0u+rfPWZthM=" src="./js/main.e8e2feeec4d5f7336d9c.js"></script>
# </body>
# </html>

# %%
soup.find('div', class_ = 'register-card__header-title')
