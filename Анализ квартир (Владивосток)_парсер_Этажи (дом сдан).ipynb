# %%
#Импортируем необходиимых библиотек для реализации парсинга
from selenium import webdriver
from selenium_stealth import stealth # делает похожим на настоящего пользователя
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from time import sleep
from tqdm import tqdm
import pandas as pd
import numpy as np
import winsound
import requests

from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

import datetime
year = datetime.date.today().year

# %%
#webdriver.__version__
import selenium
selenium.__version__
#import selenium
# Out:
# '4.15.2'

# %%
#Выгружаем данные (характеристики, адрес, текст объявления)
service = Service(executable_path = 'C:\Python\chromedriver.exe')
options = webdriver.ChromeOptions()

options.add_argument("--disable-blink-features")
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
options.add_argument("start_maximized")

driver = webdriver.Chrome(service = service, options = options)

stealth(driver,
#        user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.53 Safari/537.36',
        languages=["en-US", "en"],
        vendor = "Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine",
        fix_hairline=False, #True 
        run_on_insecure_origins=False
        )

link_all = []

url = f"https://vl.etagi.com/zastr/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3"
driver.get(url)
sleep(3)

#  while link_all <= 1:
#     try:
#         button = driver.find_element(By.XPATH, '/html/body/div[7]/div/div[1]/button') #закрываем выбор языка
#         button.click() #нажимаем кнопку крестик
#     except:
#         #pass
#         continue

#driver.execute_script("window.scrollBy(0,document.body.scrollHeight)") #прокрутка страницы до самого конца
for i in range(0, 16500, 1500):
    sleep(1)
    driver.execute_script("window.scrollBy(0, 1500)","") #прокрутка страницы 10 раз по 1500 пикселей

blocks = driver.find_elements(By.CLASS_NAME, "y8VEv")
for block in blocks:
    link = block.find_element(By.TAG_NAME, "a").get_attribute("href")
    link_all.append(link)

# %%
#len(link_all)
link_all_1 = link_all[0:15]
link_all_1
# Out:
# ['https://vl.etagi.com/zastr/jk/vostochnyjj-10168/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/chetyre-gorizonta-8909/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/zolotaya-dolina-8569/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/ayaks-11698/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/ehko-siti-7569/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/vidnyjj-8483/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/beregovojj-9805/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/aura-apartments-aura-apartments-12974/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/format-8250/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/nadezhdinskoe-polese-6686/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3',
#  'https://vl.etagi.com/zastr/jk/beregovojj-9829/?ondeadline=true&deadline_date[]=2022-4&deadline_date[]=2023-2&deadline_date[]=2023-3']

# %%
service = Service(executable_path = 'C:\Python\chromedriver.exe')
options = webdriver.ChromeOptions()

options.add_argument("--disable-blink-features")
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
options.add_argument("start_maximized")

driver = webdriver.Chrome(service = service, options = options)

stealth(driver,
#        user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.53 Safari/537.36',
        languages=["en-US", "en"],
        vendor = "Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine",
        fix_hairline=False, #True 
        run_on_insecure_origins=False
        )

link_all_2 = []

for lnk in tqdm(link_all_1, 'Сбор данных'):
    driver.get(lnk)
    sleep(3)
    
    try:
        ob = int(driver.find_element(By.CLASS_NAME, "NoBVp").text.split(" ")[-1]) #количество не открытых объектов
        click = ob // 15 + 1                                                      #количество кликов
    except:
        ob = 0
        #continue
    
    if ob > 0:
        for i in range(1, click + 1, 1):
            button = driver.find_element(By.XPATH, '//*[@id="flats"]/div/div/button') #находим элемент кнопки Еще
            button.send_keys(Keys.ENTER) #нажимаем кнопку Еще
                                         #используем send_keys(Keys.ENTER), когда кнопка вне обзора
            sleep(1)
            
    blocks = driver.find_element(By.CLASS_NAME, "bRpKZ").find_elements(By.TAG_NAME, "a")
    for block in blocks:
        link = block.get_attribute("href")
        link_all_2.append(link)
# Out:
# Сбор данных: 100%|█████████████████████████████████████████████████████████████████████| 15/15 [02:32<00:00, 10.16s/it]

# %%
print(len(link_all_2))
link_all_2
# Out:
# 911
# ['https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6744304/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6739469/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6739537/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6739468/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758927/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758947/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758948/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758949/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6738922/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758933/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758929/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758934/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758952/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758930/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758931/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758932/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758950/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758951/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758953/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758956/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758935/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758954/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6744380/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758936/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6744378/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6744379/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6744381/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758937/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758955/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6739523/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6738940/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6739425/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758938/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758957/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6738455/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758939/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6758940/',
#  'https://vl.etagi.com/zastr/jk/vostochnyjj-10168/6
',
#  'https://vl.etagi.com/zastr/jk/aura-apartments-aura-apartments-12974/8559298/',
#  'https://vl.etagi.com/zastr/jk/aura-apartments-aura-apartments-12974/8559299/',
#  'https://vl.etagi.com/zastr/jk/aura-apartments-aura-apartments-12974/8559300/',
#  'https://vl.etagi.com/zastr/jk/aura-apartments-aura-apartments-12974/8584053/',
#  'https://vl.etagi.com/zastr/jk/aura-apartments-aura-apartments-12974/8559309/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3645664/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3645665/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3651226/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3727880/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3727882/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3727883/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3645667/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3724615/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3651184/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3645674/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3645678/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3645730/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3645732/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3651192/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3651195/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3651204/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3651207/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3651216/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3651222/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3651240/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3724618/',
#  'https://vl.etagi.com/zastr/jk/renessans-8049/3645680/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666386/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666395/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666393/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666394/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666465/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/8211992/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666457/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666425/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666460/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/6923554/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/6923555/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/6923556/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666429/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666432/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666436/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666428/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666431/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/4666458/',
#  'https://vl.etagi.com/zastr/jk/vremena-goda-9536/6923552/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/8923695/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/8066823/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/8923696/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/8923694/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/6734580/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/8494077/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/6734576/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/6734578/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/6734570/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/6734574/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/6734575/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/6734577/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/6734579/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/6734572/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/6734571/',
#  'https://vl.etagi.com/zastr/jk/oazis-12812/6734573/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/3638681/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/6814109/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/6814110/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/3638630/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/3638636/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/3638641/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/3638647/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/3638653/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/3638646/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/3638671/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/3638677/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/3638658/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/3638664/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/3638682/',
#  'https://vl.etagi.com/zastr/jk/lastochka-8112/3638676/',
#  'https://vl.etagi.com/zastr/jk/format-8250/6437173/',
#  'https://vl.etagi.com/zastr/jk/format-8250/6437158/',
#  'https://vl.etagi.com/zastr/jk/format-8250/6437151/',
#  'https://vl.etagi.com/zastr/jk/format-8250/6437155/',
#  'https://vl.etagi.com/zastr/jk/format-8250/6437153/',
#  'https://vl.etagi.com/zastr/jk/format-8250/6437156/',
#  'https://vl.etagi.com/zastr/jk/format-8250/6911923/',
#  'https://vl.etagi.com/zastr/jk/format-8250/6911948/',
#  'https://vl.etagi.com/zastr/jk/format-8250/6911881/',
#  'https://vl.etagi.com/zastr/jk/nadezhdinskoe-polese-6686/7621820/',
#  'https://vl.etagi.com/zastr/jk/nadezhdinskoe-polese-6686/6814206/',
#  'https://vl.etagi.com/zastr/jk/nadezhdinskoe-polese-6686/7621824/',
#  'https://vl.etagi.com/zastr/jk/nadezhdinskoe-polese-6686/8209108/',
#  'https://vl.etagi.com/zastr/jk/nadezhdinskoe-polese-6686/7986611/',
#  'https://vl.etagi.com/zastr/jk/beregovojj-9829/6524370/',
#  'https://vl.etagi.com/zastr/jk/beregovojj-9829/6861585/',
#  'https://vl.etagi.com/zastr/jk/beregovojj-9829/6524372/']

# %%
#Сохраняем в Excel
writer = pd.ExcelWriter('Ссылки_этажи_нов.xlsx')
pd.DataFrame(link_all_2).to_excel(writer, 'link_all')
writer.save()
# Out:
# C:\Users\skapr\AppData\Local\Temp\ipykernel_14032\3144028032.py:4: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
service = Service(executable_path = 'C:\Python\chromedriver.exe')
options = webdriver.ChromeOptions()

options.add_argument("--disable-blink-features")
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
options.add_argument("start_maximized")

driver = webdriver.Chrome(service = service, options = options)

stealth(driver,
#        user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.53 Safari/537.36',
        languages=["en-US", "en"],
        vendor = "Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine",
        fix_hairline=False, #True 
        run_on_insecure_origins=False
        )

pages_lnk = []
t1 = [] #список
a = 0

for lnk in tqdm(link_all_2, 'Сбор данных'):
    try:
        a = a + 1 #счетчик
        t1.clear() #очищаем список значений
        #url = f"https://vl.etagi.com/realty/10106237/"
        driver.get(lnk)
        sleep(3)

#         b = 1
#         while b == 1:
#             try:
#                 button = driver.find_element(By.XPATH, '/html/body/div[7]/div/div[1]/button') #закрываем выбор языка
#                 button.click() #нажимаем кнопку крестик
#             except:
#                 #pass
#                 continue
#             b = b + 1

        #ХАРАКТЕРИСТИКИ_1
        inf_1 = driver.find_element(By.CLASS_NAME, "KrYxJ").text #.split(",")
        inf_1_s = ['Характеристики', inf_1] #создаем список
        t1.append(inf_1_s)                  #складываем в список

        #ЦЕНА
        price = driver.find_element(By.CLASS_NAME, "eypL8").text #.split(",")
        price_s = ['Цена', price] #создаем список
        t1.append(price_s)        #складываем в список

        #ХАРАКТЕРИСТИКИ_2
        Z = driver.find_elements(By.CLASS_NAME, "RzVYb")
        inf_2_z = [i.text for i in Z]
        N = driver.find_elements(By.CLASS_NAME, "pXUis")
        inf_2_n = [j.text for j in N]
        Dictionary = dict(zip(inf_2_z, inf_2_n))
        resultList = list(map(list, Dictionary.items()))
        #t1.append(resultList)
        for res in resultList:
            t1.append(res)

        #ССЫЛКА
        lnk_1 = ['Ссылка', lnk] #создаем список
        t1.append(lnk_1)        #складываем в список

        df = pd.DataFrame(t1)
        df = df.set_index(0)    

        if a == 1:
            df_result = df
        if a > 1:
            df_result = pd.concat([df_result, df], axis = 1)

    except:
        winsound.Beep(2000, 3000) #громкий звук в 3 секунд
        print('Сплю 10 сек')
        pages_lnk.append(lnk)     #страницы, которые не прошли
        sleep(10)                 #спим 10 сек
        #continue

df_result_copy = df_result.copy()
df_result_copy = df_result_copy.transpose()

#Сохраняем в Excel
writer = pd.ExcelWriter('Квартиры_Владивосток_вторич_этажи_нов.xlsx')
df_result_copy.to_excel(writer, 'marks')
writer.save()
# Out:
# Сбор данных:   3%|██▏                                                               | 31/911 [02:14<1:00:54,  4.15s/it]
# Сплю 10 сек
# Сбор данных:  40%|██████████████████████████▉                                        | 366/911 [26:19<39:22,  4.34s/it]
# Сплю 10 сек
# Сбор данных:  56%|█████████████████████████████████████▎                             | 508/911 [36:34<30:06,  4.48s/it]
# Сплю 10 сек
# Сбор данных:  79%|█████████████████████████████████████████████████████▏             | 724/911 [52:31<12:54,  4.14s/it]
# Сплю 10 сек
# Сбор данных: 100%|█████████████████████████████████████████████████████████████████| 911/911 [1:07:02<00:00,  4.42s/it]
# C:\Users\skapr\AppData\Local\Temp\ipykernel_14032\2223955157.py:91: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
service = Service(executable_path = 'C:\Python\chromedriver.exe')
options = webdriver.ChromeOptions()

options.add_argument("--disable-blink-features")
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
options.add_argument("start_maximized")

driver = webdriver.Chrome(service = service, options = options)

stealth(driver,
#        user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.53 Safari/537.36',
        languages=["en-US", "en"],
        vendor = "Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine",
        fix_hairline=False, #True 
        run_on_insecure_origins=False
        )

url =  f"https://vl.etagi.com/zastr/jk/chetyre-gorizonta-8909/4054898/"

driver.get(url)
sleep(2)

# %%
t1 = []

Z = driver.find_elements(By.CLASS_NAME, "RzVYb")
inf_2_z = [i.text for i in Z]
N = driver.find_elements(By.CLASS_NAME, "pXUis")
inf_2_n = [j.text for j in N]
Dictionary = dict(zip(inf_2_z, inf_2_n))
resultList = list(map(list, Dictionary.items()))
#t1.append(resultList)
for res in resultList:
    t1.append(res)

t1
# Out:
# [['Комнатность', '1-комн.'],
#  ['Площадь', '40.28 м²'],
#  ['Дом', 'ЖК "Четыре горизонта" по ул. Третья, д.6, Третья'],
#  ['Срок сдачи', 'Дом сдан'],
#  ['Этаж', '2 из 7'],
#  ['Расположение на этаже', 'Не угловая'],
#  ['Подъезд', '10 подъезд'],
#  ['Тип отделки', 'Черновая'],
#  ['Материал стен', 'Монолитно-Каркасные']]
